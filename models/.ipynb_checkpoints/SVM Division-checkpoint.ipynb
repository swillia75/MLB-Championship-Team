# %%
#import numpy to use seed 
import numpy as np
import pandas as pd
from numpy.random import seed
np.random.seed(1)

# %% [markdown]
# Read CSV create, and clean dataframe

# %%
#Read in CSV and create dataframe
mlb_teams= pd.read_csv("data/Teams.csv")
mlb_teams=mlb_teams.dropna()

mlb_teams
# Out:
#       yearID lgID      G   G.1     W     L  WPCT WSWin      R      AB  ...  \
# 0     2004.0   AL  162.0  81.0  92.0  70.0  0.36     N  836.0  5675.0  ...
# 1     2003.0   AL  162.0  82.0  77.0  85.0  0.48     N  736.0  5487.0  ...
# 2     2002.0   AL  162.0  81.0  99.0  63.0  0.54     Y  851.0  5678.0  ...
# 3     2001.0   AL  162.0  81.0  75.0  87.0  0.48     N  691.0  5551.0  ...
# 4     2000.0   AL  162.0  81.0  82.0  80.0  0.46     N  864.0  5628.0  ...
# ...      ...  ...    ...   ...   ...   ...   ...   ...    ...     ...  ...
# 1224  2006.0   NL  162.0  81.0  71.0  91.0  0.50     N  746.0  5495.0  ...
# 1225  2005.0   NL  162.0  81.0  81.0  81.0  0.51     N  639.0  5426.0  ...
# 1226  1971.0   AL  159.0  81.0  63.0  96.0  0.43     N  537.0  5290.0  ...
# 1227  1970.0   AL  162.0  81.0  70.0  92.0  0.46     N  626.0  5460.0  ...
# 1228  1969.0   AL  162.0  81.0  86.0  76.0  0.49     N  694.0  5447.0  ...
#
#         3B     HR     BB      SO     SB   ERA    CG   SHO    SV  \
# 0     37.0  162.0  450.0   942.0  143.0  4.28   2.0  11.0  50.0
# 1     33.0  150.0  476.0   838.0  129.0  4.28   5.0   9.0  39.0
# 2     32.0  152.0  462.0   805.0  117.0  3.69   7.0  14.0  54.0
# 3     26.0  158.0  494.0  1001.0  116.0  4.20   6.0   1.0  43.0
# 4     34.0  236.0  608.0  1024.0   93.0  5.00   5.0   3.0  46.0
# ...    ...    ...    ...     ...    ...   ...   ...   ...   ...
# 1224  22.0  164.0  594.0  1156.0  123.0  5.03   1.0   3.0  32.0
# 1225  32.0  117.0  491.0  1090.0   45.0  3.87   4.0   9.0  51.0
# 1226  30.0   86.0  575.0   956.0   68.0  3.70  30.0  10.0  26.0
# 1227  28.0  138.0  635.0   989.0   72.0  3.80  20.0  11.0  40.0
# 1228  40.0  148.0  630.0   900.0   52.0  3.49  28.0  10.0  41.0
#
#                       name
# 0           Anaheim Angels
# 1           Anaheim Angels
# 2           Anaheim Angels
# 3           Anaheim Angels
# 4           Anaheim Angels
# ...                    ...
# 1224  Washington Nationals
# 1225  Washington Nationals
# 1226   Washington Senators
# 1227   Washington Senators
# 1228   Washington Senators
#
# [1229 rows x 22 columns]

# %%
#Get list of dataframe columns

mlb_teams.columns
# Out:
# Index(['yearID', 'lgID', 'G', 'G.1', 'W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H',
#        '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV', 'name'],
#       dtype='object')

# %%
#Select columns for dataframe

mlb_df = mlb_teams[['yearID', 'lgID', 'G', 'G.1', 'W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H', '2B',
       '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV']]
mlb_df.head(20)
# Out:
#     yearID lgID      G   G.1     W      L  WPCT WSWin      R      AB  ...  \
# 0   2004.0   AL  162.0  81.0  92.0   70.0  0.36     N  836.0  5675.0  ...
# 1   2003.0   AL  162.0  82.0  77.0   85.0  0.48     N  736.0  5487.0  ...
# 2   2002.0   AL  162.0  81.0  99.0   63.0  0.54     Y  851.0  5678.0  ...
# 3   2001.0   AL  162.0  81.0  75.0   87.0  0.48     N  691.0  5551.0  ...
# 4   2000.0   AL  162.0  81.0  82.0   80.0  0.46     N  864.0  5628.0  ...
# 5   1999.0   AL  162.0  81.0  70.0   92.0  0.53     N  711.0  5494.0  ...
# 6   1998.0   AL  162.0  81.0  85.0   77.0  0.46     N  787.0  5630.0  ...
# 7   1997.0   AL  162.0  82.0  84.0   78.0  0.45     N  829.0  5628.0  ...
# 8   2014.0   NL  162.0  81.0  64.0   98.0  0.57     N  615.0  5552.0  ...
# 9   2013.0   NL  162.0  81.0  81.0   81.0  0.47     N  685.0  5676.0  ...
# 3  2001.0   AL  162.0  81.0  75.0  87.0  0.48  691.0  5551.0  1447.0  ...
# 4  2000.0   AL  162.0  81.0  82.0  80.0  0.46  864.0  5628.0  1574.0  ...
#
#      3B     HR     BB      SO     SB   ERA   CG   SHO    SV  WSWin_Y
# 0  37.0  162.0  450.0   942.0  143.0  4.28  2.0  11.0  50.0        0
# 1  33.0  150.0  476.0   838.0  129.0  4.28  5.0   9.0  39.0        0
# 2  32.0  152.0  462.0   805.0  117.0  3.69  7.0  14.0  54.0        1
# 3  26.0  158.0  494.0  1001.0  116.0  4.20  6.0   1.0  43.0        0
# 4  34.0  236.0  608.0  1024.0   93.0  5.00  5.0   3.0  46.0        0
#
# [5 rows x 21 columns]

# %%
data = data_bin.drop("lgID", axis = 1)
outcome = data_bin["lgID"]
print(data.shape, outcome.shape)
# Out:
# (1229, 20) (1229,)

# %% [markdown]
# Preprocess data

# %%
#Import SciKit libraries

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
#Split data and teams into training and test data

X_train, X_test, y_train, y_test = train_test_split(data, outcome, random_state=1)
y_train
# Out:
# 503     AL
# 842     AL
# 419     AL
# 493     NL
# 325     AL
#         ..
# 715     NL
# 905     NL
# 1096    NL
# 235     AL
# 1061    AL
# Name: lgID, Length: 921, dtype: object

# %%
#Scale data using StandarScaler

X_scaler = StandardScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
X_train_scaled
# Out:
# array([[ 1.06666632,  0.21120348,  0.21161126, ..., -0.88738464,
#         -0.17953   , -0.1927749 ],
#        [-0.6497719 ,  0.21120348,  0.21161126, ..., -0.88738464,
#          0.68165296, -0.1927749 ],
#        [-0.79902739,  0.21120348,  0.21161126, ..., -1.13229961,
#         -1.14836083, -0.1927749 ],
#        ...,
#        [-0.05274991,  0.21120348,  0.21161126, ..., -0.15263973,
#          1.00459658, -0.1927749 ],
#        [ 1.36517732,  0.21120348,  0.21161126, ...,  1.07193512,
#          0.46635722, -0.1927749 ],
#        [-0.2020054 ,  0.21120348,  0.21161126, ..., -0.64246967,
#          0.35870935, -0.1927749 ]])

# %%
#Import and use SVC MODEL
from sklearn.svm import SVC 
model = SVC(kernel='linear')
model.fit(X_train_scaled, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
#Print training and test scores from model using datasets

print(f"Training Data Score: {model.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {model.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.741585233441911
# Testing Data Score: 0.7467532467532467

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [100, 500, 1000],
              'gamma': [0.0001, 0.005, 0.001]}
grid = GridSearchCV(model, param_grid, verbose=3)

# %%
# Train the model with GridSearch

grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] C=100, gamma=0.0001 .............................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ................. C=100, gamma=0.0001, score=0.751, total=   2.6s
# [CV] C=100, gamma=0.0001 .............................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.5s remaining:    0.0s
# [CV] ................. C=100, gamma=0.0001, score=0.707, total=   1.9s
# [CV] C=100, gamma=0.0001 .............................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.5s remaining:    0.0s
# [CV] ................. C=100, gamma=0.0001, score=0.755, total=   3.1s
# [CV] C=100, gamma=0.0001 .............................................
# [CV] ................. C=100, gamma=0.0001, score=0.701, total=   3.1s
# [CV] C=100, gamma=0.0001 .............................................
# [CV] ................. C=100, gamma=0.0001, score=0.712, total=   3.5s
# [CV] C=100, gamma=0.005 ..............................................
# [CV] .................. C=100, gamma=0.005, score=0.751, total=   2.5s
# [CV] C=100, gamma=0.005 ..............................................
# [CV] .................. C=100, gamma=0.005, score=0.707, total=   2.0s
# [CV] C=100, gamma=0.005 ..............................................
# [CV] .................. C=100, gamma=0.005, score=0.755, total=   3.2s
# [CV] C=100, gamma=0.005 ..............................................
# [CV] .................. C=100, gamma=0.005, score=0.701, total=   3.6s
# [CV] C=100, gamma=0.005 ..............................................
# [CV] .................. C=100, gamma=0.005, score=0.712, total=   3.6s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] .................. C=100, gamma=0.001, score=0.751, total=   2.6s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] .................. C=100, gamma=0.001, score=0.707, total=   2.0s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] .................. C=100, gamma=0.001, score=0.755, total=   3.5s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] .................. C=100, gamma=0.001, score=0.701, total=   3.6s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] .................. C=100, gamma=0.001, score=0.712, total=   3.8s
# [CV] C=500, gamma=0.0001 .............................................
# [CV] ................. C=500, gamma=0.0001, score=0.757, total=  13.1s
# [CV] C=500, gamma=0.0001 .............................................
# [CV] ................. C=500, gamma=0.0001, score=0.701, total=   9.9s
# [CV] C=500, gamma=0.0001 .............................................
# [CV] ................. C=500, gamma=0.0001, score=0.750, total=  15.2s
# [CV] C=500, gamma=0.0001 .............................................
# [CV] ................. C=500, gamma=0.0001, score=0.701, total=  20.3s
# [CV] C=500, gamma=0.0001 .............................................
# [CV] ................. C=500, gamma=0.0001, score=0.712, total=  15.7s
# [CV] C=500, gamma=0.005 ..............................................
# [CV] .................. C=500, gamma=0.005, score=0.757, total=  13.6s
# [CV] C=500, gamma=0.005 ..............................................
# [CV] .................. C=500, gamma=0.005, score=0.701, total=  10.2s
# [CV] C=500, gamma=0.005 ..............................................
# [CV] .................. C=500, gamma=0.005, score=0.750, total=  15.2s
# [CV] C=500, gamma=0.005 ..............................................
# [CV] .................. C=500, gamma=0.005, score=0.701, total=  20.3s
# [CV] C=500, gamma=0.005 ..............................................
# [CV] .................. C=500, gamma=0.005, score=0.712, total=  15.1s
# [CV] C=500, gamma=0.001 ..............................................
# [CV] .................. C=500, gamma=0.001, score=0.757, total=  13.5s
# [CV] C=500, gamma=0.001 ..............................................
# [CV] .................. C=500, gamma=0.001, score=0.701, total=  10.5s
# [CV] C=500, gamma=0.001 ..............................................
# [CV] .................. C=500, gamma=0.001, score=0.750, total=  14.7s
# [CV] C=500, gamma=0.001 ..............................................
# [CV] .................. C=500, gamma=0.001, score=0.701, total=  22.6s
# [CV] C=500, gamma=0.001 ..............................................
# [CV] .................. C=500, gamma=0.001, score=0.712, total=  15.1s
# [CV] C=1000, gamma=0.0001 ............................................
# [CV] ................ C=1000, gamma=0.0001, score=0.751, total=  45.6s
# [CV] C=1000, gamma=0.0001 ............................................
# [CV] ................ C=1000, gamma=0.0001, score=0.701, total=  18.4s
# [CV] C=1000, gamma=0.0001 ............................................
# [CV] ................ C=1000, gamma=0.0001, score=0.755, total=  31.2s
# [CV] C=1000, gamma=0.0001 ............................................
# [CV] ................ C=1000, gamma=0.0001, score=0.701, total=  31.3s
# [CV] C=1000, gamma=0.0001 ............................................
# [CV] ................ C=1000, gamma=0.0001, score=0.712, total=  24.0s
# [CV] C=1000, gamma=0.005 .............................................
# [CV] ................. C=1000, gamma=0.005, score=0.751, total=  46.5s
# [CV] C=1000, gamma=0.005 .............................................
# [CV] ................. C=1000, gamma=0.005, score=0.701, total=  19.4s
# [CV] C=1000, gamma=0.005 .............................................
# [CV] ................. C=1000, gamma=0.005, score=0.755, total=  31.4s
# [CV] C=1000, gamma=0.005 .............................................
# [CV] ................. C=1000, gamma=0.005, score=0.701, total=  30.7s
# [CV] C=1000, gamma=0.005 .............................................
# [CV] ................. C=1000, gamma=0.005, score=0.712, total=  24.3s
# [CV] C=1000, gamma=0.001 .............................................
# [CV] ................. C=1000, gamma=0.001, score=0.751, total= 7.1min
# [CV] C=1000, gamma=0.001 .............................................
# [CV] ................. C=1000, gamma=0.001, score=0.701, total=  19.3s
# [CV] C=1000, gamma=0.001 .............................................
# [CV] ................. C=1000, gamma=0.001, score=0.755, total=  32.0s
# [CV] C=1000, gamma=0.001 .............................................
# [CV] ................. C=1000, gamma=0.001, score=0.701, total=  30.1s
# [CV] C=1000, gamma=0.001 .............................................
# [CV] ................. C=1000, gamma=0.001, score=0.712, total=  24.8s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed: 18.5min finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=SVC(C=1.0, break_ties=False, cache_size=200,
#                            class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='scale', kernel='linear', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'C': [100, 500, 1000],
#                          'gamma': [0.0001, 0.005, 0.001]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %% [markdown]
# Train Model

# %%
#Print best parameters and score from Gridsearch

print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'C': 100, 'gamma': 0.0001}
# 0.7252702702702704

# %%
#Print accuracy of model using test dataset

print('Test Acc: %.3f' % grid.score(X_test_scaled, y_test))
# Out:
# Test Acc: 0.753

# %% [markdown]
# Evaluate Model

# %% [markdown]
# Predict World Series Champs

# %%
#Read in CSV and create dataframe
mlb_teams2015= pd.read_csv("data/2015.csv")



mlb2015_df = mlb_teams2015[['yearID', 'lgID', 'G', 'G.1', 'W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H', '2B',
       '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV']]


data_LG2015 = mlb2015_df.copy()
data_bin2015 = pd.get_dummies(data_LG2015, columns=["WSWin"])
data_bin2015 = data_bin2015.drop(columns=['WSWin_N'])



feature2015 = data_bin2015.drop("lgID", axis=1)
team2015 = data_bin2015["lgID"]

X_feature2015_scaler = StandardScaler().fit(feature2015)
X_feature2015_scaled = X_feature2015_scaler.transform(feature2015)

#Make prediction using test data

predictions2015 = grid.predict(X_feature2015_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2015_scaled, team2015))



predictions2015 = model.predict(X_feature2015_scaled)
predictions2015
# Out:
# Test Acc: 0.743
# array(['NL', 'AL', 'NL', 'AL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'AL',
#        'AL', 'NL', 'AL', 'NL', 'NL', 'NL', 'NL', 'AL', 'AL', 'NL', 'NL',
#        'NL', 'AL', 'AL', 'NL', 'NL', 'AL', 'AL', 'AL', 'NL', 'NL', 'NL',
#        'NL', 'NL'], dtype=object)

# %%
#Read in CSV and create dataframe
mlb_teams2016= pd.read_csv("data/2016.csv")



mlb2016_df = mlb_teams2016[['yearID', 'lgID', 'G', 'G.1', 'W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H', '2B',
       '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV']]


data_LG2016 = mlb2016_df.copy()
data_bin2016 = pd.get_dummies(data_LG2016, columns=["WSWin"])
data_bin2016 = data_bin2016.drop(columns=['WSWin_N'])



feature2016 = data_bin2016.drop("lgID", axis=1)
team2016 = data_bin2016["lgID"]

X_feature2016_scaler = StandardScaler().fit(feature2016)
X_feature2016_scaled = X_feature2016_scaler.transform(feature2016)

#Make prediction using test data

predictions2016 = grid.predict(X_feature2016_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2016_scaled, team2016))



predictions2016 = model.predict(X_feature2016_scaled)
predictions2016
# Out:
# Test Acc: 0.657
# array(['NL', 'NL', 'AL', 'AL', 'AL', 'AL', 'NL', 'AL', 'NL', 'AL', 'NL',
#        'NL', 'AL', 'AL', 'NL', 'NL', 'AL', 'NL', 'NL', 'AL', 'AL', 'AL',
#        'NL', 'AL', 'AL', 'NL', 'NL', 'NL', 'NL', 'NL', 'NL', 'NL', 'NL',
#        'NL', 'NL'], dtype=object)

# %%
#Read in CSV and create dataframe
mlb_teams2017= pd.read_csv("data/2017.csv")



mlb2017_df = mlb_teams2017[['yearID', 'lgID', 'G', 'G.1', 'W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H', '2B',
       '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV']]


data_LG2017 = mlb2017_df.copy()
data_bin2017 = pd.get_dummies(data_LG2017, columns=["WSWin"])
data_bin2017 = data_bin2017.drop(columns=['WSWin_N'])



feature2017 = data_bin2017.drop("lgID", axis=1)
team2017 = data_bin2017["lgID"]

X_feature2017_scaler = StandardScaler().fit(feature2017)
X_feature2017_scaled = X_feature2017_scaler.transform(feature2017)

#Make prediction using test data

predictions2017 = grid.predict(X_feature2017_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2017_scaled, team2017))



predictions2017 = model.predict(X_feature2017_scaled)
predictions2017
# Out:
# Test Acc: 0.657
# array(['NL', 'NL', 'NL', 'AL', 'NL', 'NL', 'NL', 'AL', 'NL', 'AL', 'AL',
#        'NL', 'NL', 'NL', 'NL', 'NL', 'AL', 'AL', 'NL', 'NL', 'NL', 'AL',
#        'NL', 'AL', 'NL', 'AL', 'NL', 'NL', 'AL', 'AL', 'NL', 'NL', 'NL',
#        'NL', 'NL'], dtype=object)

# %%
#Predict 2018 WS winner (division)
mlb_teams2018= pd.read_csv("data/2018.csv")



mlb2018_df = mlb_teams2018[['yearID', 'lgID', 'G', 'G.1', 'W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H', '2B',
       '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV']]


data_LG2018 = mlb2018_df.copy()
data_bin2018 = pd.get_dummies(data_LG2018, columns=["WSWin"])
data_bin2018 = data_bin2018.drop(columns=['WSWin_N'])



feature2018 = data_bin2018.drop("lgID", axis=1)
team2018 = data_bin2018["lgID"]

X_feature2018_scaler = StandardScaler().fit(feature2018)
X_feature2018_scaled = X_feature2018_scaler.transform(feature2018)

#Make prediction using test data

predictions2018 = grid.predict(X_feature2018_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2018_scaled, team2018))



predictions2018 = model.predict(X_feature2018_scaled)
predictions2018
# Out:
# Test Acc: 0.657
# array(['NL', 'AL', 'AL', 'AL', 'NL', 'NL', 'NL', 'AL', 'NL', 'NL', 'AL',
#        'AL', 'NL', 'NL', 'NL', 'NL', 'AL', 'AL', 'AL', 'AL', 'NL', 'AL',
#        'NL', 'NL', 'AL', 'AL', 'NL', 'AL', 'NL', 'AL', 'NL', 'NL', 'NL',
#        'NL', 'NL'], dtype=object)

# %%
#Predict 2019 WS winner (division)
mlb_teams2019= pd.read_csv("data/MLB 2019 season.csv")



mlb2019_df = mlb_teams2019[['yearID', 'lgID', 'G', 'G.1', 'W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H', '2B',
       '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV']]


data_LG2019 = mlb2019_df.copy()
data_bin2019 = pd.get_dummies(data_LG2019, columns=["WSWin"])
data_bin2019 = data_bin2019.drop(columns=['WSWin_N'])



feature2019 = data_bin2019.drop("lgID", axis=1)
team2019 = data_bin2019["lgID"]

X_feature2019_scaler = StandardScaler().fit(feature2019)
X_feature2019_scaled = X_feature2019_scaler.transform(feature2019)

#Make prediction using test data

predictions2019 = grid.predict(X_feature2019_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2019_scaled, team2019))



predictions2019 = model.predict(X_feature2019_scaled)
predictions2019
# Out:
# Test Acc: 0.657
# array(['NL', 'NL', 'NL', 'NL', 'AL', 'NL', 'NL', 'AL', 'NL', 'NL', 'AL',
#        'NL', 'NL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'NL', 'AL', 'NL',
#        'NL', 'AL', 'NL', 'NL', 'NL', 'AL', 'NL', 'AL', 'NL', 'NL', 'NL',
#        'NL', 'NL'], dtype=object)

# %%
#Read in CSV and create dataframe
mlb_teams2020= pd.read_csv("data/2020.csv")



mlb2020_df = mlb_teams2020[['yearID', 'lgID', 'G', 'G.1', 'W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H', '2B',
       '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV']]


data_LG2020 = mlb2020_df.copy()
data_bin2020 = pd.get_dummies(data_LG2020, columns=["WSWin"])
data_bin2020 = data_bin2020.drop(columns=['WSWin_N'])

feature2020 = data_bin2020.drop("lgID", axis=1)
team2020 = data_bin2020["lgID"]

X_feature2020_scaler = StandardScaler().fit(feature2020)
X_feature2020_scaled = X_feature2020_scaler.transform(feature2020)

#Make prediction using test data

predictions2020 = grid.predict(X_feature2020_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2020_scaled, team2020))


predictions2020 = model.predict(X_feature2020_scaled)
predictions2020
# Out:
# Test Acc: 0.571
# array(['NL', 'NL', 'NL', 'NL', 'AL', 'AL', 'AL', 'NL', 'NL', 'AL', 'NL',
#        'AL', 'AL', 'NL', 'NL', 'NL', 'NL', 'NL', 'AL', 'NL', 'AL', 'AL',
#        'NL', 'NL', 'AL', 'AL', 'NL', 'AL', 'NL', 'AL', 'NL', 'NL', 'NL',
#        'NL', 'NL'], dtype=object)

# %%
import joblib
filename = 'saved_models/SWilliams_SVMdivision.sav'
joblib.dump(model, filename)
# Out:
# ['saved_models/SWilliams_SVMdivision.sav']
