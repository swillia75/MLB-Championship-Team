# %%
#import numpy to use seed 
import numpy as np
import pandas as pd
from numpy.random import seed
np.random.seed(1)

# %% [markdown]
# Read CSV create, and clean dataframe

# %%
#Read in CSV and create dataframe
mlb_teams= pd.read_csv("data/Teams.csv")
mlb_teams=mlb_teams.dropna()

mlb_teams
# Out:
#       yearID lgID      G   G.1     W     L  WPCT WSWin      R      AB  ...  \
# 0     2004.0   AL  162.0  81.0  92.0  70.0  0.36     N  836.0  5675.0  ...
# 1     2003.0   AL  162.0  82.0  77.0  85.0  0.48     N  736.0  5487.0  ...
# 2     2002.0   AL  162.0  81.0  99.0  63.0  0.54     Y  851.0  5678.0  ...
# 3     2001.0   AL  162.0  81.0  75.0  87.0  0.48     N  691.0  5551.0  ...
# 4     2000.0   AL  162.0  81.0  82.0  80.0  0.46     N  864.0  5628.0  ...
# ...      ...  ...    ...   ...   ...   ...   ...   ...    ...     ...  ...
# 1224  2006.0   NL  162.0  81.0  71.0  91.0  0.50     N  746.0  5495.0  ...
# 1225  2005.0   NL  162.0  81.0  81.0  81.0  0.51     N  639.0  5426.0  ...
# 1226  1971.0   AL  159.0  81.0  63.0  96.0  0.43     N  537.0  5290.0  ...
# 1227  1970.0   AL  162.0  81.0  70.0  92.0  0.46     N  626.0  5460.0  ...
# 1228  1969.0   AL  162.0  81.0  86.0  76.0  0.49     N  694.0  5447.0  ...
#
#         3B     HR     BB      SO     SB   ERA    CG   SHO    SV  \
# 0     37.0  162.0  450.0   942.0  143.0  4.28   2.0  11.0  50.0
# 1     33.0  150.0  476.0   838.0  129.0  4.28   5.0   9.0  39.0
# 2     32.0  152.0  462.0   805.0  117.0  3.69   7.0  14.0  54.0
# 3     26.0  158.0  494.0  1001.0  116.0  4.20   6.0   1.0  43.0
# 4     34.0  236.0  608.0  1024.0   93.0  5.00   5.0   3.0  46.0
# ...    ...    ...    ...     ...    ...   ...   ...   ...   ...
# 1224  22.0  164.0  594.0  1156.0  123.0  5.03   1.0   3.0  32.0
# 1225  32.0  117.0  491.0  1090.0   45.0  3.87   4.0   9.0  51.0
# 1226  30.0   86.0  575.0   956.0   68.0  3.70  30.0  10.0  26.0
# 1227  28.0  138.0  635.0   989.0   72.0  3.80  20.0  11.0  40.0
# 1228  40.0  148.0  630.0   900.0   52.0  3.49  28.0  10.0  41.0
#
#                       name
# 0           Anaheim Angels
# 1           Anaheim Angels
# 2           Anaheim Angels
# 3           Anaheim Angels
# 4           Anaheim Angels
# ...                    ...
# 1224  Washington Nationals
# 1225  Washington Nationals
# 1226   Washington Senators
# 1227   Washington Senators
# 1228   Washington Senators
#
# [1229 rows x 22 columns]

# %%
#Get list of dataframe columns

mlb_teams.columns
# Out:
# Index(['yearID', 'lgID', 'G', 'G.1', 'W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H',
#        '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV', 'name'],
#       dtype='object')

# %%
#Select columns for dataframe

mlb_df = mlb_teams[['W', 'L', 'WPCT', 'WSWin', 'R', 'H', '2B',
       '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'SHO', 'SV', 'name']]


mlb_df.tail(37)
# Out:
#          W      L  WPCT WSWin      R       H     2B    3B     HR     BB  \
# 1192  80.0   82.0  0.51     N  767.0  1489.0  287.0  36.0  195.0  470.0
# 1193  83.0   79.0  0.54     N  861.0  1562.0  328.0  21.0  244.0  526.0
# 1194  84.0   78.0  0.55     N  883.0  1580.0  337.0  14.0  212.0  578.0
# 1195  88.0   74.0  0.46     N  816.0  1482.0  316.0  19.0  221.0  564.0
# 1196  76.0   86.0  0.49     N  654.0  1333.0  275.0  41.0  147.0  487.0
# 1197  74.0   88.0  0.51     N  766.0  1451.0  302.0  35.0  177.0  529.0
# 1198  56.0   88.0  0.56     N  642.0  1309.0  275.0  27.0  140.0  492.0
# 1199  95.0   67.0  0.44     Y  847.0  1556.0  317.0  42.0  159.0  588.0
# 1200  96.0   66.0  0.56     Y  780.0  1458.0  265.0  40.0  163.0  561.0
# 1201  91.0   71.0  0.47     N  684.0  1412.0  295.0  45.0  133.0  499.0
# 1202  86.0   76.0  0.51     N  767.0  1479.0  263.0  50.0  167.0  526.0
# 1203  89.0   73.0  0.47     N  731.0  1449.0  265.0  40.0  142.0  521.0
# 1204  87.0   75.0  0.57     N  763.0  1491.0  271.0  47.0  158.0  521.0
# 1205  96.0   66.0  0.43     N  845.0  1514.0  277.0  38.0  215.0  555.0
# 1206  86.0   76.0  0.47     N  809.0  1540.0  285.0  35.0  181.0  496.0
# 1207  99.0   62.0  0.43     N  759.0  1482.0  281.0  53.0  158.0  503.0
# 1208  89.0   73.0  0.59     N  750.0  1555.0  275.0  68.0  143.0  460.0
# 1209  89.0   73.0  0.57     N  795.0  1546.0  268.0  58.0  167.0  510.0
# 1210  78.0   84.0  0.27     N  651.0  1447.0  262.0  45.0  106.0  415.0
# 1211  37.0   69.0  0.55     N  329.0   797.0  137.0  23.0   61.0  284.0
# 1212  67.0   95.0  0.46     N  624.0  1398.0  249.0  53.0  126.0  448.0
# 1213  53.0  109.0  0.49     N  613.0  1362.0  253.0  34.0   95.0  448.0
# 1214  59.0  102.0  0.47     N  590.0  1358.0  217.0  39.0   98.0  448.0
# 1215  54.0  107.0  0.55     N  605.0  1367.0  230.0  41.0  100.0  499.0
# 1216  96.0   66.0  0.63     N  686.0  1403.0  265.0  27.0  152.0  517.0
# 1217  86.0   76.0  0.46     N  656.0  1365.0  259.0  27.0  161.0  464.0
# 1218  98.0   64.0  0.38     N  731.0  1468.0  301.0  25.0  194.0  479.0
# 1219  80.0   81.0  0.54     N  624.0  1319.0  257.0  22.0  154.0  470.0
# 1220  69.0   93.0  0.67     N  655.0  1355.0  250.0  31.0  149.0  503.0
# 1221  59.0  103.0  0.52     N  710.0  1416.0  271.0  38.0  156.0  617.0
# 1222  59.0  102.0  0.62     N  641.0  1376.0  269.0  26.0  117.0  534.0
# 1223  73.0   89.0  0.55     N  673.0  1415.0  309.0  31.0  123.0  524.0
# 1224  71.0   91.0  0.50     N  746.0  1437.0  322.0  22.0  164.0  594.0
# 1225  81.0   81.0  0.51     N  639.0  1367.0  311.0  32.0  117.0  491.0
# 1226  63.0   96.0  0.43     N  537.0  1219.0  189.0  30.0   86.0  575.0
# 1227  70.0   92.0  0.46     N  626.0  1302.0  184.0  28.0  138.0  635.0
# 1228  86.0   76.0  0.49     N  694.0  1365.0  171.0  40.0  148.0  630.0
#
#           SO     SB   ERA   SHO    SV                  name
# 1192  1094.0  156.0  4.28  10.0  41.0     Toronto Blue Jays
# 1193  1026.0   89.0  5.14   4.0  37.0     Toronto Blue Jays
# 1194  1077.0  119.0  4.92   9.0  39.0     Toronto Blue Jays
# 1195  1132.0  184.0  4.28  11.0  47.0     Toronto Blue Jays
# 1196  1138.0  134.0  3.92  16.0  34.0     Toronto Blue Jays
# 1197  1105.0  116.0  4.57   7.0  35.0     Toronto Blue Jays
# 1198   906.0   75.0  4.88   8.0  22.0     Toronto Blue Jays
# 1199   861.0  170.0  4.21  11.0  50.0     Toronto Blue Jays
# 1200   933.0  129.0  3.91  14.0  49.0     Toronto Blue Jays
# 1201  1043.0  148.0  3.50  16.0  60.0     Toronto Blue Jays
# 1202   970.0  111.0  3.84   9.0  48.0     Toronto Blue Jays
# 1203   923.0  144.0  3.58  12.0  38.0     Toronto Blue Jays
# 1204   935.0  107.0  3.80  17.0  47.0     Toronto Blue Jays
# 1205   970.0  126.0  3.74   8.0  43.0     Toronto Blue Jays
# 1206   848.0  110.0  4.08  12.0  44.0     Toronto Blue Jays
# 1207   807.0  144.0  3.31   9.0  47.0     Toronto Blue Jays
# 1208   816.0  193.0  3.86  10.0  33.0     Toronto Blue Jays
# 1209   810.0  131.0  4.12   8.0  32.0     Toronto Blue Jays
# 1210   749.0  118.0  3.95  13.0  25.0     Toronto Blue Jays
# 1211   556.0   66.0  3.81   4.0  18.0     Toronto Blue Jays
# 1212   813.0   67.0  4.19   9.0  23.0     Toronto Blue Jays
# 1213   663.0   75.0  4.82   7.0  11.0     Toronto Blue Jays
# 1214   645.0   28.0  4.54   5.0  23.0     Toronto Blue Jays
# 1215   819.0   65.0  4.57   3.0  20.0     Toronto Blue Jays
# 1216  1304.0  101.0  3.03  19.0  45.0  Washington Nationals
# 1217  1192.0   88.0  3.59  13.0  47.0  Washington Nationals
# 1218  1325.0  105.0  3.33   9.0  51.0  Washington Nationals
# 1219  1323.0  106.0  3.58  10.0  49.0  Washington Nationals
# 1220  1220.0  110.0  4.13   5.0  37.0  Washington Nationals
# 1221  1208.0   73.0  5.00   3.0  33.0  Washington Nationals
# 1222  1095.0   81.0  4.66   8.0  28.0  Washington Nationals
# 1223  1128.0   69.0  4.58   6.0  46.0  Washington Nationals
# 1224  1156.0  123.0  5.03   3.0  32.0  Washington Nationals
# 1225  1090.0   45.0  3.87   9.0  51.0  Washington Nationals
# 1226   956.0   68.0  3.70  10.0  26.0   Washington Senators
# 1227   989.0   72.0  3.80  11.0  40.0   Washington Senators
# 1228   900.0   52.0  3.49  10.0  41.0   Washington Senators

# %%
#Use getdummies to convert strings

data_LG = mlb_df.copy()
data_bin = pd.get_dummies(data_LG, columns=["WSWin"])
data_bin = data_bin.drop(columns=['WSWin_N'])

data_bin.head()
# Out:
#       W     L  WPCT      R       H     2B    3B     HR     BB      SO     SB  \
# 0  92.0  70.0  0.36  836.0  1603.0  272.0  37.0  162.0  450.0   942.0  143.0
# 1  77.0  85.0  0.48  736.0  1473.0  276.0  33.0  150.0  476.0   838.0  129.0
# 2  99.0  63.0  0.54  851.0  1603.0  333.0  32.0  152.0  462.0   805.0  117.0
# 3  75.0  87.0  0.48  691.0  1447.0  275.0  26.0  158.0  494.0  1001.0  116.0
# 4  82.0  80.0  0.46  864.0  1574.0  309.0  34.0  236.0  608.0  1024.0   93.0
#
#     ERA   SHO    SV            name  WSWin_Y
# 0  4.28  11.0  50.0  Anaheim Angels        0
# 1  4.28   9.0  39.0  Anaheim Angels        0
# 2  3.69  14.0  54.0  Anaheim Angels        1
# 3  4.20   1.0  43.0  Anaheim Angels        0
# 4  5.00   3.0  46.0  Anaheim Angels        0

# %%
#Set X(data) and y(outcome)variables

data = data_bin.drop("name", axis = 1)
outcome = data_bin["name"]
print(data.shape, outcome.shape)
# Out:
# (1229, 15) (1229,)

# %% [markdown]
# Preprocess data

# %%
#Import SciKit libraries

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
#Split data and teams into training and test data

X_train, X_test, y_train, y_test = train_test_split(data, outcome, test_size = 0.2, random_state=42)
y_train
# Out:
# 752             New York Mets
# 1067         Seattle Mariners
# 986          San Diego Padres
# 425            Detroit Tigers
# 644           Minnesota Twins
#                 ...
# 1044         Seattle Mariners
# 1095      St. Louis Cardinals
# 1130           Tampa Bay Rays
# 860     Philadelphia Phillies
# 1126     Tampa Bay Devil Rays
# Name: name, Length: 983, dtype: object

# %%
#Scale data using StandardScaler

X_scaler = StandardScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
X_train_scaled
# Out:
# array([[ 0.80105711, -0.66065155,  0.85575934, ...,  1.26773464,
#          1.31530756, -0.1949738 ],
#        [-0.52112006,  0.68164629, -1.14270664, ..., -1.38371888,
#         -0.32188727, -0.1949738 ],
#        [-0.76902827,  0.93332714,  0.28476906, ...,  0.54461096,
#         -1.9590821 , -0.1949738 ],
#        ...,
#        [-0.27321184,  0.42996545,  0.42751663, ...,  2.95502325,
#         -0.10359463, -0.1949738 ],
#        [ 0.05733245,  0.09439099,  0.71301177, ...,  0.30356973,
#          0.44213698, -0.1949738 ],
#        [-1.51275293,  1.68836967, -0.57171636, ..., -0.90163642,
#         -0.86761888, -0.1949738 ]])

# %%
##Import RandomForestClassifier and train

from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=1000, random_state=1)

rf.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=1000,
#                        n_jobs=None, oob_score=False, random_state=1, verbose=0,
#                        warm_start=False)

# %%
#Get Score for RandomForestClassifier
rf.score(X_test_scaled, y_test)
# Out:
# 0.2032520325203252

# %%
#Print data scores for training aand test datasets
print(f"Training Data Score: {rf.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {rf.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 1.0
# Testing Data Score: 0.2032520325203252

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {"bootstrap": [True],
              "max_depth": [20, 40, 100, 125],
              "n_estimators": [100, 500, 1000]
              }
grid = GridSearchCV(rf, param_grid, verbose=3)
grid
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=1000, n_jobs=None,
#                                               oob_score=False, random_state=1,
#                                               verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'bootstrap': [True], 'max_depth': [20, 40, 100, 125],
#                          'n_estimators': [100, 500, 1000]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %% [markdown]
# Train Model

# %%
# Train the model with GridSearch

grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] bootstrap=True, max_depth=20, n_estimators=100 ..................
# C:\Users\swill\Anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_split.py:667: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  bootstrap=True, max_depth=20, n_estimators=100, score=0.157, total=   0.8s
# [CV] bootstrap=True, max_depth=20, n_estimators=100 ..................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.7s remaining:    0.0s
# [CV]  bootstrap=True, max_depth=20, n_estimators=100, score=0.183, total=   0.8s
# [CV] bootstrap=True, max_depth=20, n_estimators=100 ..................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.5s remaining:    0.0s
# [CV]  bootstrap=True, max_depth=20, n_estimators=100, score=0.203, total=   0.8s
# [CV] bootstrap=True, max_depth=20, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=100, score=0.173, total=   0.8s
# [CV] bootstrap=True, max_depth=20, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=100, score=0.194, total=   0.8s
# [CV] bootstrap=True, max_depth=20, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=500, score=0.213, total=   4.0s
# [CV] bootstrap=True, max_depth=20, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=500, score=0.173, total=   4.0s
# [CV] bootstrap=True, max_depth=20, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=500, score=0.203, total=   3.9s
# [CV] bootstrap=True, max_depth=20, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=500, score=0.173, total=   4.0s
# [CV] bootstrap=True, max_depth=20, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=500, score=0.219, total=   3.9s
# [CV] bootstrap=True, max_depth=20, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=20, n_estimators=1000, score=0.198, total=   8.4s
# [CV] bootstrap=True, max_depth=20, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=20, n_estimators=1000, score=0.162, total=   8.0s
# [CV] bootstrap=True, max_depth=20, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=20, n_estimators=1000, score=0.198, total=   8.1s
# [CV] bootstrap=True, max_depth=20, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=20, n_estimators=1000, score=0.173, total=   8.1s
# [CV] bootstrap=True, max_depth=20, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=20, n_estimators=1000, score=0.230, total=   8.8s
# [CV] bootstrap=True, max_depth=40, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=100, score=0.162, total=   0.8s
# [CV] bootstrap=True, max_depth=40, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=100, score=0.213, total=   0.8s
# [CV] bootstrap=True, max_depth=40, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=100, score=0.173, total=   0.8s
# [CV] bootstrap=True, max_depth=40, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=100, score=0.153, total=   0.8s
# [CV] bootstrap=True, max_depth=40, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=100, score=0.240, total=   0.8s
# [CV] bootstrap=True, max_depth=40, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=500, score=0.198, total=   4.0s
# [CV] bootstrap=True, max_depth=40, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=500, score=0.178, total=   3.9s
# [CV] bootstrap=True, max_depth=40, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=500, score=0.198, total=   4.0s
# [CV] bootstrap=True, max_depth=40, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=500, score=0.158, total=   3.9s
# [CV] bootstrap=True, max_depth=40, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=500, score=0.250, total=   4.0s
# [CV] bootstrap=True, max_depth=40, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=40, n_estimators=1000, score=0.193, total=   8.3s
# [CV] bootstrap=True, max_depth=40, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=40, n_estimators=1000, score=0.168, total=   8.0s
# [CV] bootstrap=True, max_depth=40, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=40, n_estimators=1000, score=0.193, total=   8.0s
# [CV] bootstrap=True, max_depth=40, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=40, n_estimators=1000, score=0.179, total=   8.0s
# [CV] bootstrap=True, max_depth=40, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=40, n_estimators=1000, score=0.235, total=   8.8s
# [CV] bootstrap=True, max_depth=100, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=100, score=0.162, total=   0.9s
# [CV] bootstrap=True, max_depth=100, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=100, score=0.213, total=   0.8s
# [CV] bootstrap=True, max_depth=100, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=100, score=0.173, total=   0.8s
# [CV] bootstrap=True, max_depth=100, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=100, score=0.153, total=   0.8s
# [CV] bootstrap=True, max_depth=100, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=100, score=0.240, total=   0.8s
# [CV] bootstrap=True, max_depth=100, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=500, score=0.198, total=   4.0s
# [CV] bootstrap=True, max_depth=100, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=500, score=0.178, total=   4.0s
# [CV] bootstrap=True, max_depth=100, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=500, score=0.198, total=   4.0s
# [CV] bootstrap=True, max_depth=100, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=500, score=0.158, total=   3.9s
# [CV] bootstrap=True, max_depth=100, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=500, score=0.250, total=   4.0s
# [CV] bootstrap=True, max_depth=100, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=100, n_estimators=1000, score=0.193, total=   8.4s
# [CV] bootstrap=True, max_depth=100, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=100, n_estimators=1000, score=0.168, total=   7.9s
# [CV] bootstrap=True, max_depth=100, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=100, n_estimators=1000, score=0.193, total=   8.0s
# [CV] bootstrap=True, max_depth=100, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=100, n_estimators=1000, score=0.179, total=   7.9s
# [CV] bootstrap=True, max_depth=100, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=100, n_estimators=1000, score=0.235, total=   8.7s
# [CV] bootstrap=True, max_depth=125, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=100, score=0.162, total=   0.8s
# [CV] bootstrap=True, max_depth=125, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=100, score=0.213, total=   0.8s
# [CV] bootstrap=True, max_depth=125, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=100, score=0.173, total=   0.7s
# [CV] bootstrap=True, max_depth=125, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=100, score=0.153, total=   0.8s
# [CV] bootstrap=True, max_depth=125, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=100, score=0.240, total=   0.8s
# [CV] bootstrap=True, max_depth=125, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=500, score=0.198, total=   3.9s
# [CV] bootstrap=True, max_depth=125, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=500, score=0.178, total=   4.0s
# [CV] bootstrap=True, max_depth=125, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=500, score=0.198, total=   4.0s
# [CV] bootstrap=True, max_depth=125, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=500, score=0.158, total=   4.7s
# [CV] bootstrap=True, max_depth=125, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=500, score=0.250, total=   4.2s
# [CV] bootstrap=True, max_depth=125, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=125, n_estimators=1000, score=0.193, total=   8.0s
# [CV] bootstrap=True, max_depth=125, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=125, n_estimators=1000, score=0.168, total=   7.9s
# [CV] bootstrap=True, max_depth=125, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=125, n_estimators=1000, score=0.193, total=   8.0s
# [CV] bootstrap=True, max_depth=125, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=125, n_estimators=1000, score=0.179, total=   8.0s
# [CV] bootstrap=True, max_depth=125, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=125, n_estimators=1000, score=0.235, total=   8.1s
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:  4.3min finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=1000, n_jobs=None,
#                                               oob_score=False, random_state=1,
#                                               verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'bootstrap': [True], 'max_depth': [20, 40, 100, 125],
#                          'n_estimators': [100, 500, 1000]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %% [markdown]
# Evaluate Model

# %%
#Print best parameter and score 

print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'bootstrap': True, 'max_depth': 40, 'n_estimators': 500}
# 0.19635346524396563

# %% [markdown]
# Use model to Predict World Series Champions

# %%
#Preprocess and predict 2015 MLB WS Champ
mlb_teams2015= pd.read_csv("data/2015.csv")

mlb2015_df = mlb_teams2015[['W', 'L', 'WPCT', 'WSWin', 'R', 'H', '2B',
       '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'SHO', 'SV', 'name']]

data2015_LG = mlb2015_df.copy()
data2015_bin = pd.get_dummies(data2015_LG, columns=["WSWin"])
data2015_bin = data2015_bin.drop(columns=['WSWin_N'])

feature2015 = data2015_bin.drop("name", axis=1)
team2015 = data2015_bin["name"]

X_feature2015_scaler = StandardScaler().fit(feature2015)
X_feature2015_scaled = X_feature2015_scaler.transform(feature2015)

predictions2015 = grid.predict(X_feature2015_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2015_scaled, team2015))
predictions2015 = rf.predict(X_feature2015_scaled)
print(predictions2015)
# Out:
# Test Acc: 0.029
# ['Toronto Blue Jays' 'Minnesota Twins' 'Detroit Tigers'
#  'Arizona Diamondbacks' 'Philadelphia Phillies' 'Florida Marlins'
#  'Oakland Athletics' 'Philadelphia Phillies' 'Colorado Rockies'
#  'Philadelphia Phillies' 'Toronto Blue Jays' 'Toronto Blue Jays'
#  'Houston Astros' 'Houston Astros' 'Kansas City Royals' 'Colorado Rockies'
#  'Arizona Diamondbacks' 'Houston Astros' 'Houston Astros'
#  'Pittsburgh Pirates' 'Kansas City Royals' 'New York Mets'
#  'Philadelphia Phillies' 'Toronto Blue Jays' 'Houston Astros'
#  'San Diego Padres' 'San Diego Padres' 'New York Mets' 'Atlanta Braves'
#  'Houston Astros' 'New York Yankees' 'New York Yankees' 'New York Yankees'
#  'New York Yankees' 'New York Yankees']

# %% [markdown]
# Evaluate Model

# %%
#Preprocess and predict 2016 MLB WS Champ
mlb_teams2016= pd.read_csv("data/2016.csv")

mlb2016_df = mlb_teams2016[['W', 'L', 'WPCT', 'WSWin', 'R', 'H', '2B',
       '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'SHO', 'SV', 'name']]

data2016_LG = mlb2016_df.copy()
data2016_bin = pd.get_dummies(data2016_LG, columns=["WSWin"])
data2016_bin = data2016_bin.drop(columns=['WSWin_N'])

feature2016 = data2016_bin.drop("name", axis=1)
team2016 = data2016_bin["name"]

X_feature2016_scaler = StandardScaler().fit(feature2016)
X_feature2016_scaled = X_feature2016_scaler.transform(feature2016)

predictions2016 = grid.predict(X_feature2016_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2016_scaled, team2016))
predictions2016 = rf.predict(X_feature2016_scaled)
print(predictions2016)
# Out:
# Test Acc: 0.086
# ['Colorado Rockies' 'Philadelphia Phillies' 'Oakland Athletics'
#  'Cincinnati Reds' 'Arizona Diamondbacks' 'New York Mets'
#  'Philadelphia Phillies' 'New York Mets' 'Colorado Rockies'
#  'Detroit Tigers' 'Philadelphia Phillies' 'Toronto Blue Jays'
#  'Florida Marlins' 'Houston Astros' 'Pittsburgh Pirates' 'Florida Marlins'
#  'Colorado Rockies' 'Houston Astros' 'Chicago White Sox' 'Minnesota Twins'
#  'Philadelphia Phillies' 'San Diego Padres' 'Florida Marlins'
#  'Pittsburgh Pirates' 'Houston Astros' 'Arizona Diamondbacks'
#  'Detroit Tigers' 'Chicago White Sox' 'Houston Astros' 'New York Mets'
#  'New York Yankees' 'New York Yankees' 'New York Yankees'
#  'New York Yankees' 'New York Yankees']

# %% [markdown]
# Predict World Series Champs

# %%
#Preprocess and predict 2017 MLB WS Champ
mlb_teams2017= pd.read_csv("data/2017.csv")

mlb2017_df = mlb_teams2017[['W', 'L', 'WPCT', 'WSWin', 'R', 'H', '2B',
       '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'SHO', 'SV', 'name']]

data2017_LG = mlb2017_df.copy()
data2017_bin = pd.get_dummies(data2017_LG, columns=["WSWin"])
data2017_bin = data2017_bin.drop(columns=['WSWin_N'])

feature2017 = data2017_bin.drop("name", axis=1)
team2017 = data2017_bin["name"]

X_feature2017_scaler = StandardScaler().fit(feature2017)
X_feature2017_scaled = X_feature2017_scaler.transform(feature2017)

predictions2017 = grid.predict(X_feature2017_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2017_scaled, team2017))
predictions2017 = rf.predict(X_feature2017_scaled)
print(predictions2017)
# Out:
# Test Acc: 0.029
# ['Philadelphia Phillies' 'Minnesota Twins' 'Toronto Blue Jays'
#  'New York Mets' 'New York Mets' 'Chicago Cubs' 'Detroit Tigers'
#  'Philadelphia Phillies' 'Arizona Diamondbacks' 'Colorado Rockies'
#  'Toronto Blue Jays' 'Oakland Athletics' 'Oakland Athletics'
#  'Houston Astros' 'Toronto Blue Jays' 'Houston Astros' 'New York Mets'
#  'Minnesota Twins' 'New York Mets' 'Cincinnati Reds' 'Pittsburgh Pirates'
#  'Pittsburgh Pirates' 'Philadelphia Phillies' 'Minnesota Twins'
#  'Chicago White Sox' 'New York Mets' 'San Diego Padres' 'Detroit Tigers'
#  'New York Yankees' 'Philadelphia Phillies' 'New York Yankees'
#  'New York Yankees' 'New York Yankees' 'New York Yankees'
#  'New York Yankees']

# %%
#Preprocess and predict 2018 MLB WS Champ
mlb_teams2018= pd.read_csv("data/2018.csv")

mlb2018_df = mlb_teams2018[['W', 'L', 'WPCT', 'WSWin', 'R', 'H', '2B',
       '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'SHO', 'SV', 'name']]

data2018_LG = mlb2018_df.copy()
data2018_bin = pd.get_dummies(data2018_LG, columns=["WSWin"])
data2018_bin = data2018_bin.drop(columns=['WSWin_N'])

feature2018 = data2018_bin.drop("name", axis=1)
team2018 = data2018_bin["name"]

X_feature2018_scaler = StandardScaler().fit(feature2018)
X_feature2018_scaled = X_feature2018_scaler.transform(feature2018)

predictions2018 = grid.predict(X_feature2018_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2018_scaled, team2018))
predictions2018 = rf.predict(X_feature2018_scaled)
print(predictions2018)
# Out:
# Test Acc: 0.029
# ['Philadelphia Phillies' 'Toronto Blue Jays' 'Baltimore Orioles'
#  'Toronto Blue Jays' 'Toronto Blue Jays' 'Toronto Blue Jays'
#  'Colorado Rockies' 'Houston Astros' 'Toronto Blue Jays'
#  'Kansas City Royals' 'New York Mets' 'Pittsburgh Pirates'
#  'Chicago White Sox' 'Philadelphia Phillies' 'Minnesota Twins'
#  'Toronto Blue Jays' 'Arizona Diamondbacks' 'Philadelphia Phillies'
#  'Houston Astros' 'Houston Astros' 'Philadelphia Phillies'
#  'Florida Marlins' 'Philadelphia Phillies' 'Philadelphia Phillies'
#  'Toronto Blue Jays' 'New York Yankees' 'Toronto Blue Jays'
#  'Detroit Tigers' 'Milwaukee Brewers' 'New York Mets' 'New York Yankees'
#  'New York Yankees' 'New York Yankees' 'New York Yankees'
#  'New York Yankees']

# %%
#Preprocess and predict 2019 MLB WS Champ
mlb2019_teams= pd.read_csv("data/MLB 2019 season.csv")

mlb2019_df = mlb2019_teams[['W', 'L', 'WPCT', 'WSWin', 'R', 'H', '2B',
       '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'SHO', 'SV', 'name']]

data2019_LG = mlb2019_df.copy()
data2019_bin = pd.get_dummies(data2019_LG, columns=["WSWin"])
data2019_bin = data2019_bin.drop(columns=['WSWin_N'])

feature2019 = data2019_bin.drop("name", axis=1)
team2019 = data2019_bin["name"]

X_feature2019_scaler = StandardScaler().fit(feature2019)
X_feature2019_scaled = X_feature2019_scaler.transform(feature2019)

predictions2019 = grid.predict(X_feature2019_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2019_scaled, team2019))
predictions2019 = rf.predict(X_feature2019_scaled)
print(predictions2019)
# Out:
# Test Acc: 0.143
# ['Toronto Blue Jays' 'New York Mets' 'Colorado Rockies' 'Cincinnati Reds'
#  'Chicago Cubs' 'Houston Astros' 'Philadelphia Phillies' 'New York Mets'
#  'Colorado Rockies' 'Kansas City Royals' 'Houston Astros'
#  'Kansas City Royals' 'Detroit Tigers' 'Houston Astros' 'Minnesota Twins'
#  'Philadelphia Phillies' 'Boston Red Sox' 'Houston Astros'
#  'Houston Astros' 'Houston Astros' 'Philadelphia Phillies'
#  'Kansas City Royals' 'Philadelphia Phillies' 'Colorado Rockies'
#  'Philadelphia Phillies' 'New York Mets' 'New York Mets'
#  'Toronto Blue Jays' 'Detroit Tigers' 'Toronto Blue Jays'
#  'New York Yankees' 'New York Yankees' 'New York Yankees'
#  'New York Yankees' 'New York Yankees']

# %%
#Preprocess and predict 2020 MLB WS Champ
mlb2020_teams= pd.read_csv("data/2020.csv")

mlb2020_df = mlb2020_teams[['W', 'L', 'WPCT', 'WSWin', 'R', 'H', '2B',
       '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'SHO', 'SV', 'name']]

data2020_LG = mlb2020_df.copy()
data2020_bin = pd.get_dummies(data2020_LG, columns=["WSWin"])
data2020_bin = data2020_bin.drop(columns=['WSWin_Y'])

feature2020 = data2020_bin.drop("name", axis=1)
team2020 = data2020_bin["name"]

X_feature2020_scaler = StandardScaler().fit(feature2020)
X_feature2020_scaled = X_feature2020_scaler.transform(feature2020)

predictions2020 = grid.predict(X_feature2020_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2020_scaled, team2020))
predictions2020 = rf.predict(X_feature2020_scaled)
print(predictions2020)
# Out:
# Test Acc: 0.000
# ['Pittsburgh Pirates' 'New York Yankees' 'Toronto Blue Jays'
#  'Minnesota Twins' 'Philadelphia Phillies' 'Atlanta Braves'
#  'Houston Astros' 'Houston Astros' 'Toronto Blue Jays' 'Toronto Blue Jays'
#  'Arizona Diamondbacks' 'Florida Marlins' 'Detroit Tigers'
#  'New York Yankees' 'Houston Astros' 'Cincinnati Reds' 'Baltimore Orioles'
#  'Detroit Tigers' 'San Francisco Giants' 'Philadelphia Phillies'
#  'Toronto Blue Jays' 'Chicago Cubs' 'Toronto Blue Jays' 'Colorado Rockies'
#  'Cincinnati Reds' 'Milwaukee Brewers' 'Philadelphia Phillies'
#  'Chicago Cubs' 'Chicago White Sox' 'Pittsburgh Pirates'
#  'New York Yankees' 'New York Yankees' 'New York Yankees'
#  'New York Yankees' 'New York Yankees']
