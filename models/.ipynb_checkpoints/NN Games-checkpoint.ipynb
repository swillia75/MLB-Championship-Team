# %%
#import numpy to use seed 
import numpy as np
import pandas as pd
from numpy.random import seed
np.random.seed(42)

# %%
#import other dependencies

import os
import tensorflow 
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense

# %% [markdown]
# Read CSV create, and clean dataframe

# %%
#Read in CSV and create dataframe
mlb_teams= pd.read_csv("data/Teams.csv")
mlb_teams = mlb_teams.dropna()
mlb_teams
# Out:
#       yearID lgID      G   G.1     W     L  WPCT WSWin      R      AB  ...  \
# 0     2004.0   AL  162.0  81.0  92.0  70.0  0.36     N  836.0  5675.0  ...
# 1     2003.0   AL  162.0  82.0  77.0  85.0  0.48     N  736.0  5487.0  ...
# 2     2002.0   AL  162.0  81.0  99.0  63.0  0.54     Y  851.0  5678.0  ...
# 3     2001.0   AL  162.0  81.0  75.0  87.0  0.48     N  691.0  5551.0  ...
# 4     2000.0   AL  162.0  81.0  82.0  80.0  0.46     N  864.0  5628.0  ...
# ...      ...  ...    ...   ...   ...   ...   ...   ...    ...     ...  ...
# 1224  2006.0   NL  162.0  81.0  71.0  91.0  0.50     N  746.0  5495.0  ...
# 1225  2005.0   NL  162.0  81.0  81.0  81.0  0.51     N  639.0  5426.0  ...
# 1226  1971.0   AL  159.0  81.0  63.0  96.0  0.43     N  537.0  5290.0  ...
# 1227  1970.0   AL  162.0  81.0  70.0  92.0  0.46     N  626.0  5460.0  ...
# 1228  1969.0   AL  162.0  81.0  86.0  76.0  0.49     N  694.0  5447.0  ...
#
#         3B     HR     BB      SO     SB   ERA    CG   SHO    SV  \
# 0     37.0  162.0  450.0   942.0  143.0  4.28   2.0  11.0  50.0
# 1     33.0  150.0  476.0   838.0  129.0  4.28   5.0   9.0  39.0
# 2     32.0  152.0  462.0   805.0  117.0  3.69   7.0  14.0  54.0
# 3     26.0  158.0  494.0  1001.0  116.0  4.20   6.0   1.0  43.0
# 4     34.0  236.0  608.0  1024.0   93.0  5.00   5.0   3.0  46.0
# ...    ...    ...    ...     ...    ...   ...   ...   ...   ...
# 1224  22.0  164.0  594.0  1156.0  123.0  5.03   1.0   3.0  32.0
# 1225  32.0  117.0  491.0  1090.0   45.0  3.87   4.0   9.0  51.0
# 1226  30.0   86.0  575.0   956.0   68.0  3.70  30.0  10.0  26.0
# 1227  28.0  138.0  635.0   989.0   72.0  3.80  20.0  11.0  40.0
# 1228  40.0  148.0  630.0   900.0   52.0  3.49  28.0  10.0  41.0
#
#                       name
# 0           Anaheim Angels
# 1           Anaheim Angels
# 2           Anaheim Angels
# 3           Anaheim Angels
# 4           Anaheim Angels
# ...                    ...
# 1224  Washington Nationals
# 1225  Washington Nationals
# 1226   Washington Senators
# 1227   Washington Senators
# 1228   Washington Senators
#
# [1229 rows x 22 columns]

# %%
#Get list of dataframe columns

mlb_teams.columns
# Out:
# Index(['yearID', 'lgID', 'G', 'G.1', 'W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H',
#        '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV', 'name'],
#       dtype='object')

# %%
#Select columns for dataframe


mlb_df = mlb_teams[['W', 'L', 'WPCT', 'R', 'H', '2B',
       '3B', 'HR', 'BB', 'SB', 'ERA', 'SHO', 'SV', 'name']]
mlb_df.head(20)
# Out:
#        W      L  WPCT      R       H     2B    3B     HR     BB     SB   ERA  \
# 0   92.0   70.0  0.36  836.0  1603.0  272.0  37.0  162.0  450.0  143.0  4.28
# 1   77.0   85.0  0.48  736.0  1473.0  276.0  33.0  150.0  476.0  129.0  4.28
# 2   99.0   63.0  0.54  851.0  1603.0  333.0  32.0  152.0  462.0  117.0  3.69
# 3   75.0   87.0  0.48  691.0  1447.0  275.0  26.0  158.0  494.0  116.0  4.20
# 4   82.0   80.0  0.46  864.0  1574.0  309.0  34.0  236.0  608.0   93.0  5.00
# 5   70.0   92.0  0.53  711.0  1404.0  248.0  22.0  158.0  511.0   71.0  4.79
# 6   85.0   77.0  0.46  787.0  1530.0  314.0  27.0  147.0  510.0   93.0  4.49
# 7   84.0   78.0  0.45  829.0  1531.0  279.0  25.0  161.0  617.0  126.0  4.52
# 8   64.0   98.0  0.57  615.0  1379.0  259.0  47.0  118.0  398.0   86.0  4.26
# 9   81.0   81.0  0.47  685.0  1468.0  302.0  31.0  130.0  519.0   62.0  3.92
# 10  81.0   81.0  0.43  734.0  1416.0  307.0  33.0  165.0  539.0   93.0  3.93
# 11  94.0   68.0  0.62  731.0  1357.0  293.0  37.0  172.0  531.0  133.0  3.80
# 12  65.0   97.0  0.56  713.0  1366.0  301.0  34.0  180.0  589.0   86.0  4.81
# 13  70.0   92.0  0.50  720.0  1408.0  307.0  45.0  173.0  571.0  102.0  4.42
# 14  82.0   80.0  0.41  720.0  1355.0  318.0  47.0  159.0  587.0   58.0  3.98
# 15  90.0   72.0  0.59  712.0  1350.0  286.0  40.0  171.0  532.0  109.0  4.13
# 16  76.0   86.0  0.43  773.0  1506.0  331.0  38.0  160.0  504.0   76.0  4.48
# 17  77.0   85.0  0.62  696.0  1419.0  291.0  27.0  191.0  606.0   67.0  4.84
# 18  51.0  111.0  0.61  615.0  1401.0  295.0  38.0  135.0  441.0   53.0  4.98
# 19  84.0   78.0  0.56  717.0  1467.0  303.0  47.0  152.0  531.0   76.0  3.84
#
#      SHO    SV                  name
# 0   11.0  50.0        Anaheim Angels
# 1    9.0  39.0        Anaheim Angels
# 2   14.0  54.0        Anaheim Angels
# 3    1.0  43.0        Anaheim Angels
# 4    3.0  46.0        Anaheim Angels
# 5    7.0  37.0        Anaheim Angels
# 6    5.0  52.0        Anaheim Angels
# 7    5.0  39.0        Anaheim Angels
# 8    4.0  35.0  Arizona Diamondbacks
# 9    7.0  38.0  Arizona Diamondbacks
# 10   9.0  39.0  Arizona Diamondbacks
# 11  12.0  58.0  Arizona Diamondbacks
# 12   3.0  35.0  Arizona Diamondbacks
# 13  12.0  36.0  Arizona Diamondbacks
# 14   9.0  39.0  Arizona Diamondbacks
# 15  12.0  51.0  Arizona Diamondbacks
# 16   9.0  34.0  Arizona Diamondbacks
# 17  10.0  45.0  Arizona Diamondbacks
# 18   6.0  33.0  Arizona Diamondbacks
# 19  11.0  42.0  Arizona Diamondbacks

# %%
#Use getdummies to convert strings

data_LG = mlb_df.copy()
data_bin = pd.get_dummies(data_LG, columns=["name"])
data_bin = data_bin.drop(columns=['WSWin_N'])

data_bin.head()
# Out:
#       W     L  WPCT      R       H     2B    3B     HR     BB     SB   ERA  \
# 0  92.0  70.0  0.36  836.0  1603.0  272.0  37.0  162.0  450.0  143.0  4.28
# 1  77.0  85.0  0.48  736.0  1473.0  276.0  33.0  150.0  476.0  129.0  4.28
# 2  99.0  63.0  0.54  851.0  1603.0  333.0  32.0  152.0  462.0  117.0  3.69
# 3  75.0  87.0  0.48  691.0  1447.0  275.0  26.0  158.0  494.0  116.0  4.20
# 4  82.0  80.0  0.46  864.0  1574.0  309.0  34.0  236.0  608.0   93.0  5.00
#
#     SHO    SV            name  WSWin_Y
# 0  11.0  50.0  Anaheim Angels        0
# 1   9.0  39.0  Anaheim Angels        0
# 2  14.0  54.0  Anaheim Angels        1
# 3   1.0  43.0  Anaheim Angels        0
# 4   3.0  46.0  Anaheim Angels        0

# %%
#Set X(data) and y(team)variables

data = data_bin.drop(["W"], axis=1)
outcome = data_bin["W"]
                   
                   
                   
                   
                   

print(data.shape, outcome.shape)
# Out:
# (1229, 14) (1229,)

# %%
outcome.unique()
# Out:
# array([ 92.,  77.,  99.,  75.,  82.,  70.,  85.,  84.,  64.,  81.,  94.,
#         65.,  90.,  76.,  51.,  98., 100.,  79.,  96.,  89.,  91.,  86.,
#         72., 101.,  88.,  95., 103., 106., 104.,  63.,  54.,  69.,  66.,
#         80.,  50.,  61.,  67.,  93.,  68.,  74.,  78.,  71.,  87.,  73.,
#         83.,  59., 102.,  97., 108., 109.,  38.,  56.,  57.,  60.,  52.,
#         62.,  43.,  55.,  53.,  58.,  41., 114.,  46., 116.,  44., 105.,
#         37.])

# %% [markdown]
# Preprocess data

# %%
#Import SciKit libraries

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from tensorflow.keras.utils import to_categorical

# %%
#Split data and teams into training and test data

X_train, X_test, y_train, y_test = train_test_split(data, outcome, train_size=0.6, test_size=0.4, random_state=1)
X_train
# Out:
#           L  WPCT      R       H     2B    3B     HR     BB     SB   ERA  \
# 959    98.0  0.46  678.0  1442.0  257.0  32.0  128.0  565.0   76.0  4.87
# 990   100.0  0.44  486.0  1250.0  184.0  31.0   96.0  438.0   70.0  3.22
# 474    87.0  0.48  573.0  1301.0  209.0  32.0   94.0  548.0  179.0  3.61
# 1051   46.0  0.60  927.0  1637.0  310.0  38.0  169.0  614.0  174.0  3.54
# 472    81.0  0.64  608.0  1350.0  255.0  38.0   96.0  506.0  139.0  3.72
# ...     ...   ...    ...     ...    ...   ...    ...    ...    ...   ...
# 715   107.0  0.60  531.0  1275.0  224.0  32.0   94.0  433.0   86.0  3.99
# 905    83.0  0.49  651.0  1313.0  241.0  37.0  170.0  444.0   73.0  3.86
# 1096   79.0  0.44  631.0  1464.0  262.0  44.0   94.0  495.0  208.0  3.38
# 235    83.0  0.47  654.0  1387.0  252.0  16.0  154.0  475.0   81.0  4.10
# 1061   85.0  0.47  640.0  1419.0  251.0  26.0  107.0  596.0  105.0  3.69
#
#        SHO    SV                 name  WSWin_Y
# 959   10.0  31.0     San Diego Padres        0
# 990   10.0  17.0     San Diego Padres        0
# 474    6.0  37.0       Houston Astros        0
# 1051  14.0  56.0     Seattle Mariners        0
# 472   12.0  45.0       Houston Astros        0
# ...    ...   ...                  ...      ...
# 715   10.0  21.0       Montreal Expos        0
# 905   10.0  45.0   Pittsburgh Pirates        0
# 1096   9.0  47.0  St. Louis Cardinals        0
# 235   14.0  42.0    Chicago White Sox        0
# 1061   7.0  41.0     Seattle Mariners        0
#
# [737 rows x 14 columns]

# %%
#Scale data using StandardScaler

X_scaler = StandardScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
X_train_scaled
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-4c5c4827accc> in <module>
#       1 #Scale data using StandardScaler
#       2
# ----> 3 X_scaler = StandardScaler().fit(X_train)
#       4 X_train_scaled = X_scaler.transform(X_train)
#       5 X_test_scaled = X_scaler.transform(X_test)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y)
#     667         # Reset internal state before fitting
#     668         self._reset()
# --> 669         return self.partial_fit(X, y)
#     670
#     671     def partial_fit(self, X, y=None):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\preprocessing\_data.py in partial_fit(self, X, y)
#     698         X = check_array(X, accept_sparse=('csr', 'csc'),
#     699                         estimator=self, dtype=FLOAT_DTYPES,
# --> 700                         force_all_finite='allow-nan')
#     701
#     702         # Even in the case of `with_mean=False`, we update the mean anyway
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     529                     array = array.astype(dtype, casting="unsafe", copy=False)
#     530                 else:
# --> 531                     array = np.asarray(array, order=order, dtype=dtype)
#     532             except ComplexWarning:
#     533                 raise ValueError("Complex data not supported\n"
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: could not convert string to float: 'San Diego Padres'

# %%
#Label-encode team

label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)
encoded_y_train
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-646a59b71a40> in <module>
#       4 label_encoder.fit(y_train)
#       5 encoded_y_train = label_encoder.transform(y_train)
# ----> 6 encoded_y_test = label_encoder.transform(y_test)
#       7 encoded_y_train
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\preprocessing\_label.py in transform(self, y)
#     271             return np.array([])
#     272
# --> 273         _, y = _encode(y, uniques=self.classes_, encode=True)
#     274         return y
#     275
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\preprocessing\_label.py in _encode(values, uniques, encode, check_unknown)
#     116     else:
#     117         return _encode_numpy(values, uniques, encode,
# --> 118                              check_unknown=check_unknown)
#     119
#     120
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\preprocessing\_label.py in _encode_numpy(values, uniques, encode, check_unknown)
#      48             if diff:
#      49                 raise ValueError("y contains previously unseen labels: %s"
# ---> 50                                  % str(diff))
#      51         encoded = np.searchsorted(uniques, values)
#      52         return uniques, encoded
#
# ValueError: y contains previously unseen labels: [106.0]

# %%
#One hot_encode the team data

y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)
for x in y_test_categorical:
    print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-aa7144df040e> in <module>
#       2
#       3 y_train_categorical = to_categorical(encoded_y_train)
# ----> 4 y_test_categorical = to_categorical(encoded_y_test)
#       5 for x in y_test_categorical:
#       6     print(x)
#
# NameError: name 'encoded_y_test' is not defined

# %% [markdown]
# Create Neural Network Model

# %%
# Create model and add layers
model = Sequential()
model.add(Dense(100, input_dim=14, activation='relu'))

model.add(Dense(36, activation='softmax'))

# %%
#View model summary

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               1500
# _________________________________________________________________
# dense_1 (Dense)              (None, 36)                3636
# =================================================================
# Total params: 5,136
# Trainable params: 5,136
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Train Model

# %%
#Compile model
model.compile(optimizer="adam",
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
print(len(y_train_categorical))
# Out:
# 737

# %%
#Fit data to train model

model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
# 24/24 - 0s - loss: 0.1283 - accuracy: 0.0312
# Epoch 2/100
# 24/24 - 0s - loss: 0.1233 - accuracy: 0.0773
# Epoch 3/100
# 24/24 - 0s - loss: 0.1199 - accuracy: 0.1194
# Epoch 4/100
# 24/24 - 0s - loss: 0.1172 - accuracy: 0.1493
# Epoch 5/100
# 24/24 - 0s - loss: 0.1150 - accuracy: 0.1465
# Epoch 6/100
# 24/24 - 0s - loss: 0.1130 - accuracy: 0.1791
# Epoch 7/100
# 24/24 - 0s - loss: 0.1114 - accuracy: 0.1900
# Epoch 8/100
# 24/24 - 0s - loss: 0.1099 - accuracy: 0.1981
# Epoch 9/100
# 24/24 - 0s - loss: 0.1085 - accuracy: 0.2049
# Epoch 10/100
# 24/24 - 0s - loss: 0.1072 - accuracy: 0.2090
# Epoch 11/100
# 24/24 - 0s - loss: 0.1061 - accuracy: 0.2280
# Epoch 12/100
# 24/24 - 0s - loss: 0.1049 - accuracy: 0.2334
# Epoch 13/100
# 24/24 - 0s - loss: 0.1039 - accuracy: 0.2347
# Epoch 14/100
# 24/24 - 0s - loss: 0.1030 - accuracy: 0.2347
# Epoch 15/100
# 24/24 - 0s - loss: 0.1022 - accuracy: 0.2361
# Epoch 16/100
# 24/24 - 0s - loss: 0.1013 - accuracy: 0.2429
# Epoch 17/100
# 24/24 - 0s - loss: 0.1005 - accuracy: 0.2510
# Epoch 18/100
# 24/24 - 0s - loss: 0.0996 - accuracy: 0.2592
# Epoch 19/100
# 24/24 - 0s - loss: 0.0988 - accuracy: 0.2605
# Epoch 20/100
# 24/24 - 0s - loss: 0.0981 - accuracy: 0.2673
# Epoch 21/100
# 24/24 - 0s - loss: 0.0973 - accuracy: 0.2741
# Epoch 22/100
# 24/24 - 0s - loss: 0.0967 - accuracy: 0.2795
# Epoch 23/100
# 24/24 - 0s - loss: 0.0960 - accuracy: 0.2849
# Epoch 24/100
# 24/24 - 0s - loss: 0.0955 - accuracy: 0.2863
# Epoch 25/100
# 24/24 - 0s - loss: 0.0949 - accuracy: 0.2836
# Epoch 26/100
# 24/24 - 0s - loss: 0.0942 - accuracy: 0.2999
# Epoch 27/100
# 24/24 - 0s - loss: 0.0936 - accuracy: 0.3053
# Epoch 28/100
# 24/24 - 0s - loss: 0.0931 - accuracy: 0.2931
# Epoch 29/100
# 24/24 - 0s - loss: 0.0926 - accuracy: 0.3012
# Epoch 30/100
# 24/24 - 0s - loss: 0.0922 - accuracy: 0.3107
# Epoch 31/100
# 24/24 - 0s - loss: 0.0916 - accuracy: 0.3080
# Epoch 32/100
# 24/24 - 0s - loss: 0.0911 - accuracy: 0.3107
# Epoch 33/100
# 24/24 - 0s - loss: 0.0906 - accuracy: 0.3229
# Epoch 34/100
# 24/24 - 0s - loss: 0.0901 - accuracy: 0.3161
# Epoch 35/100
# 24/24 - 0s - loss: 0.0897 - accuracy: 0.3216
# Epoch 36/100
# 24/24 - 0s - loss: 0.0893 - accuracy: 0.3338
# Epoch 37/100
# 24/24 - 0s - loss: 0.0887 - accuracy: 0.3351
# Epoch 38/100
# 24/24 - 0s - loss: 0.0883 - accuracy: 0.3311
# Epoch 39/100
# 24/24 - 0s - loss: 0.0880 - accuracy: 0.3351
# Epoch 40/100
# 24/24 - 0s - loss: 0.0876 - accuracy: 0.3351
# Epoch 41/100
# 24/24 - 0s - loss: 0.0873 - accuracy: 0.3324
# Epoch 42/100
# 24/24 - 0s - loss: 0.0868 - accuracy: 0.3460
# Epoch 43/100
# 24/24 - 0s - loss: 0.0864 - accuracy: 0.3446
# Epoch 44/100
# 24/24 - 0s - loss: 0.0859 - accuracy: 0.3446
# Epoch 45/100
# 24/24 - 0s - loss: 0.0855 - accuracy: 0.3474
# Epoch 46/100
# 24/24 - 0s - loss: 0.0849 - accuracy: 0.3582
# Epoch 47/100
# 24/24 - 0s - loss: 0.0846 - accuracy: 0.3609
# Epoch 48/100
# 24/24 - 0s - loss: 0.0843 - accuracy: 0.3636
# Epoch 49/100
# 24/24 - 0s - loss: 0.0839 - accuracy: 0.3569
# Epoch 50/100
# 24/24 - 0s - loss: 0.0835 - accuracy: 0.3758
# Epoch 51/100
# 24/24 - 0s - loss: 0.0832 - accuracy: 0.3691
# Epoch 52/100
# 24/24 - 0s - loss: 0.0828 - accuracy: 0.3691
# Epoch 53/100
# 24/24 - 0s - loss: 0.0824 - accuracy: 0.3677
# Epoch 54/100
# 24/24 - 0s - loss: 0.0821 - accuracy: 0.3881
# Epoch 55/100
# 24/24 - 0s - loss: 0.0816 - accuracy: 0.3813
# Epoch 56/100
# 24/24 - 0s - loss: 0.0814 - accuracy: 0.3840
# Epoch 57/100
# 24/24 - 0s - loss: 0.0810 - accuracy: 0.3908
# Epoch 58/100
# 24/24 - 0s - loss: 0.0807 - accuracy: 0.3826
# Epoch 59/100
# 24/24 - 0s - loss: 0.0803 - accuracy: 0.3948
# Epoch 60/100
# 24/24 - 0s - loss: 0.0801 - accuracy: 0.3976
# Epoch 61/100
# 24/24 - 0s - loss: 0.0798 - accuracy: 0.3881
# Epoch 62/100
# 24/24 - 0s - loss: 0.0794 - accuracy: 0.4071
# Epoch 63/100
# 24/24 - 0s - loss: 0.0790 - accuracy: 0.4098
# Epoch 64/100
# 24/24 - 0s - loss: 0.0788 - accuracy: 0.4030
# Epoch 65/100
# 24/24 - 0s - loss: 0.0784 - accuracy: 0.4138
# Epoch 66/100
# 24/24 - 0s - loss: 0.0783 - accuracy: 0.4098
# Epoch 67/100
# 24/24 - 0s - loss: 0.0780 - accuracy: 0.4084
# Epoch 68/100
# 24/24 - 0s - loss: 0.0776 - accuracy: 0.4220
# Epoch 69/100
# 24/24 - 0s - loss: 0.0772 - accuracy: 0.4328
# Epoch 70/100
# 24/24 - 0s - loss: 0.0769 - accuracy: 0.4328
# Epoch 71/100
# 24/24 - 0s - loss: 0.0769 - accuracy: 0.4301
# Epoch 72/100
# 24/24 - 0s - loss: 0.0763 - accuracy: 0.4396
# Epoch 73/100
# 24/24 - 0s - loss: 0.0764 - accuracy: 0.4315
# Epoch 74/100
# 24/24 - 0s - loss: 0.0762 - accuracy: 0.4315
# Epoch 75/100
# 24/24 - 0s - loss: 0.0758 - accuracy: 0.4315
# Epoch 76/100
# 24/24 - 0s - loss: 0.0754 - accuracy: 0.4410
# Epoch 77/100
# 24/24 - 0s - loss: 0.0751 - accuracy: 0.4491
# Epoch 78/100
# 24/24 - 0s - loss: 0.0747 - accuracy: 0.4491
# Epoch 79/100
# 24/24 - 0s - loss: 0.0744 - accuracy: 0.4613
# Epoch 80/100
# 24/24 - 0s - loss: 0.0741 - accuracy: 0.4627
# Epoch 81/100
# 24/24 - 0s - loss: 0.0739 - accuracy: 0.4586
# Epoch 82/100
# 24/24 - 0s - loss: 0.0736 - accuracy: 0.4695
# Epoch 83/100
# 24/24 - 0s - loss: 0.0733 - accuracy: 0.4790
# Epoch 84/100
# 24/24 - 0s - loss: 0.0733 - accuracy: 0.4681
# Epoch 85/100
# 24/24 - 0s - loss: 0.0730 - accuracy: 0.4668
# Epoch 86/100
# 24/24 - 0s - loss: 0.0727 - accuracy: 0.4790
# Epoch 87/100
# 24/24 - 0s - loss: 0.0723 - accuracy: 0.4844
# Epoch 88/100
# 24/24 - 0s - loss: 0.0722 - accuracy: 0.4898
# Epoch 89/100
# 24/24 - 0s - loss: 0.0722 - accuracy: 0.4776
# Epoch 90/100
# 24/24 - 0s - loss: 0.0717 - accuracy: 0.4966
# Epoch 91/100
# 24/24 - 0s - loss: 0.0714 - accuracy: 0.4966
# Epoch 92/100
# 24/24 - 0s - loss: 0.0712 - accuracy: 0.4871
# Epoch 93/100
# 24/24 - 0s - loss: 0.0709 - accuracy: 0.4844
# Epoch 94/100
# 24/24 - 0s - loss: 0.0710 - accuracy: 0.4830
# Epoch 95/100
# 24/24 - 0s - loss: 0.0705 - accuracy: 0.4939
# Epoch 96/100
# 24/24 - 0s - loss: 0.0704 - accuracy: 0.4898
# Epoch 97/100
# 24/24 - 0s - loss: 0.0701 - accuracy: 0.5007
# Epoch 98/100
# 24/24 - 0s - loss: 0.0697 - accuracy: 0.4980
# Epoch 99/100
# 24/24 - 0s - loss: 0.0695 - accuracy: 0.4966
# Epoch 100/100
# 24/24 - 0s - loss: 0.0692 - accuracy: 0.4980

# %% [markdown]
# Evaluate Model

# %%
#Evaluate model

model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(f"Deep Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 16/16 - 0s - loss: 0.1215 - accuracy: 0.1545
# Deep Neural Network - Loss: 0.12147093564271927, Accuracy: 0.15447154641151428

# %%
#Preprocess and predict 2015 MLB WS Champ
mlb_teams2015= pd.read_csv("data/2015.csv")

mlb2015_df = mlb_teams2015[['W', 'L', 'WPCT', 'WSWin', 'R', 'H', '2B',
       '3B', 'HR', 'BB', 'SB', 'ERA', 'SHO', 'SV', 'name']]


data2015_LG = mlb2015_df.copy()
data2015_bin = pd.get_dummies(data2015_LG, columns=["WSWin"])
data2015_bin = data2015_bin.drop(columns=['WSWin_N'])

feature2015 = data2015_bin.drop("name", axis=1)
team2015 = data2015_bin["name"]


X_feature2015_scaler = StandardScaler().fit(feature2015)
X_feature2015_scaled = X_feature2015_scaler.transform(feature2015)

label2015_encoder = LabelEncoder()
label2015_encoder.fit(team2015)
encoded_y_2015 = label2015_encoder.transform(team2015)

y_2015_categorical = to_categorical(encoded_y_2015)

encoded_predictions2015 = model.predict_classes(X_feature2015_scaled[:10])
prediction2015_labels = label2015_encoder.inverse_transform(encoded_predictions2015)

print(f"Predicted classes: {prediction2015_labels}")
# Out:
# WARNING:tensorflow:From <ipython-input-21-26256bb4673e>:25: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# Predicted classes: ['Kansas City Royals' 'San Diego Padres' 'Chicago Cubs' 'Florida Marlins'
#  'Cincinnati Reds' 'Minnesota Twins' 'Cincinnati Reds'
#  'Philadelphia Phillies' 'Colorado Rockies' 'Colorado Rockies']

# %%
#Preprocess and predict 2016 MLB WS Champ
mlb_teams2016= pd.read_csv("data/2016.csv")

mlb2016_df = mlb_teams2016[['W', 'L', 'WPCT', 'WSWin', 'R', 'H', '2B',
       '3B', 'HR', 'BB', 'SB', 'ERA', 'SHO', 'SV', 'name']]

data2016_LG = mlb2016_df.copy()
data2016_bin = pd.get_dummies(data2016_LG, columns=["WSWin"])
data2016_bin = data2016_bin.drop(columns=['WSWin_N'])

feature2016 = data2016_bin.drop("name", axis=1)
team2016 = data2016_bin["name"]

X_feature2016_scaler = StandardScaler().fit(feature2016)
X_feature2016_scaled = X_feature2016_scaler.transform(feature2016)

label2016_encoder = LabelEncoder()
label2016_encoder.fit(team2016)
encoded_y_2016 = label2015_encoder.transform(team2016)
encoded_y_2016
y_2016_categorical = to_categorical(encoded_y_2016)


encoded_predictions2016 = model.predict_classes(X_feature2016_scaled[:10])
prediction2016_labels = label2016_encoder.inverse_transform(encoded_predictions2016)

print(f"Predicted classes: {prediction2016_labels}")
# Out:
# Predicted classes: ['Kansas City Royals' 'Florida Marlins' 'Chicago Cubs'
#  'Philadelphia Phillies' 'Florida Marlins' 'Florida Marlins'
#  'Kansas City Royals' 'Cincinnati Reds' 'Colorado Rockies'
#  'Chicago White Sox']

# %%
#Preprocess and predict 2017 MLB WS Champ
mlb_teams2017= pd.read_csv("data/2017.csv")

mlb2017_df = mlb_teams2017[['W', 'L', 'WPCT', 'WSWin', 'R', 'H', '2B',
       '3B', 'HR', 'BB', 'SB', 'ERA', 'SHO', 'SV', 'name']]

data2017_LG = mlb2017_df.copy()
data2017_bin = pd.get_dummies(data2017_LG, columns=["WSWin"])
data2017_bin = data2017_bin.drop(columns=['WSWin_N',])

feature2017 = data2017_bin.drop("name", axis=1)
team2017 = data2017_bin["name"]

X_feature2017_scaler = StandardScaler().fit(feature2017)
X_feature2017_scaled = X_feature2017_scaler.transform(feature2017)

label2017_encoder = LabelEncoder()
label2017_encoder.fit(team2017)
encoded_y_2017 = label2017_encoder.transform(team2017)

y_2017_categorical = to_categorical(encoded_y_2017)




encoded_predictions2017 = model.predict_classes(X_feature2017_scaled[:10])
prediction2017_labels = label2017_encoder.inverse_transform(encoded_predictions2017)

print(f"Predicted classes: {prediction2017_labels}")
# Out:
# Predicted classes: ['Toronto Blue Jays' 'Minnesota Twins' 'Chicago White Sox'
#  'Cincinnati Reds' 'Philadelphia Phillies' 'Kansas City Royals'
#  'Kansas City Royals' 'Toronto Blue Jays' 'Toronto Blue Jays'
#  'Arizona Diamondbacks']

# %%
#Preprocess and predict 2018 MLB WS Champ
mlb_teams2018= pd.read_csv("data/2018.csv")

mlb2018_df = mlb_teams2018[['W', 'L', 'WPCT', 'WSWin', 'R', 'H', '2B',
       '3B', 'HR', 'BB', 'SB', 'ERA', 'SHO', 'SV', 'name']]

data2018_LG = mlb2018_df.copy()
data2018_bin = pd.get_dummies(data2018_LG, columns=["WSWin"])
data2018_bin = data2018_bin.drop(columns=['WSWin_N',])

feature2018 = data2018_bin.drop("name", axis=1)
team2018 = data2018_bin["name"]

X_feature2018_scaler = StandardScaler().fit(feature2018)
X_feature2018_scaled = X_feature2018_scaler.transform(feature2018)

label2018_encoder = LabelEncoder()
label2018_encoder.fit(team2018)
encoded_y_2018 = label2018_encoder.transform(team2018)

y_2018_categorical = to_categorical(encoded_y_2018)




encoded_predictions2018 = model.predict_classes(X_feature2018_scaled[:10])
prediction2018_labels = label2018_encoder.inverse_transform(encoded_predictions2018)

print(f"Predicted classes: {prediction2018_labels}")
# Out:
# Predicted classes: ['Philadelphia Phillies' 'Toronto Blue Jays' 'Tampa Bay Devil Rays'
#  'Florida Marlins' 'Boston Red Sox' 'Kansas City Royals'
#  'Cleveland Indians' 'Cincinnati Reds' 'Toronto Blue Jays'
#  'Minnesota Twins']

# %%
#Preprocess and predict 2019 MLB WS Champ
mlb2019_teams= pd.read_csv("data/MLB 2019 season.csv")



mlb2019_df = mlb2019_teams[['W', 'L', 'WPCT', 'WSWin', 'R', 'H', '2B',
       '3B', 'HR', 'BB', 'SB', 'ERA', 'SHO', 'SV', 'name']]


data2019_LG = mlb2019_df.copy()
data2019_bin = pd.get_dummies(data2019_LG, columns=["WSWin"])
data2019_bin = data2019_bin.drop(columns=['WSWin_N'])



feature2019 = data2019_bin.drop("name", axis=1)
team2019 = data2019_bin["name"]


X_feature2019_scaler = StandardScaler().fit(feature2019)
X_feature2019_scaled = X_feature2019_scaler.transform(feature2019)


label_team_encoder2019 = LabelEncoder()
label_team_encoder2019.fit(team2019)
encoded_y_team2019 = label_team_encoder2019.transform(team2019)


y_team2019_categorical = to_categorical(encoded_y_team2019)

encoded_predictions2019 = model.predict_classes(feature2019)
prediction2019_labels = label_team_encoder2019.inverse_transform(encoded_predictions2019)

print(f"Predicted classes: {prediction2019_labels}")
# Out:
# Predicted classes: ['Boston Red Sox' 'Boston Red Sox' 'Boston Red Sox' 'Boston Red Sox'
#  'Boston Red Sox' 'Boston Red Sox' 'Boston Red Sox' 'Boston Red Sox'
#  'Boston Red Sox' 'Boston Red Sox' 'Boston Red Sox' 'Boston Red Sox'
#  'Boston Red Sox' 'Boston Red Sox' 'Boston Red Sox' 'Boston Red Sox'
#  'Boston Red Sox' 'Boston Red Sox' 'Boston Red Sox' 'Boston Red Sox'
#  'Boston Red Sox' 'Boston Red Sox' 'Boston Red Sox' 'Boston Red Sox'
#  'Boston Red Sox' 'Boston Red Sox' 'Boston Red Sox' 'Boston Red Sox'
#  'Boston Red Sox' 'Boston Red Sox' 'Minnesota Twins' 'Minnesota Twins'
#  'Minnesota Twins' 'Minnesota Twins' 'Minnesota Twins']

# %%
#Preprocess and predict 2020 MLB WS Champ
mlb2020_teams= pd.read_csv("data/2020.csv")

mlb2020_df = mlb2020_teams[['W', 'L', 'WPCT', 'WSWin', 'R', 'H', '2B',
       '3B', 'HR', 'BB', 'SB', 'ERA', 'SHO', 'SV', 'name']]

data2020_LG = mlb2020_df.copy()
data2020_bin = pd.get_dummies(data2020_LG, columns=["WSWin"])
data2020_bin = data2020_bin.drop(columns=['WSWin_Y'])

feature2020 = data2020_bin.drop("name", axis=1)
team2020 = data2020_bin["name"]



X_feature2020_scaler = StandardScaler().fit(feature2020)
X_feature2020_scaled = X_feature2020_scaler.transform(feature2020)


label_team_encoder2020 = LabelEncoder()
label_team_encoder2020.fit(team2020)
encoded_y_team2020 = label_team_encoder2020.transform(team2020)


y_team2020_categorical = to_categorical(encoded_y_team2020)

encoded_predictions2020 = model.predict_classes(X_feature2020_scaled[:10])
prediction2020_labels = label2018_encoder.inverse_transform(encoded_predictions2020)

print(f"Predicted classes: {prediction2020_labels}")
# Out:
# Predicted classes: ['Toronto Blue Jays' 'Oakland Athletics' 'Chicago Cubs' 'Florida Marlins'
#  'San Diego Padres' 'Texas Rangers' 'Oakland Athletics' 'Cincinnati Reds'
#  'Kansas City Royals' 'Toronto Blue Jays']

# %% [markdown]
# Predict World Series Champs

# %%
model.save("saved_models/mlb_trained.h5")
