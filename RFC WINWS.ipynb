# %%
#import numpy to use seed 
import numpy as np
import pandas as pd
from numpy.random import seed
np.random.seed(1)

# %% [markdown]
# Read CSV create, and clean dataframe

# %%
#Read in CSV and create dataframe
mlb_teams= pd.read_csv("Teams.csv")
mlb_teams = mlb_teams.dropna()
mlb_teams
# Out:
#       yearID lgID      G   G.1     W      L  WPCT WSWin      R      AB  ...  \
# 0     2014.0   NL  162.0  81.0  64.0   98.0  0.57     N  615.0  5552.0  ...
# 1     2014.0   NL  162.0  81.0  79.0   83.0  0.67     N  573.0  5468.0  ...
# 2     2014.0   AL  162.0  81.0  96.0   66.0  0.54     N  705.0  5596.0  ...
# 3     2014.0   AL  162.0  81.0  71.0   91.0  0.44     N  634.0  5551.0  ...
# 4     2014.0   NL  162.0  81.0  73.0   89.0  0.42     N  614.0  5508.0  ...
# ...      ...  ...    ...   ...   ...    ...   ...   ...    ...     ...  ...
# 1224  1969.0   NL  162.0  81.0  88.0   74.0  0.56     N  725.0  5626.0  ...
# 1225  1969.0   NL  162.0  81.0  52.0  110.0  0.46     N  468.0  5357.0  ...
# 1226  1969.0   NL  162.0  81.0  90.0   72.0  0.53     N  713.0  5474.0  ...
# 1227  1969.0   NL  162.0  80.0  87.0   75.0  0.40     N  595.0  5536.0  ...
# 1228  1969.0   AL  162.0  81.0  86.0   76.0  0.49     N  694.0  5447.0  ...
#
#         3B     HR     BB      SO    SB   ERA    CG   SHO    SV  \
# 0     47.0  118.0  398.0  1165.0  86.0  4.26   2.0   4.0  35.0
# 1     22.0  123.0  472.0  1369.0  95.0  3.38   5.0  13.0  54.0
# 2     16.0  211.0  401.0  1285.0  44.0  3.43   3.0  13.0  53.0
# 3     20.0  123.0  535.0  1337.0  63.0  4.01   3.0   7.0  36.0
# 4     31.0  157.0  442.0  1477.0  65.0  3.91   1.0  11.0  37.0
# ...    ...    ...    ...     ...   ...   ...   ...   ...   ...
# 1224  52.0  119.0  454.0   944.0  74.0  3.61  39.0   9.0  33.0
# 1225  42.0   99.0  423.0  1143.0  45.0  4.24  16.0   9.0  25.0
# 1226  28.0  136.0  711.0  1054.0  71.0  3.26  71.0  15.0  17.0
# 1227  44.0   90.0  503.0   876.0  87.0  2.94  63.0  12.0  26.0
# 1228  40.0  148.0  630.0   900.0  52.0  3.49  28.0  10.0  41.0
#
#                       name
# 0     Arizona Diamondbacks
# 1           Atlanta Braves
# 2        Baltimore Orioles
# 3           Boston Red Sox
# 4             Chicago Cubs
# ...                    ...
# 1224    Pittsburgh Pirates
# 1225      San Diego Padres
# 1226  San Francisco Giants
# 1227   St. Louis Cardinals
# 1228   Washington Senators
#
# [1229 rows x 22 columns]

# %%
#Get list of dataframe columns

mlb_teams.columns
# Out:
# Index(['yearID', 'lgID', 'G', 'G.1', 'W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H',
#        '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV', 'name'],
#       dtype='object')

# %%
#Select columns for dataframe

mlb_df = mlb_teams[['yearID', 'lgID', 'G', 'G.1', 'W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H', '2B',
       '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV']]


mlb_df.tail(37)
# Out:
#       yearID lgID      G   G.1      W      L  WPCT WSWin      R      AB  ...  \
# 1192  1970.0   AL  162.0  79.0   65.0   97.0  0.54     N  611.0  5503.0  ...
# 1193  1970.0   NL  161.0  81.0   87.0   74.0  0.56     N  749.0  5606.0  ...
# 1194  1970.0   AL  163.0  81.0   65.0   97.0  0.57     N  613.0  5395.0  ...
# 1195  1970.0   AL  162.0  81.0   98.0   64.0  0.45     N  744.0  5483.0  ...
# 1196  1970.0   NL  162.0  80.0   73.0   89.0  0.60     N  687.0  5411.0  ...
# 1197  1970.0   NL  162.0  82.0   83.0   79.0  0.50     N  695.0  5443.0  ...
# 1198  1970.0   AL  163.0  81.0   93.0   69.0  0.59     N  680.0  5492.0  ...
# 1199  1970.0   AL  162.0  81.0   89.0   73.0  0.52     N  678.0  5376.0  ...
# 1200  1970.0   NL  161.0  80.0   73.0   88.0  0.60     N  594.0  5456.0  ...
# 4  2014.0   NL  162.0  81.0  73.0  89.0  0.42  614.0  5508.0  1315.0  ...
#
#      3B     HR     BB      SO    SB   ERA   CG   SHO    SV  WSWin_Y
# 0  47.0  118.0  398.0  1165.0  86.0  4.26  2.0   4.0  35.0        0
# 1  22.0  123.0  472.0  1369.0  95.0  3.38  5.0  13.0  54.0        0
# 2  16.0  211.0  401.0  1285.0  44.0  3.43  3.0  13.0  53.0        0
# 3  20.0  123.0  535.0  1337.0  63.0  4.01  3.0   7.0  36.0        0
# 4  31.0  157.0  442.0  1477.0  65.0  3.91  1.0  11.0  37.0        0
#
# [5 rows x 21 columns]

# %%
#Set X(data) and y(team)variables

data = data_bin.drop("lgID", axis = 1)
outcome = data_bin["lgID"]
print(data.shape, outcome.shape)
# Out:
# (1229, 20) (1229,)

# %% [markdown]
# Preprocess data

# %%
#Import SciKit libraries

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
#Split data and teams into training and test data

X_train, X_test, y_train, y_test = train_test_split(data, outcome, test_size = 0.2, random_state=42)
y_train
# Out:
# 752     NL
# 1067    AL
# 986     NL
# 425     NL
# 644     AL
#         ..
# 1044    NL
# 1095    NL
# 1130    NL
# 860     NL
# 1126    AL
# Name: lgID, Length: 983, dtype: object

# %%
#Scale data using MinMaxScaler

X_scaler = StandardScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
X_train_scaled
# Out:
# array([[-0.40931253,  0.09427444,  0.21183845, ..., -1.40783454,
#         -0.61520277, -0.18343607],
#        [-1.30859556,  0.09427444,  0.21183845, ..., -0.66353478,
#          0.15657668, -0.18343607],
#        [-1.08377481,  0.21637165,  0.21183845, ...,  0.57696482,
#         -0.61520277, -0.18343607],
#        ...,
#        [-1.45847607,  0.21637165,  0.21183845, ...,  0.08076498,
#         -1.60749064, -0.18343607],
#        [-0.70907354,  0.21637165,  0.21183845, ...,  0.08076498,
#          0.4873393 , -0.18343607],
#        [-1.45847607,  0.21637165,  0.21183845, ...,  1.5693645 ,
#          0.15657668, -0.18343607]])

# %%
##Import RandomForestClassifier and train

from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=1000, random_state=1)

rf.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=1000,
#                        n_jobs=None, oob_score=False, random_state=1, verbose=0,
#                        warm_start=False)

# %%
#Get Score for RandomForestClassifier
rf.score(X_test_scaled, y_test)
# Out:
# 0.7032520325203252

# %%
#Print data scores for training aand test datasets
print(f"Training Data Score: {rf.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {rf.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 1.0
# Testing Data Score: 0.7032520325203252

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {"bootstrap": [True],
              "max_depth": [20, 40, 100, 125],
#              "max_features": [2,3],
 #            "min_samples_leaf": [3, 4, 5],
              "n_estimators": [100, 500, 1000]
              }
grid = GridSearchCV(rf, param_grid, verbose=3)
grid
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=1000, n_jobs=None,
#                                               oob_score=False, random_state=1,
#                                               verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'bootstrap': [True], 'max_depth': [20, 40, 100, 125],
#                          'n_estimators': [100, 500, 1000]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %% [markdown]
# Train Model

# %%
# Train the model with GridSearch

grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] bootstrap=True, max_depth=20, n_estimators=100 ..................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  bootstrap=True, max_depth=20, n_estimators=100, score=0.675, total=   0.5s
# [CV] bootstrap=True, max_depth=20, n_estimators=100 ..................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s remaining:    0.0s
# [CV]  bootstrap=True, max_depth=20, n_estimators=100, score=0.751, total=   0.6s
# [CV] bootstrap=True, max_depth=20, n_estimators=100 ..................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.0s remaining:    0.0s
# [CV]  bootstrap=True, max_depth=20, n_estimators=100, score=0.690, total=   0.6s
# [CV] bootstrap=True, max_depth=20, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=100, score=0.719, total=   0.6s
# [CV] bootstrap=True, max_depth=20, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=100, score=0.679, total=   0.5s
# [CV] bootstrap=True, max_depth=20, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=500, score=0.706, total=   2.8s
# [CV] bootstrap=True, max_depth=20, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=500, score=0.751, total=   2.8s
# [CV] bootstrap=True, max_depth=20, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=500, score=0.695, total=   2.8s
# [CV] bootstrap=True, max_depth=20, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=500, score=0.689, total=   2.5s
# [CV] bootstrap=True, max_depth=20, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=500, score=0.699, total=   2.7s
# [CV] bootstrap=True, max_depth=20, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=20, n_estimators=1000, score=0.711, total=   5.3s
# [CV] bootstrap=True, max_depth=20, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=20, n_estimators=1000, score=0.761, total=   4.9s
# [CV] bootstrap=True, max_depth=20, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=20, n_estimators=1000, score=0.685, total=   5.6s
# [CV] bootstrap=True, max_depth=20, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=20, n_estimators=1000, score=0.699, total=   5.4s
# [CV] bootstrap=True, max_depth=20, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=20, n_estimators=1000, score=0.704, total=   5.7s
# [CV] bootstrap=True, max_depth=40, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=100, score=0.675, total=   0.6s
# [CV] bootstrap=True, max_depth=40, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=100, score=0.751, total=   0.6s
# [CV] bootstrap=True, max_depth=40, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=100, score=0.685, total=   0.5s
# [CV] bootstrap=True, max_depth=40, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=100, score=0.714, total=   0.5s
# [CV] bootstrap=True, max_depth=40, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=100, score=0.673, total=   0.6s
# [CV] bootstrap=True, max_depth=40, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=500, score=0.706, total=   2.7s
# [CV] bootstrap=True, max_depth=40, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=500, score=0.751, total=   2.7s
# [CV] bootstrap=True, max_depth=40, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=500, score=0.701, total=   2.6s
# [CV] bootstrap=True, max_depth=40, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=500, score=0.684, total=   2.8s
# [CV] bootstrap=True, max_depth=40, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=500, score=0.694, total=   2.4s
# [CV] bootstrap=True, max_depth=40, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=40, n_estimators=1000, score=0.711, total=   5.3s
# [CV] bootstrap=True, max_depth=40, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=40, n_estimators=1000, score=0.761, total=   5.5s
# [CV] bootstrap=True, max_depth=40, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=40, n_estimators=1000, score=0.690, total=   5.1s
# [CV] bootstrap=True, max_depth=40, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=40, n_estimators=1000, score=0.694, total=   5.2s
# [CV] bootstrap=True, max_depth=40, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=40, n_estimators=1000, score=0.709, total=   5.0s
# [CV] bootstrap=True, max_depth=100, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=100, score=0.675, total=   0.6s
# [CV] bootstrap=True, max_depth=100, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=100, score=0.751, total=   0.5s
# [CV] bootstrap=True, max_depth=100, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=100, score=0.685, total=   0.5s
# [CV] bootstrap=True, max_depth=100, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=100, score=0.714, total=   0.6s
# [CV] bootstrap=True, max_depth=100, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=100, score=0.673, total=   0.5s
# [CV] bootstrap=True, max_depth=100, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=500, score=0.706, total=   2.6s
# [CV] bootstrap=True, max_depth=100, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=500, score=0.751, total=   2.6s
# [CV] bootstrap=True, max_depth=100, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=500, score=0.701, total=   2.6s
# [CV] bootstrap=True, max_depth=100, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=500, score=0.684, total=   2.8s
# [CV] bootstrap=True, max_depth=100, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=500, score=0.694, total=   2.8s
# [CV] bootstrap=True, max_depth=100, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=100, n_estimators=1000, score=0.711, total=   5.5s
# [CV] bootstrap=True, max_depth=100, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=100, n_estimators=1000, score=0.761, total=   5.4s
# [CV] bootstrap=True, max_depth=100, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=100, n_estimators=1000, score=0.690, total=   5.5s
# [CV] bootstrap=True, max_depth=100, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=100, n_estimators=1000, score=0.694, total=   5.4s
# [CV] bootstrap=True, max_depth=100, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=100, n_estimators=1000, score=0.709, total=   5.2s
# [CV] bootstrap=True, max_depth=125, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=100, score=0.675, total=   0.6s
# [CV] bootstrap=True, max_depth=125, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=100, score=0.751, total=   0.5s
# [CV] bootstrap=True, max_depth=125, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=100, score=0.685, total=   0.5s
# [CV] bootstrap=True, max_depth=125, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=100, score=0.714, total=   0.6s
# [CV] bootstrap=True, max_depth=125, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=100, score=0.673, total=   0.5s
# [CV] bootstrap=True, max_depth=125, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=500, score=0.706, total=   2.7s
# [CV] bootstrap=True, max_depth=125, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=500, score=0.751, total=   2.7s
# [CV] bootstrap=True, max_depth=125, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=500, score=0.701, total=   2.7s
# [CV] bootstrap=True, max_depth=125, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=500, score=0.684, total=   2.4s
# [CV] bootstrap=True, max_depth=125, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=500, score=0.694, total=   2.8s
# [CV] bootstrap=True, max_depth=125, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=125, n_estimators=1000, score=0.711, total=   5.4s
# [CV] bootstrap=True, max_depth=125, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=125, n_estimators=1000, score=0.761, total=   5.4s
# [CV] bootstrap=True, max_depth=125, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=125, n_estimators=1000, score=0.690, total=   5.7s
# [CV] bootstrap=True, max_depth=125, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=125, n_estimators=1000, score=0.694, total=   6.1s
# [CV] bootstrap=True, max_depth=125, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=125, n_estimators=1000, score=0.709, total=   5.5s
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:  2.9min finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=1000, n_jobs=None,
#                                               oob_score=False, random_state=1,
#                                               verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'bootstrap': [True], 'max_depth': [20, 40, 100, 125],
#                          'n_estimators': [100, 500, 1000]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
#Print best parameter and score 

print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'bootstrap': True, 'max_depth': 40, 'n_estimators': 1000}
# 0.7130995545426292

# %%
#Predict 2015 WS winner (division)
mlb_teams2015= pd.read_csv("2015.csv")



mlb2015_df = mlb_teams2015[['yearID', 'lgID', 'G', 'G.1', 'W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H', '2B',
       '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV']]


data_LG2015 = mlb2015_df.copy()
data_bin2015 = pd.get_dummies(data_LG2015, columns=["WSWin"])
data_bin2015 = data_bin2015.drop(columns=['WSWin_N'])



feature2015 = data_bin2015.drop("lgID", axis=1)
team2015 = data_bin2015["lgID"]

X_feature2015_scaler = StandardScaler().fit(feature2015)
X_feature2015_scaled = X_feature2015_scaler.transform(feature2015)

#Make prediction using test data

predictions2015 = grid.predict(X_feature2015_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2015_scaled, team2015))

# Calculate classification report

predictions2015 = rf.predict(X_feature2015_scaled)
predictions2015
# Out:
# Test Acc: 0.600
# array(['AL', 'AL', 'AL', 'AL', 'NL', 'NL', 'NL', 'AL', 'AL', 'AL', 'NL',
#        'AL', 'AL', 'AL', 'AL', 'NL', 'NL', 'NL', 'AL', 'AL', 'AL', 'NL',
#        'NL', 'AL', 'AL', 'NL', 'NL', 'AL', 'AL', 'AL'], dtype=object)

# %%
#Predict 2016 WS winner (division)
mlb_teams2016= pd.read_csv("2016.csv")



mlb2016_df = mlb_teams2016[['yearID', 'lgID', 'G', 'G.1', 'W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H', '2B',
       '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV']]


data_LG2016 = mlb2016_df.copy()
data_bin2016 = pd.get_dummies(data_LG2016, columns=["WSWin"])
data_bin2016 = data_bin2016.drop(columns=['WSWin_N'])



feature2016 = data_bin2016.drop("lgID", axis=1)
team2016 = data_bin2016["lgID"]

X_feature2016_scaler = StandardScaler().fit(feature2016)
X_feature2016_scaled = X_feature2016_scaler.transform(feature2016)

#Make prediction using test data

predictions2016 = grid.predict(X_feature2016_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2016_scaled, team2016))

# Calculate classification report

predictions2016 = rf.predict(X_feature2016_scaled)
predictions2016
# Out:
# Test Acc: 0.667
# array(['AL', 'NL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'NL',
#        'NL', 'AL', 'NL', 'NL', 'NL', 'AL', 'NL', 'AL', 'AL', 'NL', 'AL',
#        'NL', 'AL', 'AL', 'AL', 'NL', 'AL', 'NL', 'NL'], dtype=object)

# %%
#Predict 2017 WS winner (division)
mlb_teams2017= pd.read_csv("2017.csv")



mlb2017_df = mlb_teams2017[['yearID', 'lgID', 'G', 'G.1', 'W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H', '2B',
       '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV']]


data_LG2017 = mlb2017_df.copy()
data_bin2017 = pd.get_dummies(data_LG2017, columns=["WSWin"])
data_bin2017 = data_bin2017.drop(columns=['WSWin_N'])



feature2017 = data_bin2017.drop("lgID", axis=1)
team2017 = data_bin2017["lgID"]

X_feature2017_scaler = StandardScaler().fit(feature2017)
X_feature2017_scaled = X_feature2017_scaler.transform(feature2017)

#Make prediction using test data

predictions2017 = grid.predict(X_feature2017_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2017_scaled, team2017))

# Calculate classification report

predictions2017 = rf.predict(X_feature2017_scaled)
predictions2017
# Out:
# Test Acc: 0.667
# array(['NL', 'AL', 'AL', 'AL', 'NL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL',
#        'AL', 'AL', 'NL', 'AL', 'NL', 'AL', 'AL', 'AL', 'NL', 'NL', 'NL',
#        'NL', 'AL', 'AL', 'NL', 'NL', 'AL', 'AL', 'AL'], dtype=object)

# %%
#Predict 2018 WS winner (division)
mlb_teams2018= pd.read_csv("2018.csv")



mlb2018_df = mlb_teams2018[['yearID', 'lgID', 'G', 'G.1', 'W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H', '2B',
       '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV']]


data_LG2018 = mlb2018_df.copy()
data_bin2018 = pd.get_dummies(data_LG2018, columns=["WSWin"])
data_bin2018 = data_bin2018.drop(columns=['WSWin_N'])



feature2018 = data_bin2018.drop("lgID", axis=1)
team2018 = data_bin2018["lgID"]

X_feature2018_scaler = StandardScaler().fit(feature2018)
X_feature2018_scaled = X_feature2018_scaler.transform(feature2018)

#Make prediction using test data

predictions2018 = grid.predict(X_feature2018_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2018_scaled, team2018))

# Calculate classification report

predictions2018 = rf.predict(X_feature2018_scaled)
predictions2018
# Out:
# Test Acc: 0.600
# array(['NL', 'AL', 'AL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'NL', 'AL',
#        'AL', 'AL', 'NL', 'NL', 'NL', 'AL', 'AL', 'AL', 'AL', 'NL', 'AL',
#        'NL', 'NL', 'AL', 'AL', 'NL', 'NL', 'AL', 'AL'], dtype=object)

# %%
#Predict 2019 WS winner (division)
mlb_teams2019= pd.read_csv("MLB 2019 season.csv")



mlb2019_df = mlb_teams2019[['yearID', 'lgID', 'G', 'G.1', 'W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H', '2B',
       '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV']]


data_LG2019 = mlb2019_df.copy()
data_bin2019 = pd.get_dummies(data_LG2019, columns=["WSWin"])
data_bin2019 = data_bin2019.drop(columns=['WSWin_N'])



feature2019 = data_bin2019.drop("lgID", axis=1)
team2019 = data_bin2019["lgID"]

X_feature2019_scaler = StandardScaler().fit(feature2019)
X_feature2019_scaled = X_feature2019_scaler.transform(feature2019)

#Make prediction using test data

predictions2019 = grid.predict(X_feature2019_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2019_scaled, team2019))

# Calculate classification report

predictions2019 = rf.predict(X_feature2019_scaled)
predictions2019
# Out:
# Test Acc: 0.600
# array(['NL', 'NL', 'AL', 'AL', 'AL', 'NL', 'NL', 'AL', 'AL', 'NL', 'AL',
#        'NL', 'AL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL',
#        'NL', 'NL', 'NL', 'NL', 'NL', 'AL', 'NL', 'AL'], dtype=object)

# %%
#Predict 2020 WS winner (division)
mlb_teams2020= pd.read_csv("2020.csv")



mlb2020_df = mlb_teams2020[['yearID', 'lgID', 'G', 'G.1', 'W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H', '2B',
       '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV']]


data_LG2020 = mlb2020_df.copy()
data_bin2020 = pd.get_dummies(data_LG2020, columns=["WSWin"])

feature2020 = data_bin2020.drop("lgID", axis=1)
team2020 = data_bin2020["lgID"]

X_feature2020_scaler = StandardScaler().fit(feature2020)
X_feature2020_scaled = X_feature2020_scaler.transform(feature2020)

#Make prediction using test data

predictions2020 = grid.predict(X_feature2020_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2020_scaled, team2020))

# Calculate classification report
predictions2020 = rf.predict(X_feature2020_scaled)
predictions2020
# Out:
# Test Acc: 0.433
# array(['NL', 'AL', 'NL', 'NL', 'NL', 'AL', 'AL', 'NL', 'NL', 'NL', 'AL',
#        'NL', 'AL', 'AL', 'NL', 'NL', 'NL', 'AL', 'AL', 'AL', 'AL', 'NL',
#        'AL', 'AL', 'NL', 'AL', 'NL', 'AL', 'AL', 'AL'], dtype=object)

# %%
import joblib
filename = 'SWilliams_RFC.sav'
joblib.dump(rf, filename)
# Out:
# ['SWilliams_RFC.sav']
