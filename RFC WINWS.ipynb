# %%
#import numpy to use seed 
import numpy as np
import pandas as pd
from numpy.random import seed
np.random.seed(1)

# %%
#import other dependencies

import os
import tensorflow 
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense

# %% [markdown]
# Read CSV create, and clean dataframe

# %%
#Read in CSV and create dataframe
mlb_teams= pd.read_csv("Teams.csv")

mlb_teams
# Out:
#       yearID lgID    G  G.1    W   L WSWin    R    AB     H  ...  3B   HR  \
# 0       1969   NL  162   81   93  69     N  691  5460  1411  ...  22  141
# 1       1969   AL  162   81  109  53     N  779  5518  1465  ...  29  175
# 2       1969   AL  162   81   87  75     N  743  5494  1381  ...  37  197
# 3       1969   AL  163   81   71  91     N  528  5316  1221  ...  29   88
# 4       1969   AL  162   81   68  94     N  625  5450  1346  ...  27  112
# ...      ...  ...  ...  ...  ...  ..   ...  ...   ...   ...  ...  ..  ...
# 1403    2019   NL  162   81   91  71     N  764  5449  1336  ...  24  210
# 1404    2019   AL  162   81   96  66     N  769  5628  1427  ...  29  217
# 1405    2019   AL  162   81   78  84     N  810  5540  1374  ...  24  223
# 1406    2019   AL  162   81   67  95     N  726  5493  1299  ...  21  247
# 1407    2019   NL  162   81   93  69     Y  873  5512  1460  ...  27  231
#
#        BB    SO   SB   ERA  CG  SHO  SV                  name
# 0     485   665   59  3.53  38    7  42        Atlanta Braves
# 1     634   806   82  2.83  50   20  36     Baltimore Orioles
# 2     658   923   41  3.92  30    7  41        Boston Red Sox
# 3     516   929   54  3.54  25    9  39     California Angels
# 4     552   844   54  4.21  29   10  25     Chicago White Sox
# ...   ...   ...  ...   ...  ..  ...  ..                   ...
# 1403  561  1420  116  3.80   1   14  52   St. Louis Cardinals
# 1404  542  1493   94  3.65   0   12  46        Tampa Bay Rays
# 1405  534  1578  131  5.06   4    9  33         Texas Rangers
# 1406  509  1514   51  4.79   1    7  33     Toronto Blue Jays
# 1407  584  1308  116  4.27   1   13  40  Washington Nationals
#
# [1408 rows x 21 columns]

# %%
#Get list of dataframe columns

mlb_teams.columns
# Out:
# Index(['yearID', 'lgID', 'G', 'G.1', 'W', 'L', 'WSWin', 'R', 'AB', 'H', '2B',
#        '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV', 'name'],
#       dtype='object')

# %%
#Select columns for dataframe

mlb_df = mlb_teams[['yearID', 'lgID', 'G', 'G.1', 'W', 'L', 'WSWin', 'R', 'AB', 'H', '2B',
       '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV']]


mlb_df.tail(37)
# Out:
#       yearID lgID    G  G.1    W    L WSWin    R    AB     H   2B  3B   HR  \
# 1371    2018   AL  162   81   89   73     N  677  5513  1402  256  32  176
# 1372    2018   NL  162   81   73   89     N  603  5541  1324  255  30  133
# 1373    2018   NL  162   81   88   74     N  759  5498  1369  248   9  205
# 1374    2018   AL  162   81   90   72     N  716  5475  1415  274  43  150
# 1375    2018   AL  162   81   67   95     N  737  5453  1308  266  24  194
# 1376    2018   AL  162   81   73   89     N  709  5477  1336  320  16  217
# 1377    2018   NL  162   81   82   80     N  771  5517  1402  284  25  191
# 1378    2019   NL  162   81   85   77     N  813  5633  1419  288  40  220
# 1379    2019   NL  162   81   97   65     N  855  5560  1432  277  29  249
# 1380    2019   AL  162   81   54  108     N  729  5596  1379  252  25  213
# 1381    2019   AL  162   81   84   78     N  901  5770  1554  345  27  245
# 1382    2019   AL  161   80   72   89     N  708  5529  1443  260  20  182
# 1383    2019   NL  162   81   84   78     N  814  5461  1378  270  26  256
# 1384    2019   NL  162   81   75   87     N  701  5450  1328  235  27  227
# 1385    2019   AL  162   81   93   69     N  769  5425  1354  286  18  223
# 1386    2019   NL  162   81   71   91     N  835  5660  1502  323  41  224
# 1387    2019   AL  161   81   47  114     N  582  5549  1333  292  41  149
# 1388    2019   AL  162   81  107   55     N  920  5613  1538  323  28  288
# 1389    2019   AL  162   81   59  103     N  691  5496  1356  281  40  162
# 1390    2019   AL  162   81   72   90     N  769  5542  1368  268  21  220
# 1391    2019   NL  162   81  106   56     N  886  5493  1414  302  20  279
# 1392    2019   NL  162   81   57  105     N  615  5512  1326  265  18  146
# 1393    2019   NL  162   81   89   73     N  769  5542  1366  279  17  250
# 1394    2019   AL  162   81  101   61     N  939  5732  1547  318  23  307
# 1395    2019   AL  162   81  103   59     N  943  5583  1493  290  17  306
# 1396    2019   NL  162   81   86   76     N  791  5624  1445  280  17  242
# 1397    2019   AL  162   81   97   65     N  845  5561  1384  292  23  257
# 1398    2019   NL  162   81   81   81     N  774  5571  1369  311  26  215
# 1399    2019   NL  162   81   69   93     N  758  5657  1497  315  38  163
# 1400    2019   NL  162   81   70   92     N  682  5391  1281  224  24  219
# 1401    2019   AL  162   81   68   94     N  758  5500  1305  254  28  239
# 1402    2019   NL  162   81   77   85     N  678  5579  1332  300  26  167
# 1403    2019   NL  162   81   91   71     N  764  5449  1336  246  24  210
# 1404    2019   AL  162   81   96   66     N  769  5628  1427  291  29  217
# 1405    2019   AL  162   81   78   84     N  810  5540  1374  296  24  223
# 1406    2019   AL  162   81   67   95     N  726  5493  1299  270  21  247
# 1407    2019   NL  162   81   93   69     Y  873  5512  1460  298  27  231
#
#        BB    SO   SB   ERA  CG  SHO  SV
# 1371  430  1221   79  4.13   3   12  60
# 1372  448  1467   77  3.95   1   15  36
# 1373  525  1380   63  3.85   1    8  43
# 1374  540  1388  128  3.74   0   14  52
# 1375  555  1484   74  4.92   1    5  42
# 1376  499  1387   47  4.85   0    3  39
# 1377  631  1289  119  4.04   2    7  40
# 1378  540  1360   88  4.25   0   11  45
# 1379  619  1467   89  4.19   1    8  44
# 1380  462  1435   84  5.59   0    5  27
# 1381  590  1382   68  4.70   1    8  33
# 1382  378  1549   63  4.90   6    7  33
# 1383  581  1460   45  4.10   1   10  38
# 1384  492  1436   80  4.18   0   10  46
# 1385  563  1332  103  3.76   6   16  42
# 1386  489  1503   71  5.56   1    5  28
# 1387  391  1595   57  5.24   0    3  31
# 1388  645  1166   67  3.66   2   14  47
# 1389  456  1405  117  5.20   1    7  37
# 1390  586  1276   65  5.12   0    2  32
# 1391  607  1356   57  3.37   3   18  44
# 1392  395  1469   55  4.74   2    8  27
# 1393  629  1563  101  4.40   0    7  50
# 1394  525  1334   28  4.18   1   10  50
# 1395  569  1437   55  4.31   1    9  50
# 1396  516  1384   56  4.24   3   12  38
# 1397  578  1338   49  3.97   1   12  45
# 1398  562  1453   78  4.53   3    7  36
# 1399  425  1213   64  5.18   1    6  31
# 1400  504  1581   70  4.60   0    6  47
# 1401  588  1581  115  4.99   3    4  34
# 1402  475  1435   47  4.38   1    8  41
# 1403  561  1420  116  3.80   1   14  52
# 1404  542  1493   94  3.65   0   12  46
# 1405  534  1578  131  5.06   4    9  33
# 1406  509  1514   51  4.79   1    7  33
# 1407  584  1308  116  4.27   1   13  40

# %%
#Use getdummies to convert strings

data_LG = mlb_df.copy()
data_bin = pd.get_dummies(data_LG, columns=["WSWin"])
data_bin = data_bin.drop(columns=['WSWin_N'])

data_bin.head()
# Out:
#    yearID lgID    G  G.1    W   L    R    AB     H   2B  3B   HR   BB   SO  \
# 0    1969   NL  162   81   93  69  691  5460  1411  195  22  141  485  665
# 1    1969   AL  162   81  109  53  779  5518  1465  234  29  175  634  806
# 2    1969   AL  162   81   87  75  743  5494  1381  234  37  197  658  923
# 3    1969   AL  163   81   71  91  528  5316  1221  151  29   88  516  929
# 4    1969   AL  162   81   68  94  625  5450  1346  210  27  112  552  844
#
#    SB   ERA  CG  SHO  SV  WSWin_Y
# 0  59  3.53  38    7  42        0
# 1  82  2.83  50   20  36        0
# 2  41  3.92  30    7  41        0
# 3  54  3.54  25    9  39        0
# 4  54  4.21  29   10  25        0

# %%
#Set X(data) and y(team)variables

data = data_bin.drop("lgID", axis = 1)
outcome = data_bin["lgID"]
print(data.shape, outcome.shape)
# Out:
# (1408, 19) (1408,)

# %% [markdown]
# Preprocess data

# %%
#Import SciKit libraries

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

# %%
#Split data and teams into training and test data

X_train, X_test, y_train, y_test = train_test_split(data, outcome, test_size = 0.2, random_state=42)
y_train
# Out:
# 1335    AL
# 579     NL
# 1137    NL
# 48      NL
# 155     NL
#         ..
# 1095    AL
# 1130    NL
# 1294    NL
# 860     NL
# 1126    NL
# Name: lgID, Length: 1126, dtype: object

# %%
#Scale data using MinMaxScaler

X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
X_train_scaled
# Out:
# array([[0.96      , 0.96721311, 0.925     , ..., 0.25      , 0.44827586,
#         0.        ],
#        [0.44      , 0.96721311, 1.        , ..., 0.17857143, 0.70689655,
#         0.        ],
#        [0.82      , 0.96721311, 0.925     , ..., 0.17857143, 0.46551724,
#         0.        ],
#        ...,
#        [0.94      , 0.96721311, 0.925     , ..., 0.28571429, 0.31034483,
#         0.        ],
#        [0.64      , 0.96721311, 0.925     , ..., 0.32142857, 0.44827586,
#         0.        ],
#        [0.82      , 0.96721311, 0.925     , ..., 0.67857143, 0.44827586,
#         0.        ]])

# %%
##Import RandomForestClassifier and train
#from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=1000, random_state=1)
#classifier = MultiOutputClassifier(rf, n_jobs=-1)
rf.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=1000,
#                        n_jobs=None, oob_score=False, random_state=1, verbose=0,
#                        warm_start=False)

# %%
#Get Score for RandomForestClassifier
rf.score(X_test_scaled, y_test)
# Out:
# 0.7553191489361702

# %%
#Print data scores for training aand test datasets
print(f"Training Data Score: {classifier.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test_scaled, y_test)}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-2be3c6fa2560> in <module>
#       1 #Print data scores for training aand test datasets
# ----> 2 print(f"Training Data Score: {classifier.score(X_train_scaled, y_train)}")
#       3 print(f"Testing Data Score: {classifier.score(X_test_scaled, y_test)}")
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\multioutput.py in score(self, X, y)
#     412         n_outputs_ = len(self.estimators_)
#     413         if y.ndim == 1:
# --> 414             raise ValueError("y must have at least two dimensions for "
#     415                              "multi target classification but has only one")
#     416         if y.shape[1] != n_outputs_:
#
# ValueError: y must have at least two dimensions for multi target classification but has only one

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {"bootstrap": [True],
              "max_depth": [20, 40, 100, 125],
#              "max_features": [2,3],
 #            "min_samples_leaf": [3, 4, 5],
              "n_estimators": [100, 500, 1000]
              }
grid = GridSearchCV(rf, param_grid, verbose=3)
grid
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=1000, n_jobs=None,
#                                               oob_score=False, random_state=1,
#                                               verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'bootstrap': [True], 'max_depth': [20, 40, 100, 125],
#                          'n_estimators': [100, 500, 1000]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %% [markdown]
# Train Model

# %%
# Train the model with GridSearch

grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] bootstrap=True, max_depth=20, n_estimators=100 ..................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  bootstrap=True, max_depth=20, n_estimators=100, score=0.708, total=   0.6s
# [CV] bootstrap=True, max_depth=20, n_estimators=100 ..................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.5s remaining:    0.0s
# [CV]  bootstrap=True, max_depth=20, n_estimators=100, score=0.684, total=   0.6s
# [CV] bootstrap=True, max_depth=20, n_estimators=100 ..................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.1s remaining:    0.0s
# [CV]  bootstrap=True, max_depth=20, n_estimators=100, score=0.680, total=   0.6s
# [CV] bootstrap=True, max_depth=20, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=100, score=0.751, total=   0.6s
# [CV] bootstrap=True, max_depth=20, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=100, score=0.729, total=   0.8s
# [CV] bootstrap=True, max_depth=20, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=500, score=0.717, total=   4.3s
# [CV] bootstrap=True, max_depth=20, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=500, score=0.724, total=   3.4s
# [CV] bootstrap=True, max_depth=20, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=500, score=0.676, total=   2.7s
# [CV] bootstrap=True, max_depth=20, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=500, score=0.778, total=   2.6s
# [CV] bootstrap=True, max_depth=20, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=500, score=0.729, total=   2.6s
# [CV] bootstrap=True, max_depth=20, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=20, n_estimators=1000, score=0.708, total=   5.5s
# [CV] bootstrap=True, max_depth=20, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=20, n_estimators=1000, score=0.733, total=   5.8s
# [CV] bootstrap=True, max_depth=20, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=20, n_estimators=1000, score=0.684, total=   6.6s
# [CV] bootstrap=True, max_depth=20, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=20, n_estimators=1000, score=0.756, total=   6.6s
# [CV] bootstrap=True, max_depth=20, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=20, n_estimators=1000, score=0.724, total=   6.5s
# [CV] bootstrap=True, max_depth=40, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=100, score=0.704, total=   1.1s
# [CV] bootstrap=True, max_depth=40, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=100, score=0.684, total=   0.8s
# [CV] bootstrap=True, max_depth=40, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=100, score=0.680, total=   0.8s
# [CV] bootstrap=True, max_depth=40, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=100, score=0.742, total=   1.0s
# [CV] bootstrap=True, max_depth=40, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=100, score=0.720, total=   1.0s
# [CV] bootstrap=True, max_depth=40, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=500, score=0.717, total=   3.4s
# [CV] bootstrap=True, max_depth=40, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=500, score=0.724, total=   3.8s
# [CV] bootstrap=True, max_depth=40, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=500, score=0.676, total=   3.3s
# [CV] bootstrap=True, max_depth=40, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=500, score=0.769, total=   2.5s
# [CV] bootstrap=True, max_depth=40, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=500, score=0.733, total=   2.7s
# [CV] bootstrap=True, max_depth=40, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=40, n_estimators=1000, score=0.708, total=   5.1s
# [CV] bootstrap=True, max_depth=40, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=40, n_estimators=1000, score=0.729, total=   4.2s
# [CV] bootstrap=True, max_depth=40, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=40, n_estimators=1000, score=0.684, total=   4.1s
# [CV] bootstrap=True, max_depth=40, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=40, n_estimators=1000, score=0.764, total=   5.0s
# [CV] bootstrap=True, max_depth=40, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=40, n_estimators=1000, score=0.733, total=   4.1s
# [CV] bootstrap=True, max_depth=100, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=100, score=0.704, total=   0.4s
# [CV] bootstrap=True, max_depth=100, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=100, score=0.684, total=   0.4s
# [CV] bootstrap=True, max_depth=100, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=100, score=0.680, total=   0.4s
# [CV] bootstrap=True, max_depth=100, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=100, score=0.742, total=   0.4s
# [CV] bootstrap=True, max_depth=100, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=100, score=0.720, total=   0.4s
# [CV] bootstrap=True, max_depth=100, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=500, score=0.717, total=   2.1s
# [CV] bootstrap=True, max_depth=100, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=500, score=0.724, total=   2.1s
# [CV] bootstrap=True, max_depth=100, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=500, score=0.676, total=   2.1s
# [CV] bootstrap=True, max_depth=100, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=500, score=0.769, total=   2.0s
# [CV] bootstrap=True, max_depth=100, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=500, score=0.733, total=   2.0s
# [CV] bootstrap=True, max_depth=100, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=100, n_estimators=1000, score=0.708, total=   5.4s
# [CV] bootstrap=True, max_depth=100, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=100, n_estimators=1000, score=0.729, total=   5.9s
# [CV] bootstrap=True, max_depth=100, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=100, n_estimators=1000, score=0.684, total=   4.2s
# [CV] bootstrap=True, max_depth=100, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=100, n_estimators=1000, score=0.764, total=   4.6s
# [CV] bootstrap=True, max_depth=100, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=100, n_estimators=1000, score=0.733, total=   4.2s
# [CV] bootstrap=True, max_depth=125, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=100, score=0.704, total=   0.4s
# [CV] bootstrap=True, max_depth=125, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=100, score=0.684, total=   0.5s
# [CV] bootstrap=True, max_depth=125, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=100, score=0.680, total=   0.4s
# [CV] bootstrap=True, max_depth=125, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=100, score=0.742, total=   0.4s
# [CV] bootstrap=True, max_depth=125, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=100, score=0.720, total=   0.4s
# [CV] bootstrap=True, max_depth=125, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=500, score=0.717, total=   2.1s
# [CV] bootstrap=True, max_depth=125, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=500, score=0.724, total=   2.1s
# [CV] bootstrap=True, max_depth=125, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=500, score=0.676, total=   2.1s
# [CV] bootstrap=True, max_depth=125, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=500, score=0.769, total=   2.0s
# [CV] bootstrap=True, max_depth=125, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=500, score=0.733, total=   2.0s
# [CV] bootstrap=True, max_depth=125, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=125, n_estimators=1000, score=0.708, total=   4.7s
# [CV] bootstrap=True, max_depth=125, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=125, n_estimators=1000, score=0.729, total=   4.6s
# [CV] bootstrap=True, max_depth=125, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=125, n_estimators=1000, score=0.684, total=   3.9s
# [CV] bootstrap=True, max_depth=125, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=125, n_estimators=1000, score=0.764, total=   3.9s
# [CV] bootstrap=True, max_depth=125, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=125, n_estimators=1000, score=0.733, total=   3.9s
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:  2.7min finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=1000, n_jobs=None,
#                                               oob_score=False, random_state=1,
#                                               verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'bootstrap': [True], 'max_depth': [20, 40, 100, 125],
#                          'n_estimators': [100, 500, 1000]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
#Print best parameter and score 

print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'bootstrap': True, 'max_depth': 20, 'n_estimators': 500}
# 0.7246961651917404

# %% [markdown]
# Evaluate Model

# %%
#Make prediction using test data

predictions = grid.predict(X_test_scaled)
print('Test Acc: %.3f' % grid.score(X_test_scaled, y_test))
# Out:
# Test Acc: 0.741

# %% [markdown]
# Predict World Series Champs

# %%
print('Test Acc: %.3f' % grid.score(X_test_scaled, y_test))
# Out:
# Test Acc: 0.741

# %%
# Calculate classification report
from sklearn.metrics import classification_report
predictions = rf.predict(X_test_scaled)
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#           AL       0.72      0.82      0.77       141
#           NL       0.80      0.69      0.74       141
#
#     accuracy                           0.76       282
#    macro avg       0.76      0.76      0.75       282
# weighted avg       0.76      0.76      0.75       282

# %%
import joblib
filename = 'SWilliams_RFC.sav'
joblib.dump(rf, filename)
# Out:
# ['SWilliams_RFC.sav']
