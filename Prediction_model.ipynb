# %%
# !pip install tensorflow
# Out:
# ...
#   Using cached tensorflow-2.3.1-cp37-cp37m-win_amd64.whl (342.5 MB)
# ...

# %%
from numpy.random import seed
seed(1)

# %%
import os
import tensorflow 
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense

# %%
import numpy as np
import pandas as pd

# %%
mlb_teams= pd.read_csv("Team Statistics.csv")

mlb_teams
# Out:
#         YR  LG                  Name    G    W   L WSWin  Unnamed: 7    R  \
# 0     1969  NL        Atlanta Braves  162   93  69     N         NaN  691
# 1     1969  AL     Baltimore Orioles  162  109  53     N         NaN  779
# 2     1969  AL        Boston Red Sox  162   87  75     N         NaN  743
# 3     1969  AL     California Angels  163   71  91     N         NaN  528
# 4     1969  AL     Chicago White Sox  162   68  94     N         NaN  625
# ...    ...  ..                   ...  ...  ...  ..   ...         ...  ...
# 1403  2019  NL   St. Louis Cardinals  162   91  71     N         NaN  764
# 1404  2019  AL        Tampa Bay Rays  162   96  66     N         NaN  769
# 1405  2019  AL         Texas Rangers  162   78  84     N         NaN  810
# 1406  2019  AL     Toronto Blue Jays  162   67  95     N         NaN  726
# 1407  2019  NL  Washington Nationals  162   93  69     Y         NaN  873
#
#          H   2B  3B   HR   BB  Unnamed: 14    SO   ERA  SHO  SV     FP
# ...

# %%
mlb_teams.columns
# Out:
# Index(['YR', 'LG', 'Name', 'G', 'W', 'L', 'WSWin', 'Unnamed: 7', 'R', 'H',
#        '2B', '3B', 'HR', 'BB', 'Unnamed: 14', 'SO', 'ERA', 'SHO', 'SV', 'FP'],
#       dtype='object')

# %%
mlb_df = mlb_teams[['YR', 'LG', 'Name', 'G', 'W', 'L', 'WSWin', 'R', 'H',
                   '2B', '3B', 'HR', 'BB', 'SO', 'ERA', 'SHO', 'SV', 'FP']]
mlb_df.head(20)
# Out:
#       YR  LG                   Name    G    W    L WSWin    R     H   2B  3B  \
# 0   1969  NL         Atlanta Braves  162   93   69     N  691  1411  195  22
# 1   1969  AL      Baltimore Orioles  162  109   53     N  779  1465  234  29
# 2   1969  AL         Boston Red Sox  162   87   75     N  743  1381  234  37
# 3   1969  AL      California Angels  163   71   91     N  528  1221  151  29
# 4   1969  AL      Chicago White Sox  162   68   94     N  625  1346  210  27
# 5   1969  NL           Chicago Cubs  163   92   70     N  720  1400  215  40
# 6   1969  NL        Cincinnati Reds  163   89   73     N  798  1558  224  42
# 7   1969  AL      Cleveland Indians  161   62   99     N  573  1272  173  24
# 8   1969  AL         Detroit Tigers  162   90   72     N  701  1316  188  29
# 9   1969  NL         Houston Astros  162   81   81     N  676  1284  208  40
# 10  1969  AL     Kansas City Royals  163   69   93     N  586  1311  179  32
# ...

# %%
data = mlb_df.drop("Name", axis=1)
team = mlb_df["Name"]
print(data.shape, team.shape)
# Out:
# (1408, 17) (1408,)

# %%
data_LG = data.copy()
data_bin = pd.get_dummies(data_LG, columns=["LG", "WSWin"])                                                    
data_bin.head()
# Out:
#      YR    G    W   L    R     H   2B  3B   HR   BB   SO   ERA  SHO  SV  \
# 0  1969  162   93  69  691  1411  195  22  141  485  665  3.53    7  42
# 1  1969  162  109  53  779  1465  234  29  175  634  806  2.83   20  36
# 2  1969  162   87  75  743  1381  234  37  197  658  923  3.92    7  41
# 3  1969  163   71  91  528  1221  151  29   88  516  929  3.54    9  39
# 4  1969  162   68  94  625  1346  210  27  112  552  844  4.21   10  25
#
#       FP  LG_AL  LG_NL  WSWin_N  WSWin_Y
# 0  0.981      0      1        1        0
# 1  0.984      1      0        1        0
# 2  0.975      1      0        1        0
# 3  0.978      1      0        1        0
# 4  0.981      1      0        1        0

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

# %%
X_train, X_test, y_train, y_test = train_test_split(data_bin, team, random_state=42)
data_bin_train.head()
# Out:
#         YR  LG    G   W    L WSWin    R     H   2B  3B   HR   BB    SO   ERA  \
# 497   1988  NL  160  85   75     N  651  1327  240  45  110  553   947  3.47
# 881   2002  AL  162  62  100     N  737  1415  285  42  140  524   921  5.21
# 1370  2018  NL  162  66   96     N  617  1289  250  30  162  471  1523  4.40
# 846   2001  AL  162  91   71     N  897  1559  294  37  212  577  1076  4.64
# 10    1969  AL  163  69   93     N  586  1311  179  32   98  522   901  3.72
#
#       SHO  SV     FP
# 497    11  46  0.980
# 881     6  30  0.979
# 1370    5  36  0.983
# 846     4  42  0.982
# 10     10  25  0.975

# %%
X_scaler = MinMaxScaler().fit(data_train)
X_train_scaled = X_scaler.transform(data_train)
X_test_scaled = X_scaler.transform(data_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-f67e76f4c7f6> in <module>
# ----> 1 X_scaler = MinMaxScaler().fit(data_train)
#       2 X_train_scaled = X_scaler.transform(data_train)
#       3 X_test_scaled = X_scaler.transform(data_test)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y)
#     337         # Reset internal state before fitting
#     338         self._reset()
# --> 339         return self.partial_fit(X, y)
#     340
#     341     def partial_fit(self, X, y=None):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sklearn\preprocessing\_data.py in partial_fit(self, X, y)
#     371         X = check_array(X,
#     372                         estimator=self, dtype=FLOAT_DTYPES,
# --> 373                         force_all_finite="allow-nan")
#     374
# ...
