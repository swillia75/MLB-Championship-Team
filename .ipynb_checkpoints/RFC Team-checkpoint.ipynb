# %%
#import numpy to use seed 
import numpy as np
import pandas as pd
from numpy.random import seed
np.random.seed(1)

# %%
#import other dependencies

import os
import tensorflow 
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense

# %% [markdown]
# Read CSV create, and clean dataframe

# %%
#Read in CSV and create dataframe
mlb_teams= pd.read_csv("Teams.csv")

mlb_teams
# Out:
#       yearID lgID    G  G.1    W   L WSWin    R    AB     H  ...  3B   HR  \
# 0       1969   NL  162   81   93  69     N  691  5460  1411  ...  22  141
# 1       1969   AL  162   81  109  53     N  779  5518  1465  ...  29  175
# 2       1969   AL  162   81   87  75     N  743  5494  1381  ...  37  197
# 3       1969   AL  163   81   71  91     N  528  5316  1221  ...  29   88
# 4       1969   AL  162   81   68  94     N  625  5450  1346  ...  27  112
# ...      ...  ...  ...  ...  ...  ..   ...  ...   ...   ...  ...  ..  ...
# 1403    2019   NL  162   81   91  71     N  764  5449  1336  ...  24  210
# 1404    2019   AL  162   81   96  66     N  769  5628  1427  ...  29  217
# 1405    2019   AL  162   81   78  84     N  810  5540  1374  ...  24  223
# 1406    2019   AL  162   81   67  95     N  726  5493  1299  ...  21  247
# 1407    2019   NL  162   81   93  69     Y  873  5512  1460  ...  27  231
#
#        BB    SO   SB   ERA  CG  SHO  SV                  name
# 0     485   665   59  3.53  38    7  42        Atlanta Braves
# 1     634   806   82  2.83  50   20  36     Baltimore Orioles
# 2     658   923   41  3.92  30    7  41        Boston Red Sox
# 3     516   929   54  3.54  25    9  39     California Angels
# 4     552   844   54  4.21  29   10  25     Chicago White Sox
# ...   ...   ...  ...   ...  ..  ...  ..                   ...
# 1403  561  1420  116  3.80   1   14  52   St. Louis Cardinals
# 1404  542  1493   94  3.65   0   12  46        Tampa Bay Rays
# 1405  534  1578  131  5.06   4    9  33         Texas Rangers
# 1406  509  1514   51  4.79   1    7  33     Toronto Blue Jays
# 1407  584  1308  116  4.27   1   13  40  Washington Nationals
#
# [1408 rows x 21 columns]

# %%
#Get list of dataframe columns

mlb_teams.columns
# Out:
# Index(['yearID', 'lgID', 'G', 'G.1', 'W', 'L', 'WSWin', 'R', 'AB', 'H', '2B',
#        '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV', 'name'],
#       dtype='object')

# %%
#Select columns for dataframe

mlb_df = mlb_teams[['yearID', 'lgID', 'G', 'G.1', 'W', 'L', 'WSWin', 'R', 'AB', 'H', '2B',
       '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV', 'name']]


mlb_df.tail(37)
# Out:
#       yearID lgID    G  G.1    W    L WSWin    R    AB     H  ...  3B   HR  \
# 1371    2018   AL  162   81   89   73     N  677  5513  1402  ...  32  176
# 1372    2018   NL  162   81   73   89     N  603  5541  1324  ...  30  133
# 1373    2018   NL  162   81   88   74     N  759  5498  1369  ...   9  205
# 1374    2018   AL  162   81   90   72     N  716  5475  1415  ...  43  150
# 1375    2018   AL  162   81   67   95     N  737  5453  1308  ...  24  194
# 1376    2018   AL  162   81   73   89     N  709  5477  1336  ...  16  217
# 1377    2018   NL  162   81   82   80     N  771  5517  1402  ...  25  191
# 1378    2019   NL  162   81   85   77     N  813  5633  1419  ...  40  220
# 1379    2019   NL  162   81   97   65     N  855  5560  1432  ...  29  249
# 1380    2019   AL  162   81   54  108     N  729  5596  1379  ...  25  213
# 1381    2019   AL  162   81   84   78     N  901  5770  1554  ...  27  245
# 1382    2019   AL  161   80   72   89     N  708  5529  1443  ...  20  182
# 1394  525  1334   28  4.18   1   10  50                Minnesota Twins
# 1395  569  1437   55  4.31   1    9  50               New York Yankees
# 1396  516  1384   56  4.24   3   12  38                  New York Mets
# 1397  578  1338   49  3.97   1   12  45              Oakland Athletics
# 1398  562  1453   78  4.53   3    7  36          Philadelphia Phillies
# 1399  425  1213   64  5.18   1    6  31             Pittsburgh Pirates
# 1400  504  1581   70  4.60   0    6  47               San Diego Padres
# 1401  588  1581  115  4.99   3    4  34               Seattle Mariners
# 1402  475  1435   47  4.38   1    8  41           San Francisco Giants
# 1403  561  1420  116  3.80   1   14  52            St. Louis Cardinals
# 1404  542  1493   94  3.65   0   12  46                 Tampa Bay Rays
# 1405  534  1578  131  5.06   4    9  33                  Texas Rangers
# 1406  509  1514   51  4.79   1    7  33              Toronto Blue Jays
# 1407  584  1308  116  4.27   1   13  40           Washington Nationals
#
# [37 rows x 21 columns]

# %%
#Use getdummies to convert strings

data_LG = mlb_df.copy()
data_bin = pd.get_dummies(data_LG, columns=["WSWin", 'lgID'])
data_bin = data_bin.drop(columns=['WSWin_N', 'lgID_AL'])

data_bin.head()
# Out:
#    yearID    G  G.1    W   L    R    AB     H   2B  3B  ...   BB   SO  SB  \
# 0    1969  162   81   93  69  691  5460  1411  195  22  ...  485  665  59
# 1    1969  162   81  109  53  779  5518  1465  234  29  ...  634  806  82
# 2    1969  162   81   87  75  743  5494  1381  234  37  ...  658  923  41
# 3    1969  163   81   71  91  528  5316  1221  151  29  ...  516  929  54
# 4    1969  162   81   68  94  625  5450  1346  210  27  ...  552  844  54
#
#     ERA  CG  SHO  SV               name WSWin_Y  lgID_NL
# 0  3.53  38    7  42     Atlanta Braves       0        1
# 1  2.83  50   20  36  Baltimore Orioles       0        0
# 2  3.92  30    7  41     Boston Red Sox       0        0
# 3  3.54  25    9  39  California Angels       0        0
# 4  4.21  29   10  25  Chicago White Sox       0        0
#
# [5 rows x 21 columns]

# %%
#Set X(data) and y(team)variables

data = data_bin.drop("name", axis = 1)
outcome = data_bin["name"]
print(data.shape, outcome.shape)
# Out:
# (1408, 20) (1408,)

# %% [markdown]
# Preprocess data

# %%
#Import SciKit libraries

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from tensorflow.keras.utils import to_categorical

# %%
#Split data and teams into training and test data

X_train, X_test, y_train, y_test = train_test_split(data, outcome, test_size = 0.2, random_state=42)
y_train
# Out:
# 1335        New York Yankees
# 579      St. Louis Cardinals
# 1137    Washington Nationals
# 48            Atlanta Braves
# 155      Los Angeles Dodgers
#                 ...
# 1095        New York Yankees
# 1130        San Diego Padres
# 1294         Cincinnati Reds
# 860       Pittsburgh Pirates
# 1126           New York Mets
# Name: name, Length: 1126, dtype: object

# %%
#Scale data using MinMaxScaler

X_scaler = StandardScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
X_train_scaled
# Out:
# array([[ 1.48844839,  0.25123133,  0.24703643, ..., -0.18573807,
#         -0.18941638, -0.99822538],
#        [-0.28249427,  0.25123133,  0.82254614, ...,  1.44393257,
#         -0.18941638,  1.00177778],
#        [ 1.01165613,  0.25123133,  0.24703643, ..., -0.07709336,
#         -0.18941638,  1.00177778],
#        ...,
#        [ 1.42033521,  0.25123133,  0.24703643, ..., -1.05489574,
#         -0.18941638,  1.00177778],
#        [ 0.39863752,  0.25123133,  0.24703643, ..., -0.18573807,
#         -0.18941638,  1.00177778],
#        [ 1.01165613,  0.25123133,  0.24703643, ..., -0.18573807,
#         -0.18941638,  1.00177778]])

# %%
##Import RandomForestClassifier and train
#from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=1000, random_state=1)
#classifier = MultiOutputClassifier(rf, n_jobs=-1)
rf.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=1000,
#                        n_jobs=None, oob_score=False, random_state=1, verbose=0,
#                        warm_start=False)

# %%
#Get Score for RandomForestClassifier
rf.score(X_test_scaled, y_test)
# Out:
# 0.2978723404255319

# %%
#Print data scores for training aand test datasets
print(f"Training Data Score: {rf.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {rf.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 1.0
# Testing Data Score: 0.2978723404255319

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {"bootstrap": [True],
              "max_depth": [20, 40, 100, 125],
#              "max_features": [2,3],
 #            "min_samples_leaf": [3, 4, 5],
              "n_estimators": [100, 500, 1000]
              }
grid = GridSearchCV(rf, param_grid, verbose=3)
grid
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=1000, n_jobs=None,
#                                               oob_score=False, random_state=1,
#                                               verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'bootstrap': [True], 'max_depth': [20, 40, 100, 125],
#                          'n_estimators': [100, 500, 1000]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %% [markdown]
# Train Model

# %%
# Train the model with GridSearch

grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] bootstrap=True, max_depth=20, n_estimators=100 ..................
# C:\Users\swill\Anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  bootstrap=True, max_depth=20, n_estimators=100, score=0.239, total=   0.9s
# [CV] bootstrap=True, max_depth=20, n_estimators=100 ..................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [CV]  bootstrap=True, max_depth=20, n_estimators=100, score=0.249, total=   0.9s
# [CV] bootstrap=True, max_depth=20, n_estimators=100 ..................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.7s remaining:    0.0s
# [CV]  bootstrap=True, max_depth=20, n_estimators=100, score=0.244, total=   0.9s
# [CV] bootstrap=True, max_depth=20, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=100, score=0.236, total=   0.9s
# [CV] bootstrap=True, max_depth=20, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=100, score=0.236, total=   0.9s
# [CV] bootstrap=True, max_depth=20, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=500, score=0.270, total=   4.4s
# [CV] bootstrap=True, max_depth=20, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=500, score=0.280, total=   4.5s
# [CV] bootstrap=True, max_depth=20, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=500, score=0.244, total=   4.7s
# [CV] bootstrap=True, max_depth=20, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=500, score=0.236, total=   4.5s
# [CV] bootstrap=True, max_depth=20, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=500, score=0.236, total=   4.5s
# [CV] bootstrap=True, max_depth=20, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=20, n_estimators=1000, score=0.261, total=   9.3s
# [CV] bootstrap=True, max_depth=20, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=20, n_estimators=1000, score=0.253, total=  10.1s
# [CV] bootstrap=True, max_depth=20, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=20, n_estimators=1000, score=0.258, total=   9.6s
# [CV] bootstrap=True, max_depth=20, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=20, n_estimators=1000, score=0.218, total=   9.3s
# [CV] bootstrap=True, max_depth=20, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=20, n_estimators=1000, score=0.236, total=   9.3s
# [CV] bootstrap=True, max_depth=40, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=100, score=0.261, total=   0.9s
# [CV] bootstrap=True, max_depth=40, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=100, score=0.240, total=   0.9s
# [CV] bootstrap=True, max_depth=40, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=100, score=0.267, total=   0.9s
# [CV] bootstrap=True, max_depth=40, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=100, score=0.227, total=   0.9s
# [CV] bootstrap=True, max_depth=40, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=100, score=0.231, total=   0.9s
# [CV] bootstrap=True, max_depth=40, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=500, score=0.257, total=   4.5s
# [CV] bootstrap=True, max_depth=40, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=500, score=0.276, total=   4.7s
# [CV] bootstrap=True, max_depth=40, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=500, score=0.240, total=   4.7s
# [CV] bootstrap=True, max_depth=40, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=500, score=0.236, total=   4.6s
# [CV] bootstrap=True, max_depth=40, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=500, score=0.244, total=   4.8s
# [CV] bootstrap=True, max_depth=40, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=40, n_estimators=1000, score=0.265, total=   9.7s
# [CV] bootstrap=True, max_depth=40, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=40, n_estimators=1000, score=0.262, total=   9.7s
# [CV] bootstrap=True, max_depth=40, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=40, n_estimators=1000, score=0.258, total=   9.2s
# [CV] bootstrap=True, max_depth=40, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=40, n_estimators=1000, score=0.231, total=   9.4s
# [CV] bootstrap=True, max_depth=40, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=40, n_estimators=1000, score=0.240, total=   9.3s
# [CV] bootstrap=True, max_depth=100, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=100, score=0.261, total=   0.9s
# [CV] bootstrap=True, max_depth=100, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=100, score=0.240, total=   1.0s
# [CV] bootstrap=True, max_depth=100, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=100, score=0.267, total=   0.9s
# [CV] bootstrap=True, max_depth=100, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=100, score=0.227, total=   0.9s
# [CV] bootstrap=True, max_depth=100, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=100, score=0.231, total=   0.9s
# [CV] bootstrap=True, max_depth=100, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=500, score=0.257, total=   4.7s
# [CV] bootstrap=True, max_depth=100, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=500, score=0.276, total=   4.6s
# [CV] bootstrap=True, max_depth=100, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=500, score=0.240, total=   5.1s
# [CV] bootstrap=True, max_depth=100, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=500, score=0.236, total=   5.1s
# [CV] bootstrap=True, max_depth=100, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=500, score=0.244, total=   4.8s
# [CV] bootstrap=True, max_depth=100, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=100, n_estimators=1000, score=0.265, total=   9.4s
# [CV] bootstrap=True, max_depth=100, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=100, n_estimators=1000, score=0.262, total=   9.3s
# [CV] bootstrap=True, max_depth=100, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=100, n_estimators=1000, score=0.258, total=   9.2s
# [CV] bootstrap=True, max_depth=100, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=100, n_estimators=1000, score=0.231, total=   9.0s
# [CV] bootstrap=True, max_depth=100, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=100, n_estimators=1000, score=0.240, total=   9.7s
# [CV] bootstrap=True, max_depth=125, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=100, score=0.261, total=   1.2s
# [CV] bootstrap=True, max_depth=125, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=100, score=0.240, total=   0.9s
# [CV] bootstrap=True, max_depth=125, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=100, score=0.267, total=   0.9s
# [CV] bootstrap=True, max_depth=125, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=100, score=0.227, total=   0.9s
# [CV] bootstrap=True, max_depth=125, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=100, score=0.231, total=   1.0s
# [CV] bootstrap=True, max_depth=125, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=500, score=0.257, total=   5.8s
# [CV] bootstrap=True, max_depth=125, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=500, score=0.276, total=   5.1s
# [CV] bootstrap=True, max_depth=125, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=500, score=0.240, total=   5.4s
# [CV] bootstrap=True, max_depth=125, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=500, score=0.236, total=   4.7s
# [CV] bootstrap=True, max_depth=125, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=500, score=0.244, total=   4.9s
# [CV] bootstrap=True, max_depth=125, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=125, n_estimators=1000, score=0.265, total=   9.3s
# [CV] bootstrap=True, max_depth=125, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=125, n_estimators=1000, score=0.262, total=   9.5s
# [CV] bootstrap=True, max_depth=125, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=125, n_estimators=1000, score=0.258, total=   8.8s
# [CV] bootstrap=True, max_depth=125, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=125, n_estimators=1000, score=0.231, total=   8.8s
# [CV] bootstrap=True, max_depth=125, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=125, n_estimators=1000, score=0.240, total=   9.3s
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:  5.1min finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=1000, n_jobs=None,
#                                               oob_score=False, random_state=1,
#                                               verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'bootstrap': [True], 'max_depth': [20, 40, 100, 125],
#                          'n_estimators': [100, 500, 1000]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
#Print best parameter and score 

print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'bootstrap': True, 'max_depth': 20, 'n_estimators': 500}
# 0.2530934119960669

# %% [markdown]
# Evaluate Model

# %%
#Make prediction using test data

predictions = grid.predict(X_test_scaled)
print('Test Acc: %.3f' % grid.score(X_test_scaled, y_test))
# Out:
# Test Acc: 0.305

# %% [markdown]
# Predict World Series Champs

# %%
print('Test Acc: %.3f' % grid.score(X_test_scaled, y_test))
# Out:
# Test Acc: 0.305

# %%
# Calculate classification report
from sklearn.metrics import classification_report
predictions = rf.predict(X_test_scaled)
print(classification_report(y_test, predictions))
# Out:
#                                precision    recall  f1-score   support
#
#                Anaheim Angels       0.00      0.00      0.00         3
#          Arizona Diamondbacks       1.00      0.29      0.44         7
#                Atlanta Braves       0.27      0.40      0.32        10
#             Baltimore Orioles       0.55      0.43      0.48        14
#                Boston Red Sox       0.47      0.73      0.57        11
#             California Angels       0.33      0.14      0.20         7
#                  Chicago Cubs       0.30      0.33      0.32         9
#             Chicago White Sox       0.22      0.50      0.31         8
#               Cincinnati Reds       0.29      0.62      0.40         8
#             Cleveland Indians       0.36      0.40      0.38        10
#              Colorado Rockies       0.38      0.83      0.53         6
#                Detroit Tigers       0.43      0.33      0.38         9
#               Florida Marlins       0.50      0.25      0.33         4
#                Houston Astros       0.25      0.11      0.15         9
#            Kansas City Royals       0.54      0.58      0.56        12
# Los Angeles Angels of Anaheim       0.67      0.67      0.67         3
#           Los Angeles Dodgers       0.23      0.43      0.30         7
#                 Miami Marlins       0.00      0.00      0.00         1
#             Milwaukee Brewers       0.00      0.00      0.00        16
#               Minnesota Twins       0.17      0.25      0.20         8
#                Montreal Expos       0.00      0.00      0.00         7
#                 New York Mets       0.00      0.00      0.00        13
#              New York Yankees       0.40      0.33      0.36        12
#             Oakland Athletics       0.42      0.50      0.45        10
#         Philadelphia Phillies       0.14      0.22      0.17         9
#            Pittsburgh Pirates       0.20      0.25      0.22        12
#              San Diego Padres       0.25      0.22      0.24         9
#          San Francisco Giants       0.21      0.30      0.25        10
#              Seattle Mariners       0.14      0.17      0.15         6
#           St. Louis Cardinals       0.67      0.15      0.25        13
#          Tampa Bay Devil Rays       0.00      0.00      0.00         2
#                 Texas Rangers       0.00      0.00      0.00         3
#             Toronto Blue Jays       0.17      0.09      0.12        11
#          Washington Nationals       0.00      0.00      0.00         2
#           Washington Senators       0.00      0.00      0.00         1
#
#                      accuracy                           0.30       282
#                     macro avg       0.27      0.27      0.25       282
#                  weighted avg       0.30      0.30      0.28       282
# C:\Users\swill\Anaconda3\envs\PythonData\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import joblib
filename = 'SWilliams_RFC.sav'
joblib.dump(rf, filename)
# Out:
# ['SWilliams_RFC.sav']
