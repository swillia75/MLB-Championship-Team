shape)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-ae80b55dfafd> in <module>
# ----> 1 data = data_bin.drop("lgID", axis = 1)
#       2 outcome = data_bin["lgID"]
#       3 print(data.shape, outcome.shape)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5015         if mask.any():
#    5016             if errors != "ignore":
# -> 5017                 raise KeyError(f"{labels[mask]} not found in axis")
#    5018             indexer = indexer[~mask]
#    5019         return self.delete(indexer)
#
# KeyError: "['lgID'] not found in axis"

# %% [markdown]
# Preprocess data

# %%
#Import SciKit libraries

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
#Split data and teams into training and test data

X_train, X_test, y_train, y_test = train_test_split(data, outcome, random_state=1)
y_train
# Out:
# 503     NL
# 842     AL
# 419     AL
# 493     AL
# 325     AL
#         ..
# 715     NL
# 905     NL
# 1096    AL
# 235     NL
# 1061    AL
# Name: lgID, Length: 921, dtype: object

# %%
#Scale data using StandarScaler

X_scaler = StandardScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
X_train_scaled
# Out:
# array([[ 0.42165868,  0.22603988,  0.22503865, ...,  0.29503273,
#          2.29677766, -0.18663189],
#        [-0.63077397,  0.11140181,  0.22503865, ..., -0.65755322,
#          0.36780557, -0.18663189],
#        [ 0.64717997,  0.22603988,  0.45180079, ...,  0.05688624,
#          0.36780557, -0.18663189],
#        ...,
#        [-1.38251158,  0.22603988,  0.22503865, ...,  0.7713257 ,
#         -2.20415721, -0.18663189],
#        [ 1.09822253,  0.22603988,  0.22503865, ..., -0.41940673,
#         -0.38235024, -0.18663189],
#        [-1.23216405,  0.22603988,  0.22503865, ...,  1.24761867,
#         -2.41848744, -0.18663189]])

# %%
#Import and use SVC MODEL
from sklearn.svm import SVC 
model = SVC(kernel='linear')
model.fit(X_train_scaled, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
#Print training and test scores from model using datasets

print(f"Training Data Score: {model.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {model.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.749185667752443
# Testing Data Score: 0.7175324675324676

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [100, 500, 1000],
              'gamma': [0.0001, 0.005, 0.001]}
grid = GridSearchCV(model, param_grid, verbose=3)

# %%
# Train the model with GridSearch

grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] C=100, gamma=0.0001 .............................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ................. C=100, gamma=0.0001, score=0.735, total=   2.3s
# [CV] C=100, gamma=0.0001 .............................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.2s remaining:    0.0s
# [CV] ................. C=100, gamma=0.0001, score=0.734, total=   2.6s
# [CV] C=100, gamma=0.0001 .............................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.7s remaining:    0.0s
# [CV] ................. C=100, gamma=0.0001, score=0.696, total=   2.6s
# [CV] C=100, gamma=0.0001 .............................................
# [CV] ................. C=100, gamma=0.0001, score=0.793, total=   3.9s
# [CV] C=100, gamma=0.0001 .............................................
# [CV] ................. C=100, gamma=0.0001, score=0.739, total=   3.7s
# [CV] C=100, gamma=0.005 ..............................................
# [CV] .................. C=100, gamma=0.005, score=0.735, total=   2.4s
# [CV] C=100, gamma=0.005 ..............................................
# [CV] .................. C=100, gamma=0.005, score=0.734, total=   3.0s
# [CV] C=100, gamma=0.005 ..............................................
# [CV] .................. C=100, gamma=0.005, score=0.696, total=   2.8s
# [CV] C=100, gamma=0.005 ..............................................
# [CV] .................. C=100, gamma=0.005, score=0.793, total=   4.2s
# [CV] C=100, gamma=0.005 ..............................................
# [CV] .................. C=100, gamma=0.005, score=0.739, total=   3.9s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] .................. C=100, gamma=0.001, score=0.735, total=   2.3s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] .................. C=100, gamma=0.001, score=0.734, total=   2.6s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] .................. C=100, gamma=0.001, score=0.696, total=   2.5s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] .................. C=100, gamma=0.001, score=0.793, total=   4.0s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] .................. C=100, gamma=0.001, score=0.739, total=   3.8s
# [CV] C=500, gamma=0.0001 .............................................
# [CV] ................. C=500, gamma=0.0001, score=0.730, total=  12.4s
# [CV] C=500, gamma=0.0001 .............................................
# [CV] ................. C=500, gamma=0.0001, score=0.734, total=  10.6s
# [CV] C=500, gamma=0.0001 .............................................
# [CV] ................. C=500, gamma=0.0001, score=0.696, total=  15.7s
# [CV] C=500, gamma=0.0001 .............................................
# [CV] ................. C=500, gamma=0.0001, score=0.799, total=  19.1s
# [CV] C=500, gamma=0.0001 .............................................
# [CV] ................. C=500, gamma=0.0001, score=0.750, total=  23.9s
# [CV] C=500, gamma=0.005 ..............................................
# [CV] .................. C=500, gamma=0.005, score=0.730, total=  15.0s
# [CV] C=500, gamma=0.005 ..............................................
# [CV] .................. C=500, gamma=0.005, score=0.734, total=  12.5s
# [CV] C=500, gamma=0.005 ..............................................
# [CV] .................. C=500, gamma=0.005, score=0.696, total=  19.9s
# [CV] C=500, gamma=0.005 ..............................................
# [CV] .................. C=500, gamma=0.005, score=0.799, total=  22.9s
# [CV] C=500, gamma=0.005 ..............................................
# [CV] .................. C=500, gamma=0.005, score=0.750, total=  22.7s
# [CV] C=500, gamma=0.001 ..............................................
# [CV] .................. C=500, gamma=0.001, score=0.730, total=  13.1s
# [CV] C=500, gamma=0.001 ..............................................
# [CV] .................. C=500, gamma=0.001, score=0.734, total=  10.5s
# [CV] C=500, gamma=0.001 ..............................................
# [CV] .................. C=500, gamma=0.001, score=0.696, total=  15.1s
# [CV] C=500, gamma=0.001 ..............................................
# [CV] .................. C=500, gamma=0.001, score=0.799, total=  17.5s
# [CV] C=500, gamma=0.001 ..............................................
# [CV] .................. C=500, gamma=0.001, score=0.750, total=  22.2s
# [CV] C=1000, gamma=0.0001 ............................................
# [CV] ................ C=1000, gamma=0.0001, score=0.730, total=  25.5s
# [CV] C=1000, gamma=0.0001 ............................................
# [CV] ................ C=1000, gamma=0.0001, score=0.734, total=  21.1s
# [CV] C=1000, gamma=0.0001 ............................................
# [CV] ................ C=1000, gamma=0.0001, score=0.696, total= 2.7min
# [CV] C=1000, gamma=0.0001 ............................................
# [CV] ................ C=1000, gamma=0.0001, score=0.793, total=  25.3s
# [CV] C=1000, gamma=0.0001 ............................................
# [CV] ................ C=1000, gamma=0.0001, score=0.745, total=  25.2s
# [CV] C=1000, gamma=0.005 .............................................
# [CV] ................. C=1000, gamma=0.005, score=0.730, total=  26.2s
# [CV] C=1000, gamma=0.005 .............................................
# [CV] ................. C=1000, gamma=0.005, score=0.734, total=  20.4s
# [CV] C=1000, gamma=0.005 .............................................
# [CV] ................. C=1000, gamma=0.005, score=0.696, total=  30.1s
# [CV] C=1000, gamma=0.005 .............................................
# [CV] ................. C=1000, gamma=0.005, score=0.793, total=  25.1s
# [CV] C=1000, gamma=0.005 .............................................
# [CV] ................. C=1000, gamma=0.005, score=0.745, total=  25.4s
# [CV] C=1000, gamma=0.001 .............................................
# [CV] ................. C=1000, gamma=0.001, score=0.730, total=  25.0s
# [CV] C=1000, gamma=0.001 .............................................
# [CV] ................. C=1000, gamma=0.001, score=0.734, total=  19.4s
# [CV] C=1000, gamma=0.001 .............................................
# [CV] ................. C=1000, gamma=0.001, score=0.696, total=  28.4s
# [CV] C=1000, gamma=0.001 .............................................
# [CV] ................. C=1000, gamma=0.001, score=0.793, total=  25.4s
# [CV] C=1000, gamma=0.001 .............................................
# [CV] ................. C=1000, gamma=0.001, score=0.745, total=  26.8s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed: 13.5min finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=SVC(C=1.0, break_ties=False, cache_size=200,
#                            class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='scale', kernel='linear', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'C': [100, 500, 1000],
#                          'gamma': [0.0001, 0.005, 0.001]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %% [markdown]
# Train Model

# %%
#Print best parameters and score from Gridsearch

print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'C': 500, 'gamma': 0.0001}
# 0.7415981198589894

# %%
#Print accuracy of model using test dataset

print('Test Acc: %.3f' % grid.score(X_test_scaled, y_test))
# Out:
# Test Acc: 0.721

# %% [markdown]
# Evaluate Model

# %% [markdown]
# Predict World Series Champs

# %%
#Read in CSV and create dataframe
mlb_teams2015= pd.read_csv("2015.csv")



mlb2015_df = mlb_teams2015[['yearID', 'lgID', 'G', 'G.1', 'W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H', '2B',
       '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV']]


data_LG2015 = mlb2015_df.copy()
data_bin2015 = pd.get_dummies(data_LG2015, columns=["WSWin"])
data_bin2015 = data_bin2015.drop(columns=['WSWin_N'])



feature2015 = data_bin2015.drop("lgID", axis=1)
team2015 = data_bin2015["lgID"]

X_feature2015_scaler = StandardScaler().fit(feature2015)
X_feature2015_scaled = X_feature2015_scaler.transform(feature2015)

#Make prediction using test data

predictions2015 = grid.predict(X_feature2015_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2015_scaled, team2015))



predictions2015 = model.predict(X_feature2015_scaled)
predictions2015
# Out:
# Test Acc: 0.767
# array(['NL', 'AL', 'NL', 'AL', 'NL', 'AL', 'NL', 'AL', 'AL', 'AL', 'NL',
#        'AL', 'NL', 'NL', 'NL', 'NL', 'NL', 'NL', 'AL', 'AL', 'NL', 'NL',
#        'NL', 'AL', 'AL', 'NL', 'NL', 'AL', 'AL', 'NL'], dtype=object)

# %%
#Read in CSV and create dataframe
mlb_teams2016= pd.read_csv("2016.csv")



mlb2016_df = mlb_teams2016[['yearID', 'lgID', 'G', 'G.1', 'W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H', '2B',
       '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV']]


data_LG2016 = mlb2016_df.copy()
data_bin2016 = pd.get_dummies(data_LG2016, columns=["WSWin"])
data_bin2016 = data_bin2016.drop(columns=['WSWin_N'])



feature2016 = data_bin2016.drop("lgID", axis=1)
team2016 = data_bin2016["lgID"]

X_feature2016_scaler = StandardScaler().fit(feature2016)
X_feature2016_scaled = X_feature2016_scaler.transform(feature2016)

#Make prediction using test data

predictions2016 = grid.predict(X_feature2016_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2016_scaled, team2016))



predictions2016 = model.predict(X_feature2016_scaled)
predictions2016
# Out:
# Test Acc: 0.567
# array(['NL', 'NL', 'AL', 'AL', 'NL', 'AL', 'NL', 'AL', 'AL', 'AL', 'NL',
#        'NL', 'AL', 'NL', 'AL', 'NL', 'AL', 'NL', 'NL', 'AL', 'NL', 'AL',
#        'NL', 'AL', 'AL', 'NL', 'NL', 'AL', 'NL', 'NL'], dtype=object)

# %%
#Read in CSV and create dataframe
mlb_teams2017= pd.read_csv("2017.csv")



mlb2017_df = mlb_teams2017[['yearID', 'lgID', 'G', 'G.1', 'W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H', '2B',
       '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV']]


data_LG2017 = mlb2017_df.copy()
data_bin2017 = pd.get_dummies(data_LG2017, columns=["WSWin"])
data_bin2017 = data_bin2017.drop(columns=['WSWin_N'])



feature2017 = data_bin2017.drop("lgID", axis=1)
team2017 = data_bin2017["lgID"]

X_feature2017_scaler = StandardScaler().fit(feature2017)
X_feature2017_scaled = X_feature2017_scaler.transform(feature2017)

#Make prediction using test data

predictions2017 = grid.predict(X_feature2017_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2017_scaled, team2017))



predictions2017 = model.predict(X_feature2017_scaled)
predictions2017
# Out:
# Test Acc: 0.667
# array(['NL', 'NL', 'AL', 'AL', 'NL', 'NL', 'AL', 'AL', 'NL', 'AL', 'AL',
#        'AL', 'NL', 'NL', 'AL', 'NL', 'AL', 'AL', 'AL', 'NL', 'NL', 'NL',
#        'NL', 'AL', 'AL', 'AL', 'NL', 'NL', 'AL', 'AL'], dtype=object)

# %%
#Predict 2018 WS winner (division)
mlb_teams2018= pd.read_csv("2018.csv")



mlb2018_df = mlb_teams2018[['yearID', 'lgID', 'G', 'G.1', 'W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H', '2B',
       '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV']]


data_LG2018 = mlb2018_df.copy()
data_bin2018 = pd.get_dummies(data_LG2018, columns=["WSWin"])
data_bin2018 = data_bin2018.drop(columns=['WSWin_N'])



feature2018 = data_bin2018.drop("lgID", axis=1)
team2018 = data_bin2018["lgID"]

X_feature2018_scaler = StandardScaler().fit(feature2018)
X_feature2018_scaled = X_feature2018_scaler.transform(feature2018)

#Make prediction using test data

predictions2018 = grid.predict(X_feature2018_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2018_scaled, team2018))



predictions2018 = model.predict(X_feature2018_scaled)
predictions2018
# Out:
# Test Acc: 0.633
# array(['NL', 'AL', 'AL', 'AL', 'NL', 'NL', 'NL', 'AL', 'NL', 'NL', 'AL',
#        'AL', 'NL', 'NL', 'NL', 'NL', 'AL', 'AL', 'AL', 'AL', 'NL', 'AL',
#        'NL', 'NL', 'AL', 'AL', 'NL', 'NL', 'NL', 'AL'], dtype=object)

# %%
#Predict 2019 WS winner (division)
mlb_teams2019= pd.read_csv("MLB 2019 season.csv")



mlb2019_df = mlb_teams2019[['yearID', 'lgID', 'G', 'G.1', 'W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H', '2B',
       '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV']]


data_LG2019 = mlb2019_df.copy()
data_bin2019 = pd.get_dummies(data_LG2019, columns=["WSWin"])
data_bin2019 = data_bin2019.drop(columns=['WSWin_N'])



feature2019 = data_bin2019.drop("lgID", axis=1)
team2019 = data_bin2019["lgID"]

X_feature2019_scaler = StandardScaler().fit(feature2019)
X_feature2019_scaled = X_feature2019_scaler.transform(feature2019)

#Make prediction using test data

predictions2019 = grid.predict(X_feature2019_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2019_scaled, team2019))



predictions2019 = rf.predict(X_feature2019_scaled)
predictions2019
# Out:
# Test Acc: 0.633
# array(['NL', 'NL', 'NL', 'AL', 'AL', 'NL', 'NL', 'AL', 'NL', 'NL', 'AL',
#        'NL', 'NL', 'AL', 'NL', 'NL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL',
#        'NL', 'AL', 'NL', 'NL', 'NL', 'AL', 'NL', 'AL'], dtype=object)

# %%
#Read in CSV and create dataframe
mlb_teams2020= pd.read_csv("2020.csv")



mlb2020_df = mlb_teams2020[['yearID', 'lgID', 'G', 'G.1', 'W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H', '2B',
       '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV']]


data_LG2020 = mlb2020_df.copy()
data_bin2020 = pd.get_dummies(data_LG2020, columns=["WSWin"])

feature2020 = data_bin2020.drop("lgID", axis=1)
team2020 = data_bin2020["lgID"]

X_feature2020_scaler = StandardScaler().fit(feature2020)
X_feature2020_scaled = X_feature2020_scaler.transform(feature2020)

#Make prediction using test data

predictions2020 = grid.predict(X_feature2020_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2020_scaled, team2020))


predictions2020 = model.predict(X_feature2020_scaled)
predictions2020
# Out:
# Test Acc: 0.467
# array(['NL', 'NL', 'AL', 'NL', 'AL', 'NL', 'AL', 'NL', 'NL', 'NL', 'NL',
#        'AL', 'AL', 'AL', 'NL', 'NL', 'NL', 'NL', 'AL', 'NL', 'AL', 'AL',
#        'AL', 'AL', 'AL', 'AL', 'NL', 'AL', 'AL', 'AL'], dtype=object)

# %%
import joblib
filename = 'SWilliams_SVM.sav'
joblib.dump(model, filename)
# Out:
# ['SWilliams_SVM.sav']
