# %%
#import numpy to use seed 
import numpy as np
import pandas as pd
from numpy.random import seed
np.random.seed(1)

# %%
#import other dependencies

import os
import tensorflow 
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense

# %% [markdown]
# Read CSV create, and clean dataframe

# %%
#Read in CSV and create dataframe
mlb_teams= pd.read_csv("Team Statistics.csv")

mlb_teams
# Out:
#         YR                  Name  ID    G    W  WPCT   L WSWin    R     H  \
# 0     1969        Atlanta Braves   3  162   93  0.57  69     N  691  1411
# 1     1969     Baltimore Orioles   4  162  109  0.67  53     N  779  1465
# 2     1969        Boston Red Sox   5  162   87  0.54  75     N  743  1381
# 3     1969     California Angels   6  163   71  0.44  91     N  528  1221
# 4     1969     Chicago White Sox   8  162   68  0.42  94     N  625  1346
# ...    ...                   ...  ..  ...  ...   ...  ..   ...  ...   ...
# 1403  2019   St. Louis Cardinals  31  162   91  0.56  71     N  764  1336
# 1404  2019        Tampa Bay Rays  33  162   96  0.59  66     N  769  1427
# 1405  2019         Texas Rangers  34  162   78  0.48  84     N  810  1374
# 1406  2019     Toronto Blue Jays  35  162   67  0.41  95     N  726  1299
# 1407  2019  Washington Nationals  36  162   93  0.57  69     Y  873  1460
#
#        2B  3B   HR   BB    SO   ERA  SHO  SV     FP
# 0     195  22  141  485   665  3.53    7  42  0.981
# 1     234  29  175  634   806  2.83   20  36  0.984
# 2     234  37  197  658   923  3.92    7  41  0.975
# 3     151  29   88  516   929  3.54    9  39  0.978
# 4     210  27  112  552   844  4.21   10  25  0.981
# ...   ...  ..  ...  ...   ...   ...  ...  ..    ...
# 1403  246  24  210  561  1420  3.80   14  52  0.989
# 1404  291  29  217  542  1493  3.65   12  46  0.985
# 1405  296  24  223  534  1578  5.06    9  33  0.982
# 1406  270  21  247  509  1514  4.79    7  33  0.984
# 1407  298  27  231  584  1308  4.27   13  40  0.985
#
# [1408 rows x 19 columns]

# %%
#Get list of dataframe columns

mlb_teams.columns
# Out:
# Index(['YR', 'Name', 'ID', 'G', 'W', 'WPCT', 'L', 'WSWin', 'R', 'H', '2B',
#        '3B', 'HR', 'BB', 'SO', 'ERA', 'SHO', 'SV', 'FP'],
#       dtype='object')

# %%
#Select columns for dataframe

mlb_df = mlb_teams[['YR', 'Name', 'WPCT', 'WSWin', 'R', 'H',
                   '2B', '3B', 'HR', 'BB', 'SO', 'ERA', 'SHO', 'SV', 'FP']]
mlb_df.tail(37)
# Out:
#         YR                           Name  WPCT WSWin    R     H   2B  3B  \
# 1371  2018               Seattle Mariners  0.55     N  677  1402  256  32
# 1372  2018           San Francisco Giants  0.45     N  603  1324  255  30
# 1373  2018            St. Louis Cardinals  0.54     N  759  1369  248   9
# 1374  2018                 Tampa Bay Rays  0.56     N  716  1415  274  43
# 1375  2018                  Texas Rangers  0.41     N  737  1308  266  24
# 1376  2018              Toronto Blue Jays  0.45     N  709  1336  320  16
# 1377  2018           Washington Nationals  0.51     N  771  1402  284  25
# 1378  2019           Arizona Diamondbacks  0.52     N  813  1419  288  40
# 1379  2019                 Atlanta Braves  0.60     N  855  1432  277  29
# 1380  2019              Baltimore Orioles  0.33     N  729  1379  252  25
# 1381  2019                 Boston Red Sox  0.52     N  901  1554  345  27
# 1382  2019              Chicago White Sox  0.45     N  708  1443  260  20
# 1383  2019                   Chicago Cubs  0.52     N  814  1378  270  26
# 1384  2019                Cincinnati Reds  0.46     N  701  1328  235  27
# 1385  2019              Cleveland Indians  0.57     N  769  1354  286  18
# 1386  2019               Colorado Rockies  0.44     N  835  1502  323  41
# 1387  2019                 Detroit Tigers  0.29     N  582  1333  292  41
# 1388  2019                 Houston Astros  0.66     N  920  1538  323  28
# 1389  2019             Kansas City Royals  0.36     N  691  1356  281  40
# 1390  2019  Los Angeles Angels of Anaheim  0.44     N  769  1368  268  21
# 1391  2019            Los Angeles Dodgers  0.65     N  886  1414  302  20
# 1392  2019                  Miami Marlins  0.35     N  615  1326  265  18
# 1393  2019              Milwaukee Brewers  0.55     N  769  1366  279  17
# 1394  2019                Minnesota Twins  0.62     N  939  1547  318  23
# 1395  2019               New York Yankees  0.64     N  943  1493  290  17
# 1396  2019                  New York Mets  0.53     N  791  1445  280  17
# 1397  2019              Oakland Athletics  0.60     N  845  1384  292  23
# 1398  2019          Philadelphia Phillies  0.50     N  774  1369  311  26
# 1399  2019             Pittsburgh Pirates  0.43     N  758  1497  315  38
# 1400  2019               San Diego Padres  0.43     N  682  1281  224  24
# 1401  2019               Seattle Mariners  0.42     N  758  1305  254  28
# 1402  2019           San Francisco Giants  0.48     N  678  1332  300  26
# 1403  2019            St. Louis Cardinals  0.56     N  764  1336  246  24
# 1404  2019                 Tampa Bay Rays  0.59     N  769  1427  291  29
# 1405  2019                  Texas Rangers  0.48     N  810  1374  296  24
# 1406  2019              Toronto Blue Jays  0.41     N  726  1299  270  21
# 1407  2019           Washington Nationals  0.57     Y  873  1460  298  27
#
#        HR   BB    SO   ERA  SHO  SV     FP
# 1371  176  430  1221  4.13   12  60  0.985
# 1372  133  448  1467  3.95   15  36  0.984
# 1373  205  525  1380  3.85    8  43  0.978
# 1374  150  540  1388  3.74   14  52  0.986
# 1375  194  555  1484  4.92    5  42  0.980
# 1376  217  499  1387  4.85    3  39  0.983
# 1377  191  631  1289  4.04    7  40  0.989
# 1378  220  540  1360  4.25   11  45  0.986
# 1379  249  619  1467  4.19    8  44  0.987
# 1380  213  462  1435  5.59    5  27  0.982
# 1381  245  590  1382  4.70    8  33  0.985
# 1382  182  378  1549  4.90    7  33  0.980
# 1383  256  581  1460  4.10   10  38  0.981
# 1384  227  492  1436  4.18   10  46  0.984
# 1385  223  563  1332  3.76   16  42  0.985
# 1386  224  489  1503  5.56    5  28  0.984
# 1387  149  391  1595  5.24    3  31  0.981
# 1388  288  645  1166  3.66   14  47  0.988
# 1389  162  456  1405  5.20    7  37  0.988
# 1390  220  586  1276  5.12    2  32  0.984
# 1391  279  607  1356  3.37   18  44  0.982
# 1392  146  395  1469  4.74    8  27  0.984
# 1393  250  629  1563  4.40    7  50  0.983
# 1394  307  525  1334  4.18   10  50  0.981
# 1395  306  569  1437  4.31    9  50  0.982
# 1396  242  516  1384  4.24   12  38  0.983
# 1397  257  578  1338  3.97   12  45  0.987
# 1398  215  562  1453  4.53    7  36  0.984
# 1399  163  425  1213  5.18    6  31  0.980
# 1400  219  504  1581  4.60    6  47  0.980
# 1401  239  588  1581  4.99    4  34  0.978
# 1402  167  475  1435  4.38    8  41  0.985
# 1403  210  561  1420  3.80   14  52  0.989
# 1404  217  542  1493  3.65   12  46  0.985
# 1405  223  534  1578  5.06    9  33  0.982
# 1406  247  509  1514  4.79    7  33  0.984
# 1407  231  584  1308  4.27   13  40  0.985

# %%
#Use getdummies to convert strings

data_LG = mlb_df.copy()
data_bin = pd.get_dummies(data_LG, columns=["WSWin"])
data_bin = data_bin.drop(columns=['WSWin_N'])

data_bin.head()
# Out:
#      YR               Name  WPCT    R     H   2B  3B   HR   BB   SO   ERA  \
# 0  1969     Atlanta Braves  0.57  691  1411  195  22  141  485  665  3.53
# 1  1969  Baltimore Orioles  0.67  779  1465  234  29  175  634  806  2.83
# 2  1969     Boston Red Sox  0.54  743  1381  234  37  197  658  923  3.92
# 3  1969  California Angels  0.44  528  1221  151  29   88  516  929  3.54
# 4  1969  Chicago White Sox  0.42  625  1346  210  27  112  552  844  4.21
#
#    SHO  SV     FP  WSWin_Y
# 0    7  42  0.981        0
# 1   20  36  0.984        0
# 2    7  41  0.975        0
# 3    9  39  0.978        0
# 4   10  25  0.981        0

# %%
#Set X(data) and y(team)variables

data = data_bin.drop("Name", axis = 1)
outcome = data_bin["Name"]
print(data.shape, outcome.shape)
# Out:
# (1408, 14) (1408,)

# %% [markdown]
# Preprocess data

# %%
#Import SciKit libraries

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

# %%
#Split data and teams into training and test data

X_train, X_test, y_train, y_test = train_test_split(data, outcome, random_state=42)
y_train
# Out:
# 497     Pittsburgh Pirates
# 881     Kansas City Royals
# 1370      San Diego Padres
# 846      Cleveland Indians
# 10      Kansas City Royals
#                ...
# 1095      New York Yankees
# 1130      San Diego Padres
# 1294       Cincinnati Reds
# 860     Pittsburgh Pirates
# 1126         New York Mets
# Name: Name, Length: 1056, dtype: object

# %%
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)
encoded_y_test
# Out:
# array([ 6, 30, 28,  2,  4, 34, 23, 25,  3,  5, 18, 18, 35, 35, 25, 16, 10,
#         9, 25, 23, 34, 11, 34, 30, 34, 22, 26, 10, 11, 21,  7, 34, 20,  7,
#         8,  3, 27,  7, 25,  6,  6,  9,  2, 26, 22, 25,  3, 21, 21, 21, 11,
#         9, 30,  4,  7, 18, 12, 10,  0, 26, 26, 26, 30, 30, 28, 13, 28,  5,
#        18,  4, 10,  9,  8, 17, 18, 24, 23, 22, 20, 30, 25, 13,  6, 22, 25,
#        15,  7, 21, 23, 30, 33,  6,  4,  5, 15,  9,  6,  2, 23,  5, 16, 25,
#        19, 13, 18, 16,  1, 23, 11, 13, 14,  2,  4, 26, 33,  2, 22, 21, 34,
#        18, 18, 23,  8, 14,  1, 30, 18, 14, 25, 28,  2, 13, 13, 12, 19, 22,
#        14, 18, 27, 27, 22, 25, 19,  8,  2,  4, 18, 13,  2, 30,  9,  1, 16,
#        28, 28, 26, 16, 22,  1, 34, 19, 27, 23, 14, 25, 16, 30,  3,  4, 27,
#         3,  4,  1, 27, 19, 27, 18, 14,  3,  3, 10, 36, 16, 24, 21,  3,  4,
#        27, 14, 21, 14, 11, 34,  3, 20, 24, 24,  7, 27, 11, 21, 13,  3,  8,
#        15, 21, 12, 22,  6, 21, 18, 22,  1, 20, 34,  6,  9, 12, 19, 24,  3,
#        18, 30,  2,  1, 27, 21, 11, 23, 31, 34, 31, 22, 10, 26, 24,  3, 20,
#        19, 21, 14,  7,  5, 11, 11,  0, 19, 20, 14, 22,  2,  0,  6, 20, 14,
#         5,  7, 18, 30,  8,  9,  5, 23, 18, 30,  8, 13,  9,  3,  3,  8, 24,
#         9, 24,  4, 34, 33, 14,  4, 26, 25, 24, 22, 30, 35,  2, 16, 20, 35,
#         7, 12, 27, 32,  2, 15, 14,  8,  7,  9,  7,  4, 28, 15, 11, 27,  4,
#         6, 34, 18, 21, 20, 16,  4, 21, 14, 16,  8,  8, 22, 21, 12, 18,  2,
#        33, 34, 28, 13,  2, 24,  8, 19, 21,  4, 16,  8, 34, 30, 19,  8,  4,
#        26, 27,  9, 23,  1, 26, 32,  8, 23,  8, 23,  9])

# %%
#Scale data using MinMaxScaler

X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
X_train_scaled
# Out:
# array([[0.38      , 0.57777778, 0.47352941, ..., 0.62068966, 0.52380952,
#         0.        ],
#        [0.66      , 0.24444444, 0.6       , ..., 0.34482759, 0.47619048,
#         0.        ],
#        [0.98      , 0.31111111, 0.42352941, ..., 0.44827586, 0.66666667,
#         0.        ],
#        ...,
#        [0.94      , 0.33333333, 0.56911765, ..., 0.31034483, 0.66666667,
#         0.        ],
#        [0.64      , 0.24444444, 0.48235294, ..., 0.44827586, 0.42857143,
#         0.        ],
#        [0.82      , 0.48888889, 0.48088235, ..., 0.44827586, 0.80952381,
#         0.        ]])

# %%
##Import RandomForestClassifier and train

from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train_scaled, y_train)

# %%
#Get Score for RandomForestClassifier

rf.score(X_test_scaled, y_test)
# Out:
# 0.20454545454545456

# %% [markdown]
# Create Neural Network Model

# %%
#Print data scores for training aand test datasets
print(f"Training Data Score: {rf.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {rf.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 1.0
# Testing Data Score: 0.20454545454545456

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {"bootstrap": [True],
              "max_depth": [80, 90, 100, 125],
#              "max_features": [2,3],
 #            "min_samples_leaf": [3, 4, 5],
              "n_estimators": [100, 500, 1000]
              }
grid = GridSearchCV(rf, param_grid, verbose=3)
grid
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=200, n_jobs=None,
#                                               oob_score=False,
#                                               random_state=None, verbose=0,
#                                               warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'bootstrap': [True], 'max_depth': [80, 90, 100, 125],
#                          'n_estimators': [100, 500, 1000]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %% [markdown]
# Train Model

# %%
# Train the model with GridSearch

grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] bootstrap=True, max_depth=80, n_estimators=100 ..................
# C:\Users\swill\Anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_split.py:667: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  bootstrap=True, max_depth=80, n_estimators=100, score=0.179, total=   0.8s
# [CV] bootstrap=True, max_depth=80, n_estimators=100 ..................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.7s remaining:    0.0s
# [CV]  bootstrap=True, max_depth=80, n_estimators=100, score=0.156, total=   0.9s
# [CV] bootstrap=True, max_depth=80, n_estimators=100 ..................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.6s remaining:    0.0s
# [CV]  bootstrap=True, max_depth=80, n_estimators=100, score=0.166, total=   0.9s
# [CV] bootstrap=True, max_depth=80, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=80, n_estimators=100, score=0.156, total=   0.9s
# [CV] bootstrap=True, max_depth=80, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=80, n_estimators=100, score=0.128, total=   0.9s
# [CV] bootstrap=True, max_depth=80, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=80, n_estimators=500, score=0.189, total=   4.6s
# [CV] bootstrap=True, max_depth=80, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=80, n_estimators=500, score=0.180, total=   4.3s
# [CV] bootstrap=True, max_depth=80, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=80, n_estimators=500, score=0.199, total=   4.2s
# [CV] bootstrap=True, max_depth=80, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=80, n_estimators=500, score=0.161, total=   4.2s
# [CV] bootstrap=True, max_depth=80, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=80, n_estimators=500, score=0.161, total=   4.2s
# [CV] bootstrap=True, max_depth=80, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=80, n_estimators=1000, score=0.170, total=   8.4s
# [CV] bootstrap=True, max_depth=80, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=80, n_estimators=1000, score=0.190, total=   8.3s
# [CV] bootstrap=True, max_depth=80, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=80, n_estimators=1000, score=0.171, total=   8.5s
# [CV] bootstrap=True, max_depth=80, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=80, n_estimators=1000, score=0.171, total=   8.3s
# [CV] bootstrap=True, max_depth=80, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=80, n_estimators=1000, score=0.133, total=   7.7s
# [CV] bootstrap=True, max_depth=90, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=90, n_estimators=100, score=0.151, total=   0.7s
# [CV] bootstrap=True, max_depth=90, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=90, n_estimators=100, score=0.142, total=   0.8s
# [CV] bootstrap=True, max_depth=90, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=90, n_estimators=100, score=0.156, total=   0.9s
# [CV] bootstrap=True, max_depth=90, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=90, n_estimators=100, score=0.175, total=   0.8s
# [CV] bootstrap=True, max_depth=90, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=90, n_estimators=100, score=0.161, total=   0.9s
# [CV] bootstrap=True, max_depth=90, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=90, n_estimators=500, score=0.179, total=   3.5s
# [CV] bootstrap=True, max_depth=90, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=90, n_estimators=500, score=0.152, total=   4.1s
# [CV] bootstrap=True, max_depth=90, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=90, n_estimators=500, score=0.175, total=   4.1s
# [CV] bootstrap=True, max_depth=90, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=90, n_estimators=500, score=0.156, total=   4.0s
# [CV] bootstrap=True, max_depth=90, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=90, n_estimators=500, score=0.147, total=   4.1s
# [CV] bootstrap=True, max_depth=90, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=90, n_estimators=1000, score=0.179, total=   8.2s
# [CV] bootstrap=True, max_depth=90, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=90, n_estimators=1000, score=0.171, total=   8.3s
# [CV] bootstrap=True, max_depth=90, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=90, n_estimators=1000, score=0.185, total=   8.7s
# [CV] bootstrap=True, max_depth=90, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=90, n_estimators=1000, score=0.156, total=   8.2s
# [CV] bootstrap=True, max_depth=90, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=90, n_estimators=1000, score=0.142, total=   8.3s
# [CV] bootstrap=True, max_depth=100, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=100, score=0.170, total=   0.8s
# [CV] bootstrap=True, max_depth=100, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=100, score=0.161, total=   0.8s
# [CV] bootstrap=True, max_depth=100, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=100, score=0.156, total=   0.8s
# [CV] bootstrap=True, max_depth=100, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=100, score=0.133, total=   0.8s
# [CV] bootstrap=True, max_depth=100, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=100, score=0.156, total=   0.9s
# [CV] bootstrap=True, max_depth=100, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=500, score=0.189, total=   4.2s
# [CV] bootstrap=True, max_depth=100, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=500, score=0.194, total=   4.2s
# [CV] bootstrap=True, max_depth=100, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=500, score=0.171, total=   3.7s
# [CV] bootstrap=True, max_depth=100, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=500, score=0.171, total=   4.1s
# [CV] bootstrap=True, max_depth=100, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=500, score=0.123, total=   4.2s
# [CV] bootstrap=True, max_depth=100, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=100, n_estimators=1000, score=0.184, total=   8.2s
# [CV] bootstrap=True, max_depth=100, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=100, n_estimators=1000, score=0.171, total=   8.6s
# [CV] bootstrap=True, max_depth=100, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=100, n_estimators=1000, score=0.175, total=   8.3s
# [CV] bootstrap=True, max_depth=100, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=100, n_estimators=1000, score=0.175, total=   7.9s
# [CV] bootstrap=True, max_depth=100, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=100, n_estimators=1000, score=0.123, total=   7.5s
# [CV] bootstrap=True, max_depth=125, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=100, score=0.175, total=   0.8s
# [CV] bootstrap=True, max_depth=125, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=100, score=0.194, total=   0.8s
# [CV] bootstrap=True, max_depth=125, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=100, score=0.175, total=   0.8s
# [CV] bootstrap=True, max_depth=125, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=100, score=0.123, total=   0.8s
# [CV] bootstrap=True, max_depth=125, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=100, score=0.123, total=   0.8s
# [CV] bootstrap=True, max_depth=125, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=500, score=0.198, total=   4.2s
# [CV] bootstrap=True, max_depth=125, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=500, score=0.161, total=   4.1s
# [CV] bootstrap=True, max_depth=125, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=500, score=0.166, total=   4.1s
# [CV] bootstrap=True, max_depth=125, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=500, score=0.171, total=   4.2s
# [CV] bootstrap=True, max_depth=125, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=500, score=0.137, total=   4.0s
# [CV] bootstrap=True, max_depth=125, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=125, n_estimators=1000, score=0.189, total=   7.8s
# [CV] bootstrap=True, max_depth=125, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=125, n_estimators=1000, score=0.171, total=   8.9s
# [CV] bootstrap=True, max_depth=125, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=125, n_estimators=1000, score=0.171, total=   8.3s
# [CV] bootstrap=True, max_depth=125, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=125, n_estimators=1000, score=0.166, total=   8.3s
# [CV] bootstrap=True, max_depth=125, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=125, n_estimators=1000, score=0.137, total=   8.8s
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:  4.4min finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=200, n_jobs=None,
#                                               oob_score=False,
#                                               random_state=None, verbose=0,
#                                               warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'bootstrap': [True], 'max_depth': [80, 90, 100, 125],
#                          'n_estimators': [100, 500, 1000]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
#Print best parameter and score 

print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'bootstrap': True, 'max_depth': 80, 'n_estimators': 500}
# 0.17802020924617726

# %% [markdown]
# Evaluate Model

# %%
#Make prediction using test data

predictions = grid.predict(X_test_scaled)

# %% [markdown]
# Predict World Series Champs

# %%
##Print accuracy score for test data

print('Test Acc: %.3f' % grid.score(X_test_scaled, y_test))
# Out:
# Test Acc: 0.207
