# 3                  Boston Red Sox
# 4                    Chicago Cubs
# 5               Chicago White Sox
# 6                 Cincinnati Reds
# 7               Cleveland Indians
# 8                Colorado Rockies
# 9                  Detroit Tigers
# 10                 Houston Astros
# 11             Kansas City Royals
# 12  Los Angeles Angels of Anaheim
# 13            Los Angeles Dodgers
# 14                  Miami Marlins
# 15              Milwaukee Brewers
# 16                Minnesota Twins
# 17                  New York Mets
# 18               New York Yankees
# 19              Oakland Athletics
#
# [20 rows x 22 columns]

# %%
#Use getdummies to convert strings

data_LG = mlb_df.copy()
data_bin = pd.get_dummies(data_LG, columns=["WSWin", "lgID"])
data_bin = data_bin.drop(columns=['WSWin_N', 'lgID_AL'])

data_bin.head()
# Out:
#    yearID      G   G.1     W     L  WPCT      R      AB       H     2B  ...  \
# 0  2014.0  162.0  81.0  64.0  98.0  0.57  615.0  5552.0  1379.0  259.0  ...
# 1  2014.0  162.0  81.0  79.0  83.0  0.67  573.0  5468.0  1316.0  240.0  ...
# 2  2014.0  162.0  81.0  96.0  66.0  0.54  705.0  5596.0  1434.0  264.0  ...
# 3  2014.0  162.0  81.0  71.0  91.0  0.44  634.0  5551.0  1355.0  282.0  ...
# 4  2014.0  162.0  81.0  73.0  89.0  0.42  614.0  5508.0  1315.0  270.0  ...
#
#       BB      SO    SB   ERA   CG   SHO    SV                  name  WSWin_Y  \
# 0  398.0  1165.0  86.0  4.26  2.0   4.0  35.0  Arizona Diamondbacks        0
# 1  472.0  1369.0  95.0  3.38  5.0  13.0  54.0        Atlanta Braves        0
# 2  401.0  1285.0  44.0  3.43  3.0  13.0  53.0     Baltimore Orioles        0
# 3  535.0  1337.0  63.0  4.01  3.0   7.0  36.0        Boston Red Sox        0
# 4  442.0  1477.0  65.0  3.91  1.0  11.0  37.0          Chicago Cubs        0
#
#   lgID_NL
# 0       1
# 1       1
# 2       0
# 3       0
# 4       1
#
# [5 rows x 22 columns]

# %%
data = data_bin.drop("name", axis = 1)
outcome = data_bin["name"]
print(data.shape, outcome.shape)
# Out:
# (1229, 21) (1229,)

# %% [markdown]
# Preprocess data

# %%
#Import SciKit libraries

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler
from tensorflow.keras.utils import to_categorical

# %%
#Split data and teams into training and test data

X_train, X_test, y_train, y_test = train_test_split(data, outcome, random_state=1)
y_train
# Out:
# 503        San Diego Padres
# 842       Milwaukee Brewers
# 419       Toronto Blue Jays
# 493      Kansas City Royals
# 325        Seattle Mariners
#                ...
# 715           New York Mets
# 905     St. Louis Cardinals
# 1096     Kansas City Royals
# 235     St. Louis Cardinals
# 1061          Texas Rangers
# Name: name, Length: 921, dtype: object

# %%
#Scale data using MinMaxScaler

X_scaler = StandardScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
X_train_scaled
# Out:
# array([[ 0.42165868,  0.22603988,  0.22503865, ...,  2.29677766,
#         -0.18663189,  1.0342451 ],
#        [-0.63077397,  0.11140181,  0.22503865, ...,  0.36780557,
#         -0.18663189, -0.9668888 ],
#        [ 0.64717997,  0.22603988,  0.45180079, ...,  0.36780557,
#         -0.18663189, -0.9668888 ],
#        ...,
#        [-1.38251158,  0.22603988,  0.22503865, ..., -2.20415721,
#         -0.18663189, -0.9668888 ],
#        [ 1.09822253,  0.22603988,  0.22503865, ..., -0.38235024,
#         -0.18663189,  1.0342451 ],
#        [-1.23216405,  0.22603988,  0.22503865, ..., -2.41848744,
#         -0.18663189, -0.9668888 ]])

# %%
#Import and use SVC MODEL
from sklearn.svm import SVC 
model = SVC(kernel='linear')
model.fit(X_train_scaled, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
#Print training and test scores from model using datasets

print(f"Training Data Score: {model.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {model.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.509229098805646
# Testing Data Score: 0.2597402597402597

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [100, 500, 1000],
              'gamma': [0.0001, 0.005, 0.001]}
grid = GridSearchCV(model, param_grid, verbose=3)

# %%
# Train the model with GridSearch

grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] C=100, gamma=0.0001 .............................................
# C:\Users\swill\Anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_split.py:667: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ................. C=100, gamma=0.0001, score=0.216, total=   3.9s
# [CV] C=100, gamma=0.0001 .............................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.8s remaining:    0.0s
# [CV] ................. C=100, gamma=0.0001, score=0.207, total=   5.0s
# [CV] C=100, gamma=0.0001 .............................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    8.8s remaining:    0.0s
# [CV] ................. C=100, gamma=0.0001, score=0.190, total=   3.5s
# [CV] C=100, gamma=0.0001 .............................................
# [CV] ................. C=100, gamma=0.0001, score=0.158, total=   5.2s
# [CV] C=100, gamma=0.0001 .............................................
# [CV] ................. C=100, gamma=0.0001, score=0.245, total=   4.2s
# [CV] C=100, gamma=0.005 ..............................................
# [CV] .................. C=100, gamma=0.005, score=0.216, total=   3.7s
# [CV] C=100, gamma=0.005 ..............................................
# [CV] .................. C=100, gamma=0.005, score=0.207, total=   5.2s
# [CV] C=100, gamma=0.005 ..............................................
# [CV] .................. C=100, gamma=0.005, score=0.190, total=   3.4s
# [CV] C=100, gamma=0.005 ..............................................
# [CV] .................. C=100, gamma=0.005, score=0.158, total=   4.3s
# [CV] C=100, gamma=0.005 ..............................................
# [CV] .................. C=100, gamma=0.005, score=0.245, total=   3.9s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] .................. C=100, gamma=0.001, score=0.216, total=   3.7s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] .................. C=100, gamma=0.001, score=0.207, total=   5.4s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] .................. C=100, gamma=0.001, score=0.190, total=   3.4s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] .................. C=100, gamma=0.001, score=0.158, total=   4.3s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] .................. C=100, gamma=0.001, score=0.245, total=   3.9s
# [CV] C=500, gamma=0.0001 .............................................
# [CV] ................. C=500, gamma=0.0001, score=0.211, total=  17.3s
# [CV] C=500, gamma=0.0001 .............................................
# [CV] ................. C=500, gamma=0.0001, score=0.217, total=  15.6s
# [CV] C=500, gamma=0.0001 .............................................
# [CV] ................. C=500, gamma=0.0001, score=0.163, total=  10.6s
# [CV] C=500, gamma=0.0001 .............................................
# [CV] ................. C=500, gamma=0.0001, score=0.147, total=  21.4s
# [CV] C=500, gamma=0.0001 .............................................
# [CV] ................. C=500, gamma=0.0001, score=0.239, total=  20.7s
# [CV] C=500, gamma=0.005 ..............................................
# [CV] .................. C=500, gamma=0.005, score=0.211, total=  17.3s
# [CV] C=500, gamma=0.005 ..............................................
# [CV] .................. C=500, gamma=0.005, score=0.217, total=  15.5s
# [CV] C=500, gamma=0.005 ..............................................
# [CV] .................. C=500, gamma=0.005, score=0.163, total=  10.6s
# [CV] C=500, gamma=0.005 ..............................................
# [CV] .................. C=500, gamma=0.005, score=0.147, total=  22.7s
# [CV] C=500, gamma=0.005 ..............................................
# [CV] .................. C=500, gamma=0.005, score=0.239, total=  20.0s
# [CV] C=500, gamma=0.001 ..............................................
# [CV] .................. C=500, gamma=0.001, score=0.211, total=  18.4s
# [CV] C=500, gamma=0.001 ..............................................
# [CV] .................. C=500, gamma=0.001, score=0.217, total= 5.6min
# [CV] C=500, gamma=0.001 ..............................................
# [CV] .................. C=500, gamma=0.001, score=0.163, total=   4.4s
# [CV] C=500, gamma=0.001 ..............................................
# [CV] .................. C=500, gamma=0.001, score=0.147, total=  21.4s
# [CV] C=500, gamma=0.001 ..............................................
# [CV] .................. C=500, gamma=0.001, score=0.239, total=  21.5s
# [CV] C=1000, gamma=0.0001 ............................................
# [CV] ................ C=1000, gamma=0.0001, score=0.200, total=  35.1s
# [CV] C=1000, gamma=0.0001 ............................................
# [CV] ................ C=1000, gamma=0.0001, score=0.217, total=  32.6s
# [CV] C=1000, gamma=0.0001 ............................................
# [CV] ................ C=1000, gamma=0.0001, score=0.163, total=  27.7s
# [CV] C=1000, gamma=0.0001 ............................................
# [CV] ................ C=1000, gamma=0.0001, score=0.141, total=  31.1s
# [CV] C=1000, gamma=0.0001 ............................................
# [CV] ................ C=1000, gamma=0.0001, score=0.234, total=  28.9s
# [CV] C=1000, gamma=0.005 .............................................
# [CV] ................. C=1000, gamma=0.005, score=0.200, total=  30.6s
# [CV] C=1000, gamma=0.005 .............................................
# [CV] ................. C=1000, gamma=0.005, score=0.217, total=  31.2s
# [CV] C=1000, gamma=0.005 .............................................
# [CV] ................. C=1000, gamma=0.005, score=0.163, total=  26.0s
# [CV] C=1000, gamma=0.005 .............................................
# [CV] ................. C=1000, gamma=0.005, score=0.141, total=  30.4s
# [CV] C=1000, gamma=0.005 .............................................
# [CV] ................. C=1000, gamma=0.005, score=0.234, total=  28.2s
# [CV] C=1000, gamma=0.001 .............................................
# [CV] ................. C=1000, gamma=0.001, score=0.200, total=  29.6s
# [CV] C=1000, gamma=0.001 .............................................
# [CV] ................. C=1000, gamma=0.001, score=0.217, total=  31.6s
# [CV] C=1000, gamma=0.001 .............................................
# [CV] ................. C=1000, gamma=0.001, score=0.163, total=  27.1s
# [CV] C=1000, gamma=0.001 .............................................
# [CV] ................. C=1000, gamma=0.001, score=0.141, total=  30.8s
# [CV] C=1000, gamma=0.001 .............................................
# [CV] ................. C=1000, gamma=0.001, score=0.234, total=  27.4s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed: 18.1min finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=SVC(C=1.0, break_ties=False, cache_size=200,
#                            class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='scale', kernel='linear', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'C': [100, 500, 1000],
#                          'gamma': [0.0001, 0.005, 0.001]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %% [markdown]
# Train Model

# %%
#Print best parameters and score from Gridsearch

print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'C': 100, 'gamma': 0.0001}
# 0.20302585193889544

# %%
#Print accuracy of model using test dataset

print('Test Acc: %.3f' % grid.score(X_test_scaled, y_test))
# Out:
# Test Acc: 0.253

# %%
#Preprocess and predict 2020 MLB WS Champ
mlb_teams2015= pd.read_csv("2015.csv")

mlb2015_df = mlb_teams2015[['yearID', 'lgID', 'G', 'G.1', 'W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H',
       '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV', 'name']]

data2015_LG = mlb2015_df.copy()
data2015_bin = pd.get_dummies(data2015_LG, columns=["WSWin", "lgID"])
data2015_bin = data2015_bin.drop(columns=['WSWin_N', 'lgID_AL'])

feature2015 = data2015_bin.drop("name", axis=1)
team2015 = data2015_bin["name"]

X_feature2015_scaler = StandardScaler().fit(feature2015)
X_feature2015_scaled = X_feature2015_scaler.transform(feature2015)

predictions2015 = grid.predict(X_feature2015_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2015_scaled, team2015))
predictions2015 = model.predict(X_feature2015_scaled)
print(predictions2015)
# Out:
# Test Acc: 0.100
# ['St. Louis Cardinals' 'San Diego Padres' 'Chicago White Sox'
#  'Cleveland Indians' 'Cincinnati Reds' 'Minnesota Twins' 'Cincinnati Reds'
#  'Boston Red Sox' 'Colorado Rockies' 'Kansas City Royals'
#  'Oakland Athletics' 'Minnesota Twins' 'Chicago White Sox'
#  'Atlanta Braves' 'Los Angeles Dodgers' 'Pittsburgh Pirates'
#  'Toronto Blue Jays' 'New York Mets' 'Oakland Athletics'
#  'Kansas City Royals' 'Pittsburgh Pirates' 'St. Louis Cardinals'
#  'San Francisco Giants' 'St. Louis Cardinals' 'Baltimore Orioles'
#  'San Francisco Giants' 'Seattle Mariners' 'Milwaukee Brewers'
#  'Oakland Athletics' 'Atlanta Braves']

# %%
#Preprocess and predict 2020 MLB WS Champ
mlb_teams2016= pd.read_csv("2016.csv")

mlb2016_df = mlb_teams2016[['yearID', 'lgID', 'G', 'G.1', 'W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H',
       '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV', 'name']]

data2016_LG = mlb2016_df.copy()
data2016_bin = pd.get_dummies(data2016_LG, columns=["WSWin", "lgID"])
data2016_bin = data2016_bin.drop(columns=['WSWin_N', 'lgID_AL'])

feature2016 = data2016_bin.drop("name", axis=1)
team2016 = data2016_bin["name"]

X_feature2016_scaler = StandardScaler().fit(feature2016)
X_feature2016_scaled = X_feature2016_scaler.transform(feature2016)

predictions2016 = grid.predict(X_feature2016_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2016_scaled, team2016))
predictions2016 = model.predict(X_feature2016_scaled)
print(predictions2016)
# Out:
# Test Acc: 0.200
# ['Philadelphia Phillies' 'Pittsburgh Pirates' 'Baltimore Orioles'
#  'Boston Red Sox' 'New York Mets' 'Minnesota Twins' 'Montreal Expos'
#  'Boston Red Sox' 'Colorado Rockies' 'Minnesota Twins' 'Oakland Athletics'
#  'Kansas City Royals' 'Cleveland Indians' 'Atlanta Braves'
#  'San Diego Padres' 'Cincinnati Reds' 'Tampa Bay Devil Rays'
#  'Atlanta Braves' 'Chicago White Sox' 'Cleveland Indians'
#  'San Diego Padres' 'Philadelphia Phillies' 'Montreal Expos'
#  'Philadelphia Phillies' 'Chicago White Sox' 'Chicago Cubs'
#  'Toronto Blue Jays' 'Chicago White Sox' 'Oakland Athletics'
#  'Atlanta Braves']

# %%
#Preprocess and predict 2020 MLB WS Champ
mlb_teams2017= pd.read_csv("2017.csv")

mlb2017_df = mlb_teams2017[['yearID', 'lgID', 'G', 'G.1', 'W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H',
       '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV', 'name']]

data2017_LG = mlb2017_df.copy()
data2017_bin = pd.get_dummies(data2017_LG, columns=["WSWin", "lgID"])
data2017_bin = data2017_bin.drop(columns=['WSWin_N', 'lgID_AL'])

feature2017 = data2017_bin.drop("name", axis=1)
team2017 = data2017_bin["name"]

X_feature2017_scaler = StandardScaler().fit(feature2017)
X_feature2017_scaled = X_feature2017_scaler.transform(feature2017)

predictions2017 = grid.predict(X_feature2017_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2017_scaled, team2017))
predictions2017 = model.predict(X_feature2017_scaled)
print(predictions2017)
# Out:
# Test Acc: 0.100
# ['Philadelphia Phillies' 'Chicago Cubs' 'Baltimore Orioles'
#  'Baltimore Orioles' 'Atlanta Braves' 'Kansas City Royals'
#  'Philadelphia Phillies' 'Boston Red Sox' 'Pittsburgh Pirates'
#  'Kansas City Royals' 'Anaheim Angels' 'Kansas City Royals'
#  'Oakland Athletics' 'Atlanta Braves' 'St. Louis Cardinals'
#  'San Diego Padres' 'Boston Red Sox' 'Chicago Cubs' 'Detroit Tigers'
#  'Boston Red Sox' 'Pittsburgh Pirates' 'San Diego Padres'
#  'Milwaukee Brewers' 'Montreal Expos' 'Cleveland Indians'
#  'St. Louis Cardinals' 'Chicago White Sox' 'Oakland Athletics'
#  'Baltimore Orioles' 'Pittsburgh Pirates']

# %%
#Preprocess and predict 2020 MLB WS Champ
mlb_teams2018= pd.read_csv("2018.csv")

mlb2018_df = mlb_teams2018[['yearID', 'lgID', 'G', 'G.1', 'W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H',
       '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV', 'name']]

data2018_LG = mlb2018_df.copy()
data2018_bin = pd.get_dummies(data2018_LG, columns=["WSWin", "lgID"])
data2018_bin = data2018_bin.drop(columns=['WSWin_N', 'lgID_AL'])

feature2018 = data2018_bin.drop("name", axis=1)
team2018 = data2018_bin["name"]

X_feature2018_scaler = StandardScaler().fit(feature2018)
X_feature2018_scaled = X_feature2018_scaler.transform(feature2018)

predictions2018 = grid.predict(X_feature2018_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2018_scaled, team2018))
predictions2018 = model.predict(X_feature2018_scaled)
print(predictions2018)
# Out:
# Test Acc: 0.133
# ['Arizona Diamondbacks' 'St. Louis Cardinals' 'Tampa Bay Devil Rays'
#  'Boston Red Sox' 'Los Angeles Dodgers' 'Detroit Tigers'
#  'San Diego Padres' 'Baltimore Orioles' 'San Francisco Giants'
#  'Kansas City Royals' 'Baltimore Orioles' 'Kansas City Royals'
#  'Chicago White Sox' 'San Francisco Giants' 'San Diego Padres'
#  'Los Angeles Dodgers' 'Boston Red Sox' 'Philadelphia Phillies'
#  'Oakland Athletics' 'Boston Red Sox' 'San Diego Padres'
#  'St. Louis Cardinals' 'San Diego Padres' 'San Diego Padres'
#  'Chicago White Sox' 'Atlanta Braves' 'Kansas City Royals'
#  'Cleveland Indians' 'Cleveland Indians' 'New York Mets']

# %%
#Preprocess and predict 2020 MLB WS Champ
mlb2019_teams= pd.read_csv("MLB 2019 season.csv")

mlb2019_df = mlb2019_teams[['yearID', 'lgID', 'G', 'G.1', 'W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H',
       '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV', 'name']]

data2019_LG = mlb2019_df.copy()
data2019_bin = pd.get_dummies(data2019_LG, columns=["WSWin", "lgID"])
data2019_bin = data2019_bin.drop(columns=['WSWin_N', 'lgID_AL'])

feature2019 = data2019_bin.drop("name", axis=1)
team2019 = data2019_bin["name"]

X_feature2019_scaler = StandardScaler().fit(feature2019)
X_feature2019_scaled = X_feature2019_scaler.transform(feature2019)

predictions2019 = grid.predict(X_feature2019_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2019_scaled, team2019))
predictions2019 = model.predict(X_feature2019_scaled)
print(predictions2019)
# Out:
# Test Acc: 0.200
# ['Houston Astros' 'Atlanta Braves' 'Tampa Bay Devil Rays' 'Boston Red Sox'
#  'Boston Red Sox' 'Atlanta Braves' 'Atlanta Braves' 'Baltimore Orioles'
#  'Colorado Rockies' 'Tampa Bay Devil Rays' 'Baltimore Orioles'
#  'Kansas City Royals' 'Cleveland Indians' 'Atlanta Braves'
#  'Pittsburgh Pirates' 'Cincinnati Reds' 'Boston Red Sox'
#  'Baltimore Orioles' 'Atlanta Braves' 'New York Yankees'
#  'Philadelphia Phillies' 'Pittsburgh Pirates' 'San Diego Padres'
#  'Oakland Athletics' 'Philadelphia Phillies' 'Los Angeles Dodgers'
#  'Minnesota Twins' 'Milwaukee Brewers' 'Oakland Athletics'
#  'St. Louis Cardinals']

# %%
#Preprocess and predict 2020 MLB WS Champ
mlb2020_teams= pd.read_csv("2020.csv")

mlb2020_df = mlb2020_teams[['yearID', 'lgID', 'G', 'G.1', 'W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H',
       '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV', 'name']]



data2020_LG = mlb2020_df.copy()
data2020_bin = pd.get_dummies(data2020_LG, columns=["WSWin", "lgID"])
data2020_bin = data2020_bin.drop(columns=['lgID_AL'])

feature2020 = data2020_bin.drop("name", axis=1)
team2020 = data2020_bin["name"]

X_feature2020_scaler = StandardScaler().fit(feature2020)
X_feature2020_scaled = X_feature2020_scaler.transform(feature2020)

predictions2020 = grid.predict(X_feature2020_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2020_scaled, team2020))
predictions2020 = model.predict(X_feature2020_scaled)
print(predictions2020)
# Out:
# Test Acc: 0.067
# ['Pittsburgh Pirates' 'New York Mets' 'Minnesota Twins' 'Minnesota Twins'
#  'Atlanta Braves' 'Texas Rangers' 'Atlanta Braves' 'New York Yankees'
#  'Pittsburgh Pirates' 'California Angels' 'Toronto Blue Jays'
#  'Seattle Mariners' 'Cleveland Indians' 'Atlanta Braves' 'Houston Astros'
#  'Atlanta Braves' 'New York Yankees' 'Chicago Cubs' 'Baltimore Orioles'
#  'Detroit Tigers' 'Atlanta Braves' 'San Diego Padres'
#  'St. Louis Cardinals' 'Pittsburgh Pirates' 'Cleveland Indians'
#  'San Francisco Giants' 'Tampa Bay Rays' 'Tampa Bay Devil Rays'
#  'Cleveland Indians' 'Pittsburgh Pirates']

# %% [markdown]
# Evaluate Model

# %% [markdown]
# Predict World Series Champs

# %%
#Predict outcome
# Calculate classification report
from sklearn.metrics import classification_report
predictions = model.predict(X_feature_scaled)
print(predictions)
# Out:
# ['Houston Astros' 'Los Angeles Dodgers' 'Kansas City Royals'
#  'Boston Red Sox' 'Minnesota Twins' 'Atlanta Braves' 'Los Angeles Dodgers'
#  'Baltimore Orioles' 'Colorado Rockies' 'Kansas City Royals'
#  'New York Yankees' 'Kansas City Royals' 'Cleveland Indians'
#  'Los Angeles Dodgers' 'Chicago Cubs' 'Cincinnati Reds' 'Boston Red Sox'
#  'New York Yankees' 'Atlanta Braves' 'New York Yankees'
#  'Philadelphia Phillies' 'Pittsburgh Pirates' 'San Diego Padres'
#  'Oakland Athletics' 'Philadelphia Phillies' 'Los Angeles Dodgers'
#  'Kansas City Royals' 'Texas Rangers' 'Oakland Athletics'
#  'St. Louis Cardinals']

# %%
print('Test Acc: %.3f' % grid.score(X_feature_scaled, team))
# Out:
# Test Acc: 0.200

# %%
import joblib
filename = 'SWilliams_SVM.sav'
joblib.dump(model, filename)
# Out:
# ['SWilliams_SVM.sav']
