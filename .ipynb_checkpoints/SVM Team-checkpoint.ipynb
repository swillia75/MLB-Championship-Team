# %%
#import numpy to use seed 
import numpy as np
import pandas as pd
from numpy.random import seed
np.random.seed(1)

# %% [markdown]
# Read CSV create, and clean dataframe

# %%
#Read in CSV and create dataframe
mlb_teams= pd.read_csv("Teams.csv")
mlb_teams= mlb_teams.dropna()

mlb_teams
# Out:
#       yearID lgID      G   G.1     W     L  WPCT WSWin      R      AB  ...  \
# 0     2004.0   AL  162.0  81.0  92.0  70.0  0.36     N  836.0  5675.0  ...
# 1     2003.0   AL  162.0  82.0  77.0  85.0  0.48     N  736.0  5487.0  ...
# 2     2002.0   AL  162.0  81.0  99.0  63.0  0.54     Y  851.0  5678.0  ...
# 3     2001.0   AL  162.0  81.0  75.0  87.0  0.48     N  691.0  5551.0  ...
# 4     2000.0   AL  162.0  81.0  82.0  80.0  0.46     N  864.0  5628.0  ...
# ...      ...  ...    ...   ...   ...   ...   ...   ...    ...     ...  ...
# 1224  2006.0   NL  162.0  81.0  71.0  91.0  0.50     N  746.0  5495.0  ...
# 1225  2005.0   NL  162.0  81.0  81.0  81.0  0.51     N  639.0  5426.0  ...
# 1226  1971.0   AL  159.0  81.0  63.0  96.0  0.43     N  537.0  5290.0  ...
# 1227  1970.0   AL  162.0  81.0  70.0  92.0  0.46     N  626.0  5460.0  ...
# 1228  1969.0   AL  162.0  81.0  86.0  76.0  0.49     N  694.0  5447.0  ...
#
#         3B     HR     BB      SO     SB   ERA    CG   SHO    SV  \
# 0     37.0  162.0  450.0   942.0  143.0  4.28   2.0  11.0  50.0
# 1     33.0  150.0  476.0   838.0  129.0  4.28   5.0   9.0  39.0
# 2     32.0  152.0  462.0   805.0  117.0  3.69   7.0  14.0  54.0
# 3     26.0  158.0  494.0  1001.0  116.0  4.20   6.0   1.0  43.0
# 4     34.0  236.0  608.0  1024.0   93.0  5.00   5.0   3.0  46.0
# ...    ...    ...    ...     ...    ...   ...   ...   ...   ...
# 1224  22.0  164.0  594.0  1156.0  123.0  5.03   1.0   3.0  32.0
# 1225  32.0  117.0  491.0  1090.0   45.0  3.87   4.0   9.0  51.0
# 1226  30.0   86.0  575.0   956.0   68.0  3.70  30.0  10.0  26.0
# 1227  28.0  138.0  635.0   989.0   72.0  3.80  20.0  11.0  40.0
# 1228  40.0  148.0  630.0   900.0   52.0  3.49  28.0  10.0  41.0
#
#                       name
# 0           Anaheim Angels
# 1           Anaheim Angels
# 2           Anaheim Angels
# 3           Anaheim Angels
# 4           Anaheim Angels
# ...                    ...
# 1224  Washington Nationals
# 1225  Washington Nationals
# 1226   Washington Senators
# 1227   Washington Senators
# 1228   Washington Senators
#
# [1229 rows x 22 columns]

# %%
#Get list of dataframe columns

mlb_teams.columns
# Out:
# Index(['yearID', 'lgID', 'G', 'G.1', 'W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H',
#        '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV', 'name'],
#       dtype='object')

# %%
#Select columns for dataframe

mlb_df = mlb_teams[['W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H',
       '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'SHO', 'SV', 'name']]
mlb_df.head(20)
# Out:
#        W      L  WPCT WSWin      R      AB       H     2B    3B     HR     BB  \
# 0   92.0   70.0  0.36     N  836.0  5675.0  1603.0  272.0  37.0  162.0  450.0
# 1   77.0   85.0  0.48     N  736.0  5487.0  1473.0  276.0  33.0  150.0  476.0
# 2   99.0   63.0  0.54     Y  851.0  5678.0  1603.0  333.0  32.0  152.0  462.0
# 3   75.0   87.0  0.48     N  691.0  5551.0  1447.0  275.0  26.0  158.0  494.0
# 4   82.0   80.0  0.46     N  864.0  5628.0  1574.0  309.0  34.0  236.0  608.0
# 5   70.0   92.0  0.53     N  711.0  5494.0  1404.0  248.0  22.0  158.0  511.0
# 6   85.0   77.0  0.46     N  787.0  5630.0  1530.0  314.0  27.0  147.0  510.0
# 7   84.0   78.0  0.45     N  829.0  5628.0  1531.0  279.0  25.0  161.0  617.0
# 8   64.0   98.0  0.57     N  615.0  5552.0  1379.0  259.0  47.0  118.0  398.0
# 9   81.0   81.0  0.47     N  685.0  5676.0  1468.0  302.0  31.0  130.0  519.0
# 10  81.0   81.0  0.43     N  734.0  5462.0  1416.0  307.0  33.0  165.0  539.0
# 11  94.0   68.0  0.62     N  731.0  5421.0  1357.0  293.0  37.0  172.0  531.0
# 12  65.0   97.0  0.56     N  713.0  5473.0  1366.0  301.0  34.0  180.0  589.0
# 13  70.0   92.0  0.50     N  720.0  5565.0  1408.0  307.0  45.0  173.0  571.0
# 14  82.0   80.0  0.41     N  720.0  5409.0  1355.0  318.0  47.0  159.0  587.0
# 15  90.0   72.0  0.59     N  712.0  5398.0  1350.0  286.0  40.0  171.0  532.0
# 16  76.0   86.0  0.43     N  773.0  5645.0  1506.0  331.0  38.0  160.0  504.0
# 17  77.0   85.0  0.62     N  696.0  5550.0  1419.0  291.0  27.0  191.0  606.0
# 18  51.0  111.0  0.61     N  615.0  5544.0  1401.0  295.0  38.0  135.0  441.0
# 19  84.0   78.0  0.56     N  717.0  5570.0  1467.0  303.0  47.0  152.0  531.0
#
#         SO     SB   ERA   SHO    SV                  name
# 0    942.0  143.0  4.28  11.0  50.0        Anaheim Angels
# 1    838.0  129.0  4.28   9.0  39.0        Anaheim Angels
# 2    805.0  117.0  3.69  14.0  54.0        Anaheim Angels
# 3   1001.0  116.0  4.20   1.0  43.0        Anaheim Angels
# 4   1024.0   93.0  5.00   3.0  46.0        Anaheim Angels
# 5   1022.0   71.0  4.79   7.0  37.0        Anaheim Angels
# 6   1028.0   93.0  4.49   5.0  52.0        Anaheim Angels
# 7    953.0  126.0  4.52   5.0  39.0        Anaheim Angels
# 8   1165.0   86.0  4.26   4.0  35.0  Arizona Diamondbacks
# 9   1142.0   62.0  3.92   7.0  38.0  Arizona Diamondbacks
# 10  1266.0   93.0  3.93   9.0  39.0  Arizona Diamondbacks
# 11  1249.0  133.0  3.80  12.0  58.0  Arizona Diamondbacks
# 12  1529.0   86.0  4.81   3.0  35.0  Arizona Diamondbacks
# 13  1298.0  102.0  4.42  12.0  36.0  Arizona Diamondbacks
# 14  1287.0   58.0  3.98   9.0  39.0  Arizona Diamondbacks
# 15  1111.0  109.0  4.13  12.0  51.0  Arizona Diamondbacks
# 16   965.0   76.0  4.48   9.0  34.0  Arizona Diamondbacks
# 17  1094.0   67.0  4.84  10.0  45.0  Arizona Diamondbacks
# 18  1022.0   53.0  4.98   6.0  33.0  Arizona Diamondbacks
# 19  1006.0   76.0  3.84  11.0  42.0  Arizona Diamondbacks

# %%
#Use getdummies to convert strings

data_LG = mlb_df.copy()
data_bin = pd.get_dummies(data_LG, columns=["WSWin"])
data_bin = data_bin.drop(columns=['WSWin_N'])

data_bin.head()
# Out:
#       W     L  WPCT      R      AB       H     2B    3B     HR     BB      SO  \
# 0  92.0  70.0  0.36  836.0  5675.0  1603.0  272.0  37.0  162.0  450.0   942.0
# 1  77.0  85.0  0.48  736.0  5487.0  1473.0  276.0  33.0  150.0  476.0   838.0
# 2  99.0  63.0  0.54  851.0  5678.0  1603.0  333.0  32.0  152.0  462.0   805.0
# 3  75.0  87.0  0.48  691.0  5551.0  1447.0  275.0  26.0  158.0  494.0  1001.0
# 4  82.0  80.0  0.46  864.0  5628.0  1574.0  309.0  34.0  236.0  608.0  1024.0
#
#       SB   ERA   SHO    SV            name  WSWin_Y
# 0  143.0  4.28  11.0  50.0  Anaheim Angels        0
# 1  129.0  4.28   9.0  39.0  Anaheim Angels        0
# 2  117.0  3.69  14.0  54.0  Anaheim Angels        1
# 3  116.0  4.20   1.0  43.0  Anaheim Angels        0
# 4   93.0  5.00   3.0  46.0  Anaheim Angels        0

# %%
data = data_bin.drop("name", axis = 1)
outcome = data_bin["name"]
print(data.shape, outcome.shape)
# Out:
# (1229, 16) (1229,)

# %% [markdown]
# Preprocess data

# %%
#Import SciKit libraries

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from tensorflow.keras.utils import to_categorical

# %%
#Split data and teams into training and test data

X_train, X_test, y_train, y_test = train_test_split(data, outcome, random_state=42)
y_train
# Out:
# 997      San Francisco Giants
# 39             Atlanta Braves
# 30             Atlanta Braves
# 242         Chicago White Sox
# 756             New York Mets
#                 ...
# 1044         Seattle Mariners
# 1095      St. Louis Cardinals
# 1130           Tampa Bay Rays
# 860     Philadelphia Phillies
# 1126     Tampa Bay Devil Rays
# Name: name, Length: 921, dtype: object

# %%
#Scale data using StandardScaler

X_scaler = StandardScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
X_train_scaled
# Out:
# array([[ 9.58934059e-01, -8.20251844e-01, -1.13307632e+00, ...,
#          1.76874671e+00,  2.06598213e+00,  5.18739732e+00],
#        [ 1.20487621e+00, -1.07087175e+00,  1.71158306e+00, ...,
#         -1.71423866e-01,  1.63203047e+00, -1.92774900e-01],
#        [ 4.67049755e-01, -3.19012024e-01, -1.98647413e+00, ...,
#          7.10974558e-02,  4.71174441e-03, -1.92774900e-01],
#        ...,
#        [-2.70776702e-01,  4.32847706e-01,  4.31486335e-01, ...,
#          2.98135331e+00, -1.03776171e-01, -1.92774900e-01],
#        [ 5.71461678e-02,  9.86878256e-02,  7.15952273e-01, ...,
#          3.13618777e-01,  4.38663405e-01, -1.92774900e-01],
#        [-1.50048746e+00,  1.68594726e+00, -5.64144446e-01, ...,
#         -8.98987830e-01, -8.63191576e-01, -1.92774900e-01]])

# %% [markdown]
# Create and train model

# %%
#Import and use SVC MODEL
from sklearn.svm import SVC 
model = SVC(kernel='linear')
model.fit(X_train_scaled, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
#Print training and test scores from model using datasets

print(f"Training Data Score: {model.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {model.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.4017372421281216
# Testing Data Score: 0.18506493506493507

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [100, 500, 1000],
              'gamma': [0.0001, 0.005, 0.001]}
grid = GridSearchCV(model, param_grid, verbose=3)

# %%
# Train the model with GridSearch

grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] C=100, gamma=0.0001 .............................................
# C:\Users\swill\Anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_split.py:667: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ................. C=100, gamma=0.0001, score=0.130, total=   7.0s
# [CV] C=100, gamma=0.0001 .............................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    6.9s remaining:    0.0s
# [CV] ................. C=100, gamma=0.0001, score=0.120, total=   7.6s
# [CV] C=100, gamma=0.0001 .............................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   14.6s remaining:    0.0s
# [CV] ................. C=100, gamma=0.0001, score=0.092, total=   5.9s
# [CV] C=100, gamma=0.0001 .............................................
# [CV] ................. C=100, gamma=0.0001, score=0.163, total=   7.1s
# [CV] C=100, gamma=0.0001 .............................................
# [CV] ................. C=100, gamma=0.0001, score=0.147, total=   6.3s
# [CV] C=100, gamma=0.005 ..............................................
# [CV] .................. C=100, gamma=0.005, score=0.130, total=   6.7s
# [CV] C=100, gamma=0.005 ..............................................
# [CV] .................. C=100, gamma=0.005, score=0.120, total=   7.6s
# [CV] C=100, gamma=0.005 ..............................................
# [CV] .................. C=100, gamma=0.005, score=0.092, total=   6.1s
# [CV] C=100, gamma=0.005 ..............................................
# [CV] .................. C=100, gamma=0.005, score=0.163, total=   6.4s
# [CV] C=100, gamma=0.005 ..............................................
# [CV] .................. C=100, gamma=0.005, score=0.147, total=   6.3s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] .................. C=100, gamma=0.001, score=0.130, total=   6.6s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] .................. C=100, gamma=0.001, score=0.120, total=   7.4s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] .................. C=100, gamma=0.001, score=0.092, total=   6.2s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] .................. C=100, gamma=0.001, score=0.163, total=   7.4s
# [CV] C=100, gamma=0.001 ..............................................
# [CV] .................. C=100, gamma=0.001, score=0.147, total=   6.5s
# [CV] C=500, gamma=0.0001 .............................................
# [CV] ................. C=500, gamma=0.0001, score=0.141, total=  26.4s
# [CV] C=500, gamma=0.0001 .............................................
# [CV] ................. C=500, gamma=0.0001, score=0.114, total=  28.8s
# [CV] C=500, gamma=0.0001 .............................................
# [CV] ................. C=500, gamma=0.0001, score=0.114, total=  14.1s
# [CV] C=500, gamma=0.0001 .............................................
# [CV] ................. C=500, gamma=0.0001, score=0.152, total=  11.8s
# [CV] C=500, gamma=0.0001 .............................................
# [CV] ................. C=500, gamma=0.0001, score=0.152, total=  11.6s
# [CV] C=500, gamma=0.005 ..............................................
# [CV] .................. C=500, gamma=0.005, score=0.141, total=   9.5s
# [CV] C=500, gamma=0.005 ..............................................
# [CV] .................. C=500, gamma=0.005, score=0.114, total=   9.9s
# [CV] C=500, gamma=0.005 ..............................................
# [CV] .................. C=500, gamma=0.005, score=0.114, total=  10.3s
# [CV] C=500, gamma=0.005 ..............................................
# [CV] .................. C=500, gamma=0.005, score=0.152, total=  11.2s
# [CV] C=500, gamma=0.005 ..............................................
# [CV] .................. C=500, gamma=0.005, score=0.152, total=  11.1s
# [CV] C=500, gamma=0.001 ..............................................
# [CV] .................. C=500, gamma=0.001, score=0.141, total=   9.6s
# [CV] C=500, gamma=0.001 ..............................................
# [CV] .................. C=500, gamma=0.001, score=0.114, total=  10.0s
# [CV] C=500, gamma=0.001 ..............................................
# [CV] .................. C=500, gamma=0.001, score=0.114, total=  10.2s
# [CV] C=500, gamma=0.001 ..............................................
# [CV] .................. C=500, gamma=0.001, score=0.152, total=  11.1s
# [CV] C=500, gamma=0.001 ..............................................
# [CV] .................. C=500, gamma=0.001, score=0.152, total=  11.0s
# [CV] C=1000, gamma=0.0001 ............................................
# [CV] ................ C=1000, gamma=0.0001, score=0.141, total=  18.7s
# [CV] C=1000, gamma=0.0001 ............................................
# [CV] ................ C=1000, gamma=0.0001, score=0.130, total=  18.1s
# [CV] C=1000, gamma=0.0001 ............................................
# [CV] ................ C=1000, gamma=0.0001, score=0.125, total=  20.9s
# [CV] C=1000, gamma=0.0001 ............................................
# [CV] ................ C=1000, gamma=0.0001, score=0.147, total=  21.2s
# [CV] C=1000, gamma=0.0001 ............................................
# [CV] ................ C=1000, gamma=0.0001, score=0.158, total=  23.1s
# [CV] C=1000, gamma=0.005 .............................................
# [CV] ................. C=1000, gamma=0.005, score=0.141, total=  18.8s
# [CV] C=1000, gamma=0.005 .............................................
# [CV] ................. C=1000, gamma=0.005, score=0.130, total=  18.3s
# [CV] C=1000, gamma=0.005 .............................................
# [CV] ................. C=1000, gamma=0.005, score=0.125, total=  20.7s
# [CV] C=1000, gamma=0.005 .............................................
# [CV] ................. C=1000, gamma=0.005, score=0.147, total=  21.2s
# [CV] C=1000, gamma=0.005 .............................................
# [CV] ................. C=1000, gamma=0.005, score=0.158, total=  22.8s
# [CV] C=1000, gamma=0.001 .............................................
# [CV] ................. C=1000, gamma=0.001, score=0.141, total=  18.4s
# [CV] C=1000, gamma=0.001 .............................................
# [CV] ................. C=1000, gamma=0.001, score=0.130, total=  17.7s
# [CV] C=1000, gamma=0.001 .............................................
# [CV] ................. C=1000, gamma=0.001, score=0.125, total=  20.4s
# [CV] C=1000, gamma=0.001 .............................................
# [CV] ................. C=1000, gamma=0.001, score=0.147, total=  20.6s
# [CV] C=1000, gamma=0.001 .............................................
# [CV] ................. C=1000, gamma=0.001, score=0.158, total=  22.5s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed: 10.0min finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=SVC(C=1.0, break_ties=False, cache_size=200,
#                            class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='scale', kernel='linear', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'C': [100, 500, 1000],
#                          'gamma': [0.0001, 0.005, 0.001]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %% [markdown]
# Evaluate Model

# %%
#Print best parameters and score from Gridsearch

print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'C': 1000, 'gamma': 0.0001}
# 0.14006462984723855

# %%
#Print accuracy of model using test dataset

print('Test Acc: %.3f' % grid.score(X_test_scaled, y_test))
# Out:
# Test Acc: 0.188

# %% [markdown]
# Predict World Series Champs

# %%
#Preprocess and predict 2015 MLB WS Champ
mlb_teams2015= pd.read_csv("2015.csv")

mlb2015_df = mlb_teams2015[['W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H',
       '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'SHO', 'SV', 'name']]

data2015_LG = mlb2015_df.copy()
data2015_bin = pd.get_dummies(data2015_LG, columns=["WSWin"])
data2015_bin = data2015_bin.drop(columns=['WSWin_N'])

feature2015 = data2015_bin.drop("name", axis=1)
team2015 = data2015_bin["name"]

X_feature2015_scaler = StandardScaler().fit(feature2015)
X_feature2015_scaled = X_feature2015_scaler.transform(feature2015)

predictions2015 = grid.predict(X_feature2015_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2015_scaled, team2015))
predictions2015 = model.predict(X_feature2015_scaled)
print(predictions2015)
# Out:
# Test Acc: 0.086
# ['Florida Marlins' 'Cleveland Indians' 'Chicago White Sox'
#  'Milwaukee Brewers' 'Tampa Bay Rays' 'Milwaukee Brewers'
#  'Cincinnati Reds' 'Philadelphia Phillies' 'Colorado Rockies'
#  'Kansas City Royals' 'Cincinnati Reds' 'Florida Marlins'
#  'Chicago White Sox' 'Tampa Bay Rays' 'Kansas City Royals'
#  'Milwaukee Brewers' 'San Francisco Giants' 'Atlanta Braves'
#  'Atlanta Braves' 'Toronto Blue Jays' 'Milwaukee Brewers'
#  'St. Louis Cardinals' 'Philadelphia Phillies' 'St. Louis Cardinals'
#  'Cincinnati Reds' 'San Francisco Giants' 'Seattle Mariners'
#  'Cincinnati Reds' 'Oakland Athletics' 'Atlanta Braves' 'Atlanta Braves'
#  'Atlanta Braves' 'Atlanta Braves' 'Atlanta Braves' 'Atlanta Braves']

# %%
#Preprocess and predict 2016 MLB WS Champ
mlb_teams2016= pd.read_csv("2016.csv")

mlb2016_df = mlb_teams2016[['W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H',
       '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'SHO', 'SV', 'name']]

data2016_LG = mlb2016_df.copy()
data2016_bin = pd.get_dummies(data2016_LG, columns=["WSWin"])
data2016_bin = data2016_bin.drop(columns=['WSWin_N'])

feature2016 = data2016_bin.drop("name", axis=1)
team2016 = data2016_bin["name"]

X_feature2016_scaler = StandardScaler().fit(feature2016)
X_feature2016_scaled = X_feature2016_scaler.transform(feature2016)

predictions2016 = grid.predict(X_feature2016_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2016_scaled, team2016))
predictions2016 = model.predict(X_feature2016_scaled)
print(predictions2016)
# Out:
# Test Acc: 0.029
# ['Colorado Rockies' 'Minnesota Twins' 'Baltimore Orioles'
#  'St. Louis Cardinals' 'San Francisco Giants' 'Chicago Cubs'
#  'Seattle Mariners' 'Cincinnati Reds' 'Detroit Tigers' 'Chicago White Sox'
#  'Cincinnati Reds' 'Pittsburgh Pirates' 'Seattle Mariners' 'New York Mets'
#  'San Francisco Giants' 'Cincinnati Reds' 'Milwaukee Brewers'
#  'Atlanta Braves' 'Chicago White Sox' 'Milwaukee Brewers'
#  'Florida Marlins' 'Philadelphia Phillies' 'Milwaukee Brewers'
#  'San Francisco Giants' 'Chicago White Sox' 'Detroit Tigers'
#  'Chicago Cubs' 'Chicago White Sox' 'Cincinnati Reds' 'Cincinnati Reds'
#  'Cleveland Indians' 'Cleveland Indians' 'Cleveland Indians'
#  'Cleveland Indians' 'Cleveland Indians']

# %%
#Preprocess and predict 2017 MLB WS Champ
mlb_teams2017= pd.read_csv("2017.csv")

mlb2017_df = mlb_teams2017[['W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H',
       '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'SHO', 'SV', 'name']]

data2017_LG = mlb2017_df.copy()
data2017_bin = pd.get_dummies(data2017_LG, columns=["WSWin"])
data2017_bin = data2017_bin.drop(columns=['WSWin_N'])

feature2017 = data2017_bin.drop("name", axis=1)
team2017 = data2017_bin["name"]

X_feature2017_scaler = StandardScaler().fit(feature2017)
X_feature2017_scaled = X_feature2017_scaler.transform(feature2017)

predictions2017 = grid.predict(X_feature2017_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2017_scaled, team2017))
predictions2017 = model.predict(X_feature2017_scaled)
print(predictions2017)
# Out:
# Test Acc: 0.057
# ['Philadelphia Phillies' 'Minnesota Twins' 'Baltimore Orioles'
#  'St. Louis Cardinals' 'San Francisco Giants' 'Detroit Tigers'
#  'Milwaukee Brewers' 'St. Louis Cardinals' 'San Francisco Giants'
#  'Detroit Tigers' 'Cincinnati Reds' 'Chicago White Sox' 'Cincinnati Reds'
#  'Cincinnati Reds' 'Milwaukee Brewers' 'Cincinnati Reds'
#  'Seattle Mariners' 'Detroit Tigers' 'Cincinnati Reds' 'Cincinnati Reds'
#  'Arizona Diamondbacks' 'San Francisco Giants' 'Florida Marlins'
#  'Minnesota Twins' 'Seattle Mariners' 'Cincinnati Reds' 'San Diego Padres'
#  'Cincinnati Reds' 'Baltimore Orioles' 'Philadelphia Phillies'
#  'Atlanta Braves' 'Atlanta Braves' 'Atlanta Braves' 'Atlanta Braves'
#  'Atlanta Braves']

# %%
#Preprocess and predict 2018 MLB WS Champ
mlb_teams2018= pd.read_csv("2018.csv")

mlb2018_df = mlb_teams2018[['W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H',
       '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'SHO', 'SV', 'name']]

data2018_LG = mlb2018_df.copy()
data2018_bin = pd.get_dummies(data2018_LG, columns=["WSWin"])
data2018_bin = data2018_bin.drop(columns=['WSWin_N'])

feature2018 = data2018_bin.drop("name", axis=1)
team2018 = data2018_bin["name"]

X_feature2018_scaler = StandardScaler().fit(feature2018)
X_feature2018_scaled = X_feature2018_scaler.transform(feature2018)

predictions2018 = grid.predict(X_feature2018_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2018_scaled, team2018))
predictions2018 = model.predict(X_feature2018_scaled)
print(predictions2018)
# Out:
# Test Acc: 0.029
# ['Philadelphia Phillies' 'Philadelphia Phillies' 'Seattle Mariners'
#  'Cincinnati Reds' 'San Francisco Giants' 'Colorado Rockies'
#  'Milwaukee Brewers' 'Oakland Athletics' 'Philadelphia Phillies'
#  'Pittsburgh Pirates' 'Atlanta Braves' 'Seattle Mariners'
#  'Chicago White Sox' 'Cincinnati Reds' 'Minnesota Twins' 'Cincinnati Reds'
#  'Minnesota Twins' 'San Francisco Giants' 'Cincinnati Reds'
#  'Boston Red Sox' 'Cincinnati Reds' 'Toronto Blue Jays'
#  'Philadelphia Phillies' 'Houston Astros' 'Chicago White Sox'
#  'Atlanta Braves' 'St. Louis Cardinals' 'Milwaukee Brewers'
#  'Milwaukee Brewers' 'Cincinnati Reds' 'Atlanta Braves' 'Atlanta Braves'
#  'Atlanta Braves' 'Atlanta Braves' 'Atlanta Braves']

# %%
#Preprocess and predict 2019 MLB WS Champ
mlb2019_teams= pd.read_csv("MLB 2019 season.csv")

mlb2019_df = mlb2019_teams[['W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H',
       '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'SHO', 'SV', 'name']]

data2019_LG = mlb2019_df.copy()
data2019_bin = pd.get_dummies(data2019_LG, columns=["WSWin"])
data2019_bin = data2019_bin.drop(columns=['WSWin_N'])

feature2019 = data2019_bin.drop("name", axis=1)
team2019 = data2019_bin["name"]

X_feature2019_scaler = StandardScaler().fit(feature2019)
X_feature2019_scaled = X_feature2019_scaler.transform(feature2019)

predictions2019 = grid.predict(X_feature2019_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2019_scaled, team2019))
predictions2019 = model.predict(X_feature2019_scaled)
print(predictions2019)
# Out:
# Test Acc: 0.000
# ['Toronto Blue Jays' 'Cincinnati Reds' 'Milwaukee Brewers'
#  'Philadelphia Phillies' 'Texas Rangers' 'San Francisco Giants'
#  'Chicago White Sox' 'Cincinnati Reds' 'Colorado Rockies'
#  'Arizona Diamondbacks' 'Toronto Blue Jays' 'Kansas City Royals'
#  'Cleveland Indians' 'Atlanta Braves' 'Minnesota Twins' 'Cincinnati Reds'
#  'Atlanta Braves' 'Chicago White Sox' 'Seattle Mariners'
#  'Chicago White Sox' 'Philadelphia Phillies' 'Kansas City Royals'
#  'San Diego Padres' 'Philadelphia Phillies' 'Pittsburgh Pirates'
#  'Chicago White Sox' 'Cincinnati Reds' 'Florida Marlins'
#  'Milwaukee Brewers' 'Cincinnati Reds' 'Atlanta Braves' 'Atlanta Braves'
#  'Atlanta Braves' 'Atlanta Braves' 'Atlanta Braves']

# %%
#Preprocess and predict 2020 MLB WS Champ
mlb2020_teams= pd.read_csv("2020.csv")

mlb2020_df = mlb2020_teams[['W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H',
       '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'SHO', 'SV', 'name']]



data2020_LG = mlb2020_df.copy()
data2020_bin = pd.get_dummies(data2020_LG, columns=["WSWin"])
data2020_bin = data2020_bin.drop(columns=["WSWin_N"])

feature2020 = data2020_bin.drop("name", axis=1)
team2020 = data2020_bin["name"]

X_feature2020_scaler = StandardScaler().fit(feature2020)
X_feature2020_scaled = X_feature2020_scaler.transform(feature2020)

predictions2020 = grid.predict(X_feature2020_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2020_scaled, team2020))
predictions2020 = model.predict(X_feature2020_scaled)
print(predictions2020)
# Out:
# Test Acc: 0.029
# ['Toronto Blue Jays' 'New York Mets' 'New York Mets' 'New York Mets'
#  'Cincinnati Reds' 'Atlanta Braves' 'Cincinnati Reds' 'Cincinnati Reds'
#  'Pittsburgh Pirates' 'Toronto Blue Jays' 'Toronto Blue Jays'
#  'Florida Marlins' 'Chicago Cubs' 'Chicago White Sox'
#  'St. Louis Cardinals' 'Chicago Cubs' 'Atlanta Braves' 'Chicago Cubs'
#  'Cincinnati Reds' 'Philadelphia Phillies' 'Seattle Mariners'
#  'Milwaukee Brewers' 'Philadelphia Phillies' 'Colorado Rockies'
#  'Cleveland Indians' 'San Francisco Giants' 'Philadelphia Phillies'
#  'Florida Marlins' 'Seattle Mariners' 'Kansas City Royals'
#  'Atlanta Braves' 'Atlanta Braves' 'Atlanta Braves' 'Atlanta Braves'
#  'Atlanta Braves']
