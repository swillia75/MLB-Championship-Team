# %%
#import numpy to use seed 
import numpy as np
import pandas as pd
from numpy.random import seed
np.random.seed(1)

# %% [markdown]
# Read CSV create, and clean dataframe

# %%
#Read in CSV and create dataframe
mlb_teams= pd.read_csv("Teams.csv")
mlb_teams=mlb_teams.dropna()

mlb_teams
# Out:
#       yearID lgID      G   G.1     W      L  WPCT WSWin      R      AB  ...  \
# 0     2014.0   NL  162.0  81.0  64.0   98.0  0.57     N  615.0  5552.0  ...
# 1     2014.0   NL  162.0  81.0  79.0   83.0  0.67     N  573.0  5468.0  ...
# 2     2014.0   AL  162.0  81.0  96.0   66.0  0.54     N  705.0  5596.0  ...
# 3     2014.0   AL  162.0  81.0  71.0   91.0  0.44     N  634.0  5551.0  ...
# 4     2014.0   NL  162.0  81.0  73.0   89.0  0.42     N  614.0  5508.0  ...
# ...      ...  ...    ...   ...   ...    ...   ...   ...    ...     ...  ...
# 1224  1969.0   NL  162.0  81.0  88.0   74.0  0.56     N  725.0  5626.0  ...
# 1225  1969.0   NL  162.0  81.0  52.0  110.0  0.46     N  468.0  5357.0  ...
# 1226  1969.0   NL  162.0  81.0  90.0   72.0  0.53     N  713.0  5474.0  ...
# 1227  1969.0   NL  162.0  80.0  87.0   75.0  0.40     N  595.0  5536.0  ...
# 1228  1969.0   AL  162.0  81.0  86.0   76.0  0.49     N  694.0  5447.0  ...
#
#         3B     HR     BB      SO    SB   ERA    CG   SHO    SV  \
# 0     47.0  118.0  398.0  1165.0  86.0  4.26   2.0   4.0  35.0
# 1     22.0  123.0  472.0  1369.0  95.0  3.38   5.0  13.0  54.0
# 2     16.0  211.0  401.0  1285.0  44.0  3.43   3.0  13.0  53.0
# 3     20.0  123.0  535.0  1337.0  63.0  4.01   3.0   7.0  36.0
# 4     31.0  157.0  442.0  1477.0  65.0  3.91   1.0  11.0  37.0
# ...    ...    ...    ...     ...   ...   ...   ...   ...   ...
# 1224  52.0  119.0  454.0   944.0  74.0  3.61  39.0   9.0  33.0
# 1225  42.0   99.0  423.0  1143.0  45.0  4.24  16.0   9.0  25.0
# 1226  28.0  136.0  711.0  1054.0  71.0  3.26  71.0  15.0  17.0
# 1227  44.0   90.0  503.0   876.0  87.0  2.94  63.0  12.0  26.0
# 1228  40.0  148.0  630.0   900.0  52.0  3.49  28.0  10.0  41.0
#
#                       name
# 0     Arizona Diamondbacks
# 1           Atlanta Braves
# 2        Baltimore Orioles
# 3           Boston Red Sox
# 4             Chicago Cubs
# ...                    ...
# 1224    Pittsburgh Pirates
# 1225      San Diego Padres
# 1226  San Francisco Giants
# 1227   St. Louis Cardinals
# 1228   Washington Senators
#
# [1229 rows x 22 columns]

# %%
#Get list of dataframe columns

mlb_teams.columns
# Out:
# Index(['yearID', 'lgID', 'G', 'G.1', 'W', 'L', 'WPCT', 'WSWin', 'R', 'AB', 'H',
#        '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV', 'name'],
#       dtype='object')

# %%
#Select columns for dataframe

mlb_df = mlb_teams[['yearID', 'lgID', 'W', 'L', 'WSWin', 'WSWin', 'R', 'AB', 'H', '2B',
       '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV', 'name']
# 1224  52.0  119.0  454.0   944.0   74.0  3.61  39.0   9.0  33.0
# 1225  42.0   99.0  423.0  1143.0   45.0  4.24  16.0   9.0  25.0
# 1226  28.0  136.0  711.0  1054.0   71.0  3.26  71.0  15.0  17.0
# 1227  44.0   90.0  503.0   876.0   87.0  2.94  63.0  12.0  26.0
# 1228  40.0  148.0  630.0   900.0   52.0  3.49  28.0  10.0  41.0
#
#                        name
# 1192     Kansas City Royals
# 1193    Los Angeles Dodgers
# 1194      Milwaukee Brewers
# 1195        Minnesota Twins
# 1196         Montreal Expos
# 1197          New York Mets
# 1198       New York Yankees
# 1199      Oakland Athletics
# 1200  Philadelphia Phillies
# 1201     Pittsburgh Pirates
# 1202       San Diego Padres
# 1203   San Francisco Giants
# 1204    St. Louis Cardinals
# 1205    Washington Senators
# 1206         Atlanta Braves
# 1207      Baltimore Orioles
# 1208         Boston Red Sox
# 1209      California Angels
# 1210           Chicago Cubs
# 1211      Chicago White Sox
# 1212        Cincinnati Reds
# 1213      Cleveland Indians
# 1214         Detroit Tigers
# 1215         Houston Astros
# 1216     Kansas City Royals
# 1217    Los Angeles Dodgers
# 1218        Minnesota Twins
# 1219         Montreal Expos
# 1220          New York Mets
# 1221       New York Yankees
# 1222      Oakland Athletics
# 1223  Philadelphia Phillies
# 1224     Pittsburgh Pirates
# 1225       San Diego Padres
# 1226   San Francisco Giants
# 1227    St. Louis Cardinals
# 1228    Washington Senators

# %%
#Use getdummies to convert strings

data_LG = mlb_df.copy()
data_bin = pd.get_dummies(data_LG, columns=["WSWin", 'lgID'])
data_bin = data_bin.drop(columns=['WSWin_N', 'lgID_AL'])

data_bin.head()
# Out:
#    yearID     W     L      R      AB       H     2B    3B     HR     BB  \
# 0  2014.0  64.0  98.0  615.0  5552.0  1379.0  259.0  47.0  118.0  398.0
# 1  2014.0  79.0  83.0  573.0  5468.0  1316.0  240.0  22.0  123.0  472.0
# 2  2014.0  96.0  66.0  705.0  5596.0  1434.0  264.0  16.0  211.0  401.0
# 3  2014.0  71.0  91.0  634.0  5551.0  1355.0  282.0  20.0  123.0  535.0
# 4  2014.0  73.0  89.0  614.0  5508.0  1315.0  270.0  31.0  157.0  442.0
#
#        SO    SB   ERA   CG   SHO    SV                  name  WSWin_Y  \
# 0  1165.0  86.0  4.26  2.0   4.0  35.0  Arizona Diamondbacks        0
# 1  1369.0  95.0  3.38  5.0  13.0  54.0        Atlanta Braves        0
# 2  1285.0  44.0  3.43  3.0  13.0  53.0     Baltimore Orioles        0
# 3  1337.0  63.0  4.01  3.0   7.0  36.0        Boston Red Sox        0
# 4  1477.0  65.0  3.91  1.0  11.0  37.0          Chicago Cubs        0
#
#    WSWin_Y  lgID_NL
# 0        0        1
# 1        0        1
# 2        0        0
# 3        0        0
# 4        0        1

# %%
#Set X(data) and y(outcome)variables

data = data_bin.drop("name", axis = 1)
outcome = data_bin["name"]
print(data.shape, outcome.shape)
# Out:
# (1229, 19) (1229,)

# %% [markdown]
# Preprocess data

# %%
#Import SciKit libraries

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
#Split data and teams into training and test data

X_train, X_test, y_train, y_test = train_test_split(data, outcome, test_size = 0.2, random_state=42)
y_train
# Out:
# 752        Atlanta Braves
# 1067    Chicago White Sox
# 986        Atlanta Braves
# 425          Chicago Cubs
# 644      Seattle Mariners
#               ...
# 1044      Cincinnati Reds
# 1095       Houston Astros
# 1130     San Diego Padres
# 860          Chicago Cubs
# 1126     New York Yankees
# Name: name, Length: 983, dtype: object

# %%
#Scale data using StandardScaler

X_scaler = StandardScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
X_train_scaled
# Out:
# array([[-0.40931253, -0.90002007,  0.97880179, ..., -0.18343607,
#         -0.18343607,  0.99088589],
#        [-1.30859556, -0.39762386,  0.47222291, ..., -0.18343607,
#         -0.18343607, -1.00919795],
#        [-1.08377481, -0.90002007,  1.06323161, ..., -0.18343607,
#         -0.18343607,  0.99088589],
#        ...,
#        [-1.45847607, -1.65361439,  1.82309994, ..., -0.18343607,
#         -0.18343607,  0.99088589],
#        [-0.70907354, -0.73255467,  0.89437198, ..., -0.18343607,
#         -0.18343607,  0.99088589],
#        [-1.45847607,  0.02103965,  0.13450365, ..., -0.18343607,
#         -0.18343607, -1.00919795]])

# %%
##Import RandomForestClassifier and train

from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=1000, random_state=1)

rf.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=1000,
#                        n_jobs=None, oob_score=False, random_state=1, verbose=0,
#                        warm_start=False)

# %%
#Get Score for RandomForestClassifier
rf.score(X_test_scaled, y_test)
# Out:
# 0.2682926829268293

# %%
#Print data scores for training aand test datasets
print(f"Training Data Score: {rf.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {rf.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 1.0
# Testing Data Score: 0.2682926829268293

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {"bootstrap": [True],
              "max_depth": [20, 40, 100, 125],
              "n_estimators": [100, 500, 1000]
              }
grid = GridSearchCV(rf, param_grid, verbose=3)
grid
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=1000, n_jobs=None,
#                                               oob_score=False, random_state=1,
#                                               verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'bootstrap': [True], 'max_depth': [20, 40, 100, 125],
#                          'n_estimators': [100, 500, 1000]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %% [markdown]
# Train Model

# %%
# Train the model with GridSearch

grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] bootstrap=True, max_depth=20, n_estimators=100 ..................
# C:\Users\swill\Anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_split.py:667: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  bootstrap=True, max_depth=20, n_estimators=100, score=0.264, total=   0.9s
# [CV] bootstrap=True, max_depth=20, n_estimators=100 ..................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [CV]  bootstrap=True, max_depth=20, n_estimators=100, score=0.284, total=   0.8s
# [CV] bootstrap=True, max_depth=20, n_estimators=100 ..................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.6s remaining:    0.0s
# [CV]  bootstrap=True, max_depth=20, n_estimators=100, score=0.284, total=   0.8s
# [CV] bootstrap=True, max_depth=20, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=100, score=0.306, total=   0.9s
# [CV] bootstrap=True, max_depth=20, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=100, score=0.286, total=   0.8s
# [CV] bootstrap=True, max_depth=20, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=500, score=0.305, total=   4.2s
# [CV] bootstrap=True, max_depth=20, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=500, score=0.310, total=   4.2s
# [CV] bootstrap=True, max_depth=20, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=500, score=0.264, total=   4.1s
# [CV] bootstrap=True, max_depth=20, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=500, score=0.316, total=   4.2s
# [CV] bootstrap=True, max_depth=20, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=500, score=0.296, total=   4.2s
# [CV] bootstrap=True, max_depth=20, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=20, n_estimators=1000, score=0.299, total=   9.0s
# [CV] bootstrap=True, max_depth=20, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=20, n_estimators=1000, score=0.305, total=   8.9s
# [CV] bootstrap=True, max_depth=20, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=20, n_estimators=1000, score=0.264, total=   8.6s
# [CV] bootstrap=True, max_depth=20, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=20, n_estimators=1000, score=0.327, total=   8.6s
# [CV] bootstrap=True, max_depth=20, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=20, n_estimators=1000, score=0.296, total=   8.6s
# [CV] bootstrap=True, max_depth=40, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=100, score=0.254, total=   0.8s
# [CV] bootstrap=True, max_depth=40, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=100, score=0.284, total=   0.8s
# [CV] bootstrap=True, max_depth=40, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=100, score=0.274, total=   0.8s
# [CV] bootstrap=True, max_depth=40, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=100, score=0.311, total=   0.8s
# [CV] bootstrap=True, max_depth=40, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=100, score=0.281, total=   0.8s
# [CV] bootstrap=True, max_depth=40, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=500, score=0.320, total=   4.2s
# [CV] bootstrap=True, max_depth=40, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=500, score=0.294, total=   4.2s
# [CV] bootstrap=True, max_depth=40, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=500, score=0.299, total=   4.2s
# [CV] bootstrap=True, max_depth=40, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=500, score=0.327, total=   4.1s
# [CV] bootstrap=True, max_depth=40, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=500, score=0.276, total=   4.2s
# [CV] bootstrap=True, max_depth=40, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=40, n_estimators=1000, score=0.289, total=   9.1s
# [CV] bootstrap=True, max_depth=40, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=40, n_estimators=1000, score=0.315, total=   8.6s
# [CV] bootstrap=True, max_depth=40, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=40, n_estimators=1000, score=0.264, total=   8.5s
# [CV] bootstrap=True, max_depth=40, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=40, n_estimators=1000, score=0.332, total=   7.2s
# [CV] bootstrap=True, max_depth=40, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=40, n_estimators=1000, score=0.281, total=   7.7s
# [CV] bootstrap=True, max_depth=100, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=100, score=0.254, total=   0.5s
# [CV] bootstrap=True, max_depth=100, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=100, score=0.284, total=   0.9s
# [CV] bootstrap=True, max_depth=100, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=100, score=0.274, total=   0.9s
# [CV] bootstrap=True, max_depth=100, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=100, score=0.311, total=   0.9s
# [CV] bootstrap=True, max_depth=100, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=100, score=0.281, total=   0.9s
# [CV] bootstrap=True, max_depth=100, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=500, score=0.320, total=   4.3s
# [CV] bootstrap=True, max_depth=100, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=500, score=0.294, total=   4.1s
# [CV] bootstrap=True, max_depth=100, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=500, score=0.299, total=   4.1s
# [CV] bootstrap=True, max_depth=100, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=500, score=0.327, total=   4.2s
# [CV] bootstrap=True, max_depth=100, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=500, score=0.276, total=   4.1s
# [CV] bootstrap=True, max_depth=100, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=100, n_estimators=1000, score=0.289, total=   9.2s
# [CV] bootstrap=True, max_depth=100, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=100, n_estimators=1000, score=0.315, total=   8.8s
# [CV] bootstrap=True, max_depth=100, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=100, n_estimators=1000, score=0.264, total=   8.4s
# [CV] bootstrap=True, max_depth=100, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=100, n_estimators=1000, score=0.332, total=   8.6s
# [CV] bootstrap=True, max_depth=100, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=100, n_estimators=1000, score=0.281, total=   8.4s
# [CV] bootstrap=True, max_depth=125, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=100, score=0.254, total=   0.8s
# [CV] bootstrap=True, max_depth=125, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=100, score=0.284, total=   0.9s
# [CV] bootstrap=True, max_depth=125, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=100, score=0.274, total=   0.8s
# [CV] bootstrap=True, max_depth=125, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=100, score=0.311, total=   0.8s
# [CV] bootstrap=True, max_depth=125, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=100, score=0.281, total=   0.8s
# [CV] bootstrap=True, max_depth=125, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=500, score=0.320, total=   4.1s
# [CV] bootstrap=True, max_depth=125, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=500, score=0.294, total=   4.2s
# [CV] bootstrap=True, max_depth=125, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=500, score=0.299, total=   4.0s
# [CV] bootstrap=True, max_depth=125, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=500, score=0.327, total=   4.2s
# [CV] bootstrap=True, max_depth=125, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=500, score=0.276, total=   4.3s
# [CV] bootstrap=True, max_depth=125, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=125, n_estimators=1000, score=0.289, total=   8.7s
# [CV] bootstrap=True, max_depth=125, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=125, n_estimators=1000, score=0.315, total=   7.8s
# [CV] bootstrap=True, max_depth=125, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=125, n_estimators=1000, score=0.264, total=   8.2s
# [CV] bootstrap=True, max_depth=125, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=125, n_estimators=1000, score=0.332, total=   7.9s
# [CV] bootstrap=True, max_depth=125, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=125, n_estimators=1000, score=0.281, total=   8.4s
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:  4.5min finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=1000, n_jobs=None,
#                                               oob_score=False, random_state=1,
#                                               verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'bootstrap': [True], 'max_depth': [20, 40, 100, 125],
#                          'n_estimators': [100, 500, 1000]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %% [markdown]
# Evaluate Model

# %%
#Print best parameter and score 

print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'bootstrap': True, 'max_depth': 40, 'n_estimators': 500}
# 0.30314928001657515

# %% [markdown]
# Use model to Predict World Series Champions

# %%
#Preprocess and predict 2015 MLB WS Champ
mlb_teams2015= pd.read_csv("2015.csv")

mlb2015_df = mlb_teams2015[['yearID', 'lgID', 'W', 'L', 'WSWin', 'WSWin', 'R', 'AB', 'H', '2B',
       '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV', 'name']]

data2015_LG = mlb2015_df.copy()
data2015_bin = pd.get_dummies(data2015_LG, columns=["WSWin", "lgID"])
data2015_bin = data2015_bin.drop(columns=['WSWin_N', 'lgID_AL'])

feature2015 = data2015_bin.drop("name", axis=1)
team2015 = data2015_bin["name"]

X_feature2015_scaler = StandardScaler().fit(feature2015)
X_feature2015_scaled = X_feature2015_scaler.transform(feature2015)

predictions2015 = grid.predict(X_feature2015_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2015_scaled, team2015))
predictions2015 = rf.predict(X_feature2015_scaled)
print(predictions2015)
# Out:
# Test Acc: 0.133
# ['Pittsburgh Pirates' 'Atlanta Braves' 'Cleveland Indians'
#  'Minnesota Twins' 'Cincinnati Reds' 'Cleveland Indians'
#  'San Diego Padres' 'Boston Red Sox' 'Colorado Rockies'
#  'Kansas City Royals' 'Oakland Athletics' 'Kansas City Royals'
#  'Cleveland Indians' 'San Francisco Giants' 'New York Mets'
#  'Philadelphia Phillies' 'Kansas City Royals' 'New York Mets'
#  'Baltimore Orioles' 'Kansas City Royals' 'Pittsburgh Pirates'
#  'Los Angeles Dodgers' 'Philadelphia Phillies' 'St. Louis Cardinals'
#  'Chicago White Sox' 'San Francisco Giants' 'Kansas City Royals'
#  'Chicago White Sox' 'Boston Red Sox' 'New York Mets']

# %% [markdown]
# Evaluate Model

# %%
#Preprocess and predict 2016 MLB WS Champ
mlb_teams2016= pd.read_csv("2016.csv")

mlb2016_df = mlb_teams2016[['yearID', 'lgID', 'W', 'L', 'WSWin', 'WSWin', 'R', 'AB', 'H', '2B',
       '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV', 'name']]

data2016_LG = mlb2016_df.copy()
data2016_bin = pd.get_dummies(data2016_LG, columns=["WSWin", "lgID"])
data2016_bin = data2016_bin.drop(columns=['WSWin_N', 'lgID_AL'])

feature2016 = data2016_bin.drop("name", axis=1)
team2016 = data2016_bin["name"]

X_feature2016_scaler = StandardScaler().fit(feature2016)
X_feature2016_scaled = X_feature2016_scaler.transform(feature2016)

predictions2016 = grid.predict(X_feature2016_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2016_scaled, team2016))
predictions2016 = rf.predict(X_feature2016_scaled)
print(predictions2016)
# Out:
# Test Acc: 0.200
# ['Colorado Rockies' 'Philadelphia Phillies' 'Chicago White Sox'
#  'Boston Red Sox' 'San Francisco Giants' 'Kansas City Royals'
#  'Pittsburgh Pirates' 'Chicago White Sox' 'Colorado Rockies'
#  'Detroit Tigers' 'Oakland Athletics' 'Kansas City Royals'
#  'Seattle Mariners' 'New York Mets' 'St. Louis Cardinals'
#  'San Diego Padres' 'Tampa Bay Devil Rays' 'New York Mets'
#  'New York Yankees' 'Cleveland Indians' 'San Diego Padres'
#  'Philadelphia Phillies' 'San Diego Padres' 'St. Louis Cardinals'
#  'Baltimore Orioles' 'Arizona Diamondbacks' 'Detroit Tigers'
#  'Chicago White Sox' 'Oakland Athletics' 'Los Angeles Dodgers']

# %% [markdown]
# Predict World Series Champs

# %%
#Preprocess and predict 2017 MLB WS Champ
mlb_teams2017= pd.read_csv("2017.csv")

mlb2017_df = mlb_teams2017[['yearID', 'lgID', 'W', 'L', 'WSWin', 'WSWin', 'R', 'AB', 'H', '2B',
       '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV', 'name']]

data2017_LG = mlb2017_df.copy()
data2017_bin = pd.get_dummies(data2017_LG, columns=["WSWin", "lgID"])
data2017_bin = data2017_bin.drop(columns=['WSWin_N', 'lgID_AL'])

feature2017 = data2017_bin.drop("name", axis=1)
team2017 = data2017_bin["name"]

X_feature2017_scaler = StandardScaler().fit(feature2017)
X_feature2017_scaled = X_feature2017_scaler.transform(feature2017)

predictions2017 = grid.predict(X_feature2017_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2017_scaled, team2017))
predictions2017 = rf.predict(X_feature2017_scaled)
print(predictions2017)
# Out:
# Test Acc: 0.167
# ['Philadelphia Phillies' 'Pittsburgh Pirates' 'Baltimore Orioles'
#  'Minnesota Twins' 'San Francisco Giants' 'Detroit Tigers'
#  'San Diego Padres' 'Boston Red Sox' 'St. Louis Cardinals'
#  'Minnesota Twins' 'Boston Red Sox' 'Cleveland Indians'
#  'Oakland Athletics' 'Atlanta Braves' 'Chicago Cubs' 'Cincinnati Reds'
#  'Chicago White Sox' 'Chicago Cubs' 'New York Yankees' 'Cleveland Indians'
#  'Philadelphia Phillies' 'San Francisco Giants' 'San Diego Padres'
#  'New York Mets' 'Seattle Mariners' 'San Francisco Giants'
#  'Detroit Tigers' 'Oakland Athletics' 'Baltimore Orioles'
#  'Philadelphia Phillies']

# %%
#Preprocess and predict 2018 MLB WS Champ
mlb_teams2018= pd.read_csv("2018.csv")

mlb2018_df = mlb_teams2018[['yearID', 'lgID', 'W', 'L', 'WSWin', 'WSWin', 'R', 'AB', 'H', '2B',
       '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV', 'name']]

data2018_LG = mlb2018_df.copy()
data2018_bin = pd.get_dummies(data2018_LG, columns=["WSWin", "lgID"])
data2018_bin = data2018_bin.drop(columns=['WSWin_N', 'lgID_AL'])

feature2018 = data2018_bin.drop("name", axis=1)
team2018 = data2018_bin["name"]

X_feature2018_scaler = StandardScaler().fit(feature2018)
X_feature2018_scaled = X_feature2018_scaler.transform(feature2018)

predictions2018 = grid.predict(X_feature2018_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2018_scaled, team2018))
predictions2018 = rf.predict(X_feature2018_scaled)
print(predictions2018)
# Out:
# Test Acc: 0.100
# ['Philadelphia Phillies' 'St. Louis Cardinals' 'Detroit Tigers'
#  'Boston Red Sox' 'St. Louis Cardinals' 'Tampa Bay Devil Rays'
#  'San Diego Padres' 'New York Yankees' 'San Francisco Giants'
#  'Kansas City Royals' 'Baltimore Orioles' 'Seattle Mariners'
#  'Baltimore Orioles' 'San Francisco Giants' 'San Diego Padres'
#  'Los Angeles Dodgers' 'Boston Red Sox' 'Philadelphia Phillies'
#  'New York Yankees' 'Boston Red Sox' 'San Diego Padres' 'Montreal Expos'
#  'San Diego Padres' 'Philadelphia Phillies' 'Kansas City Royals'
#  'Atlanta Braves' 'Kansas City Royals' 'Oakland Athletics'
#  'Cleveland Indians' 'Cincinnati Reds']

# %%
#Preprocess and predict 2019 MLB WS Champ
mlb2019_teams= pd.read_csv("MLB 2019 season.csv")

mlb2019_df = mlb2019_teams[['yearID', 'lgID', 'W', 'L', 'WSWin', 'WSWin', 'R', 'AB', 'H', '2B',
       '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV', 'name']]

data2019_LG = mlb2019_df.copy()
data2019_bin = pd.get_dummies(data2019_LG, columns=["WSWin", "lgID"])
data2019_bin = data2019_bin.drop(columns=['WSWin_N', 'lgID_AL'])

feature2019 = data2019_bin.drop("name", axis=1)
team2019 = data2019_bin["name"]

X_feature2019_scaler = StandardScaler().fit(feature2019)
X_feature2019_scaled = X_feature2019_scaler.transform(feature2019)

predictions2019 = grid.predict(X_feature2019_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2019_scaled, team2019))
predictions2019 = rf.predict(X_feature2019_scaled)
print(predictions2019)
# Out:
# Test Acc: 0.267
# ['Pittsburgh Pirates' 'San Francisco Giants' 'Kansas City Royals'
#  'Boston Red Sox' 'Cleveland Indians' 'Chicago Cubs'
#  'San Francisco Giants' 'Baltimore Orioles' 'Colorado Rockies'
#  'Detroit Tigers' 'New York Yankees' 'Kansas City Royals'
#  'Baltimore Orioles' 'New York Mets' 'San Diego Padres' 'San Diego Padres'
#  'Boston Red Sox' 'New York Yankees' 'Chicago Cubs' 'Boston Red Sox'
#  'Philadelphia Phillies' 'St. Louis Cardinals' 'San Diego Padres'
#  'Oakland Athletics' 'Philadelphia Phillies' 'Los Angeles Dodgers'
#  'Kansas City Royals' 'Oakland Athletics' 'Cleveland Indians'
#  'Cincinnati Reds']

# %%
#Preprocess and predict 2020 MLB WS Champ
mlb2020_teams= pd.read_csv("2020.csv")

mlb2020_df = mlb2020_teams[['yearID', 'lgID', 'W', 'L', 'WSWin', 'WSWin', 'R', 'AB', 'H', '2B',
       '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV', 'name']]

data2020_LG = mlb2020_df.copy()
data2020_bin = pd.get_dummies(data2020_LG, columns=["WSWin", "lgID"])
data2020_bin = data2020_bin.drop(columns=['lgID_AL'])

feature2020 = data2020_bin.drop("name", axis=1)
team2020 = data2020_bin["name"]

X_feature2020_scaler = StandardScaler().fit(feature2020)
X_feature2020_scaled = X_feature2020_scaler.transform(feature2020)

predictions2020 = grid.predict(X_feature2020_scaled)
print('Test Acc: %.3f' % grid.score(X_feature2020_scaled, team2020))
predictions2020 = rf.predict(X_feature2020_scaled)
print(predictions2020)
# Out:
# Test Acc: 0.033
# ['Pittsburgh Pirates' 'Boston Red Sox' 'Kansas City Royals'
#  'Detroit Tigers' 'San Francisco Giants' 'Detroit Tigers'
#  'Los Angeles Dodgers' 'Baltimore Orioles' 'Pittsburgh Pirates'
#  'California Angels' 'Kansas City Royals' 'Seattle Mariners'
#  'Detroit Tigers' 'Atlanta Braves' 'Houston Astros'
#  'Philadelphia Phillies' 'Baltimore Orioles' 'Atlanta Braves'
#  'Detroit Tigers' 'Baltimore Orioles' 'Chicago Cubs' 'San Diego Padres'
#  'Cincinnati Reds' 'Colorado Rockies' 'Texas Rangers' 'Atlanta Braves'
#  'Tampa Bay Rays' 'Oakland Athletics' 'Baltimore Orioles'
#  'Colorado Rockies']

# %%
import joblib
filename = 'SWilliams_RFC.sav'
joblib.dump(rf, filename)
# Out:
# ['SWilliams_RFC.sav']
