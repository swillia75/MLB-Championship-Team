# %%
#import numpy to use seed 
import numpy as np
import pandas as pd
from numpy.random import seed
np.random.seed(1)

# %%
#import other dependencies

import os
import tensorflow 
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense

# %% [markdown]
# Read CSV create, and clean dataframe

# %%
#Read in CSV and create dataframe
mlb_teams= pd.read_csv("Teams.csv")

mlb_teams
# Out:
#       yearID lgID    G  G.1   W   L WSWin    R    AB     H  ...  3B   HR   BB  \
# 0       1997   AL  162   82  84  78     N  829  5628  1531  ...  25  161  617
# 1       1998   AL  162   81  85  77     N  787  5630  1530  ...  27  147  510
# 2       1999   AL  162   81  70  92     N  711  5494  1404  ...  22  158  511
# 3       2000   AL  162   81  82  80     N  864  5628  1574  ...  34  236  608
# 4       2001   AL  162   81  75  87     N  691  5551  1447  ...  26  158  494
# ...      ...  ...  ...  ...  ..  ..   ...  ...   ...   ...  ...  ..  ...  ...
# 1344    2017   NL  162   81  97  65     N  819  5553  1477  ...  31  215  542
# 1345    2018   NL  162   81  82  80     N  771  5517  1402  ...  25  191  631
# 1346    1969   AL  162   81  86  76     N  694  5447  1365  ...  40  148  630
# 1347    1970   AL  162   81  70  92     N  626  5460  1302  ...  28  138  635
# 1348    1971   AL  159   81  63  96     N  537  5290  1219  ...  30   86  575
#
#         SO   SB   ERA  CG  SHO  SV                  name
# 0      953  126  4.52   9    5  39        Anaheim Angels
# 1     1028   93  4.49   3    5  52        Anaheim Angels
# 2     1022   71  4.79   4    7  37        Anaheim Angels
# 3     1024   93  5.00   5    3  46        Anaheim Angels
# 4     1001  116  4.20   6    1  43        Anaheim Angels
# ...    ...  ...   ...  ..  ...  ..                   ...
# 1344  1327  108  3.88   3    5  46  Washington Nationals
# 1345  1289  119  4.04   2    7  40  Washington Nationals
# 1346   900   52  3.49  28   10  41   Washington Senators
# 1347   989   72  3.80  20   11  40   Washington Senators
# 1348   956   68  3.70  30   10  26   Washington Senators
#
# [1349 rows x 21 columns]

# %%
#Get list of dataframe columns

mlb_teams.columns
# Out:
# Index(['yearID', 'lgID', 'G', 'G.1', 'W', 'L', 'WSWin', 'R', 'AB', 'H', '2B',
#        '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV', 'name'],
#       dtype='object')

# %%
#Select columns for dataframe

mlb_df = mlb_teams[['yearID', 'lgID', 'W', 'L', 'WSWin', 'R', 'AB', 'H', '2B',
       '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV', 'name']]


mlb_df.tail(37)
# Out:
#       yearID lgID   W    L WSWin    R    AB     H   2B  3B   HR   BB    SO  \
# 1312    1999   AL  84   78     N  883  5642  1580  337  14  212  578  1077
# 1313    2000   AL  83   79     N  861  5677  1562  328  21  244  526  1026
# 1314    2001   AL  80   82     N  767  5663  1489  287  36  195  470  1094
# 1315    2002   AL  78   84     N  813  5581  1457  305  38  187  522  1142
# 1316    2003   AL  86   76     N  894  5661  1580  357  33  190  546  1081
# 1317    2004   AL  67   94     N  719  5531  1438  290  34  145  513  1083
# 1318    2005   AL  80   82     N  775  5581  1480  307  39  136  486   955
# 1319    2006   AL  87   75     N  809  5596  1591  348  27  199  514   906
# 1320    2007   AL  83   79     N  753  5536  1434  344  24  165  533  1044
# 1321    2008   AL  86   76     N  714  5503  1453  303  32  126  521   938
# 1322    2009   AL  75   87     N  798  5696  1516  339  13  209  548  1028
# 1323    2010   AL  85   77     N  755  5495  1364  319  21  257  471  1164
# 1324    2011   AL  81   81     N  743  5559  1384  285  34  186  525  1184
# 1325    2012   AL  73   89     N  716  5487  1346  247  22  198  473  1251
# 1326    2013   AL  74   88     N  712  5537  1398  273  24  185  510  1123
# 1327    2014   AL  83   79     N  723  5549  1435  282  24  177  502  1151
# 1337  110  4.13   2    5  37  Washington Nationals
# 1338  106  3.58   3   10  49  Washington Nationals
# 1339  105  3.33   3    9  51  Washington Nationals
# 1340   88  3.59   6   13  47  Washington Nationals
# 1341  101  3.03   5   19  45  Washington Nationals
# 1342   57  3.62   4   13  41  Washington Nationals
# 1343  121  3.51   1   12  46  Washington Nationals
# 1344  108  3.88   3    5  46  Washington Nationals
# 1345  119  4.04   2    7  40  Washington Nationals
# 1346   52  3.49  28   10  41   Washington Senators
# 1347   72  3.80  20   11  40   Washington Senators
# 1348   68  3.70  30   10  26   Washington Senators

# %%
#Use getdummies to convert strings

data_LG = mlb_df.copy()
data_bin = pd.get_dummies(data_LG, columns=["WSWin", 'lgID'])
data_bin = data_bin.drop(columns=['WSWin_N', 'lgID_AL'])

data_bin.head()
# Out:
#    yearID   W   L    R    AB     H   2B  3B   HR   BB    SO   SB   ERA  CG  \
# 0    1997  84  78  829  5628  1531  279  25  161  617   953  126  4.52   9
# 1    1998  85  77  787  5630  1530  314  27  147  510  1028   93  4.49   3
# 2    1999  70  92  711  5494  1404  248  22  158  511  1022   71  4.79   4
# 3    2000  82  80  864  5628  1574  309  34  236  608  1024   93  5.00   5
# 4    2001  75  87  691  5551  1447  275  26  158  494  1001  116  4.20   6
#
#    SHO  SV            name  WSWin_Y  lgID_NL
# 0    5  39  Anaheim Angels        0        0
# 1    5  52  Anaheim Angels        0        0
# 2    7  37  Anaheim Angels        0        0
# 3    3  46  Anaheim Angels        0        0
# 4    1  43  Anaheim Angels        0        0

# %%
#Set X(data) and y(team)variables

data = data_bin.drop("name", axis = 1)
outcome = data_bin["name"]
print(data.shape, outcome.shape)
# Out:
# (1349, 18) (1349,)

# %% [markdown]
# Preprocess data

# %%
#Import SciKit libraries

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from tensorflow.keras.utils import to_categorical

# %%
#Split data and teams into training and test data

X_train, X_test, y_train, y_test = train_test_split(data, outcome, test_size = 0.2, random_state=42)
y_train
# Out:
# 755          Minnesota Twins
# 109        Baltimore Orioles
# 1040        San Diego Padres
# 548       Kansas City Royals
# 1341    Washington Nationals
#                 ...
# 1095    San Francisco Giants
# 1130    San Francisco Giants
# 1294       Toronto Blue Jays
# 860         New York Yankees
# 1126    San Francisco Giants
# Name: name, Length: 1079, dtype: object

# %%
#Scale data using MinMaxScaler

X_scaler = StandardScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
X_train_scaled
# Out:
# array([[ 1.61027461, -0.18217349,  0.32814779, ..., -0.12374158,
#         -0.18843736, -1.00837614],
#        [ 0.43325659, -1.43364968,  1.51573775, ..., -0.78910953,
#         -0.18843736, -1.00837614],
#        [-1.50536132, -1.68394491,  1.85504917, ..., -1.67626678,
#         -0.18843736,  0.99169344],
#        ...,
#        [-1.02070684, -1.09992269,  1.26125419, ..., -1.67626678,
#         -0.18843736, -1.00837614],
#        [-0.39757966, -0.51590047,  0.58263135, ...,  0.65252102,
#         -0.18843736, -1.00837614],
#        [ 1.12562013,  0.48528048, -0.35047505, ...,  1.53967828,
#         -0.18843736,  0.99169344]])

# %%
##Import RandomForestClassifier and train
#from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=1000, random_state=1)
#classifier = MultiOutputClassifier(rf, n_jobs=-1)
rf.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=1000,
#                        n_jobs=None, oob_score=False, random_state=1, verbose=0,
#                        warm_start=False)

# %%
#Get Score for RandomForestClassifier
rf.score(X_test_scaled, y_test)
# Out:
# 0.2777777777777778

# %%
#Print data scores for training aand test datasets
print(f"Training Data Score: {rf.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {rf.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 1.0
# Testing Data Score: 0.2777777777777778

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {"bootstrap": [True],
              "max_depth": [20, 40, 100, 125],
#              "max_features": [2,3],
 #            "min_samples_leaf": [3, 4, 5],
              "n_estimators": [100, 500, 1000]
              }
grid = GridSearchCV(rf, param_grid, verbose=3)
grid
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=1000, n_jobs=None,
#                                               oob_score=False, random_state=1,
#                                               verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'bootstrap': [True], 'max_depth': [20, 40, 100, 125],
#                          'n_estimators': [100, 500, 1000]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %% [markdown]
# Train Model

# %%
# Train the model with GridSearch

grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] bootstrap=True, max_depth=20, n_estimators=100 ..................
# C:\Users\swill\Anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_split.py:667: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  bootstrap=True, max_depth=20, n_estimators=100, score=0.245, total=   0.5s
# [CV] bootstrap=True, max_depth=20, n_estimators=100 ..................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s remaining:    0.0s
# [CV]  bootstrap=True, max_depth=20, n_estimators=100, score=0.259, total=   0.5s
# [CV] bootstrap=True, max_depth=20, n_estimators=100 ..................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.0s remaining:    0.0s
# [CV]  bootstrap=True, max_depth=20, n_estimators=100, score=0.255, total=   0.6s
# [CV] bootstrap=True, max_depth=20, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=100, score=0.310, total=   0.5s
# [CV] bootstrap=True, max_depth=20, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=100, score=0.265, total=   0.5s
# [CV] bootstrap=True, max_depth=20, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=500, score=0.255, total=   2.8s
# [CV] bootstrap=True, max_depth=20, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=500, score=0.269, total=   2.7s
# [CV] bootstrap=True, max_depth=20, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=500, score=0.241, total=   2.7s
# [CV] bootstrap=True, max_depth=20, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=500, score=0.301, total=   2.7s
# [CV] bootstrap=True, max_depth=20, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=20, n_estimators=500, score=0.260, total=   2.6s
# [CV] bootstrap=True, max_depth=20, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=20, n_estimators=1000, score=0.264, total=   6.7s
# [CV] bootstrap=True, max_depth=20, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=20, n_estimators=1000, score=0.264, total=   6.9s
# [CV] bootstrap=True, max_depth=20, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=20, n_estimators=1000, score=0.236, total=   8.6s
# [CV] bootstrap=True, max_depth=20, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=20, n_estimators=1000, score=0.306, total=   5.7s
# [CV] bootstrap=True, max_depth=20, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=20, n_estimators=1000, score=0.288, total=   5.5s
# [CV] bootstrap=True, max_depth=40, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=100, score=0.250, total=   0.7s
# [CV] bootstrap=True, max_depth=40, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=100, score=0.259, total=   0.7s
# [CV] bootstrap=True, max_depth=40, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=100, score=0.250, total=   0.5s
# [CV] bootstrap=True, max_depth=40, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=100, score=0.301, total=   0.6s
# [CV] bootstrap=True, max_depth=40, n_estimators=100 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=100, score=0.270, total=   0.7s
# [CV] bootstrap=True, max_depth=40, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=500, score=0.255, total=   2.9s
# [CV] bootstrap=True, max_depth=40, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=500, score=0.264, total=   2.5s
# [CV] bootstrap=True, max_depth=40, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=500, score=0.231, total=   2.5s
# [CV] bootstrap=True, max_depth=40, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=500, score=0.296, total=   2.5s
# [CV] bootstrap=True, max_depth=40, n_estimators=500 ..................
# [CV]  bootstrap=True, max_depth=40, n_estimators=500, score=0.279, total=   2.5s
# [CV] bootstrap=True, max_depth=40, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=40, n_estimators=1000, score=0.269, total=   5.4s
# [CV] bootstrap=True, max_depth=40, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=40, n_estimators=1000, score=0.282, total=   5.6s
# [CV] bootstrap=True, max_depth=40, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=40, n_estimators=1000, score=0.245, total=   5.7s
# [CV] bootstrap=True, max_depth=40, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=40, n_estimators=1000, score=0.310, total=   6.8s
# [CV] bootstrap=True, max_depth=40, n_estimators=1000 .................
# [CV]  bootstrap=True, max_depth=40, n_estimators=1000, score=0.260, total=   6.3s
# [CV] bootstrap=True, max_depth=100, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=100, score=0.250, total=   0.6s
# [CV] bootstrap=True, max_depth=100, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=100, score=0.259, total=   0.6s
# [CV] bootstrap=True, max_depth=100, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=100, score=0.250, total=   0.6s
# [CV] bootstrap=True, max_depth=100, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=100, score=0.301, total=   0.6s
# [CV] bootstrap=True, max_depth=100, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=100, score=0.270, total=   0.6s
# [CV] bootstrap=True, max_depth=100, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=500, score=0.255, total=   3.2s
# [CV] bootstrap=True, max_depth=100, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=500, score=0.264, total=   3.3s
# [CV] bootstrap=True, max_depth=100, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=500, score=0.231, total=   3.0s
# [CV] bootstrap=True, max_depth=100, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=500, score=0.296, total=   2.8s
# [CV] bootstrap=True, max_depth=100, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=100, n_estimators=500, score=0.279, total=   2.8s
# [CV] bootstrap=True, max_depth=100, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=100, n_estimators=1000, score=0.269, total=   5.7s
# [CV] bootstrap=True, max_depth=100, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=100, n_estimators=1000, score=0.282, total=   5.7s
# [CV] bootstrap=True, max_depth=100, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=100, n_estimators=1000, score=0.245, total=   5.7s
# [CV] bootstrap=True, max_depth=100, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=100, n_estimators=1000, score=0.310, total=   5.7s
# [CV] bootstrap=True, max_depth=100, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=100, n_estimators=1000, score=0.260, total=   5.9s
# [CV] bootstrap=True, max_depth=125, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=100, score=0.250, total=   0.6s
# [CV] bootstrap=True, max_depth=125, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=100, score=0.259, total=   0.6s
# [CV] bootstrap=True, max_depth=125, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=100, score=0.250, total=   0.6s
# [CV] bootstrap=True, max_depth=125, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=100, score=0.301, total=   0.6s
# [CV] bootstrap=True, max_depth=125, n_estimators=100 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=100, score=0.270, total=   0.6s
# [CV] bootstrap=True, max_depth=125, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=500, score=0.255, total=   3.0s
# [CV] bootstrap=True, max_depth=125, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=500, score=0.264, total=   3.7s
# [CV] bootstrap=True, max_depth=125, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=500, score=0.231, total=   3.4s
# [CV] bootstrap=True, max_depth=125, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=500, score=0.296, total=   3.3s
# [CV] bootstrap=True, max_depth=125, n_estimators=500 .................
# [CV]  bootstrap=True, max_depth=125, n_estimators=500, score=0.279, total=   3.0s
# [CV] bootstrap=True, max_depth=125, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=125, n_estimators=1000, score=0.269, total=   6.4s
# [CV] bootstrap=True, max_depth=125, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=125, n_estimators=1000, score=0.282, total=   6.5s
# [CV] bootstrap=True, max_depth=125, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=125, n_estimators=1000, score=0.245, total=   6.0s
# [CV] bootstrap=True, max_depth=125, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=125, n_estimators=1000, score=0.310, total=   6.1s
# [CV] bootstrap=True, max_depth=125, n_estimators=1000 ................
# [CV]  bootstrap=True, max_depth=125, n_estimators=1000, score=0.260, total=   6.2s
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:  3.2min finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=1000, n_jobs=None,
#                                               oob_score=False, random_state=1,
#                                               verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'bootstrap': [True], 'max_depth': [20, 40, 100, 125],
#                          'n_estimators': [100, 500, 1000]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
#Print best parameter and score 

print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'bootstrap': True, 'max_depth': 40, 'n_estimators': 1000}
# 0.27338931955211027

# %%
#Read in CSV and create dataframe
mlb_teams= pd.read_csv("MLB 2019 season.csv")

#mlb_teams

mlb_df = mlb_teams[['yearID', 'lgID', 'W', 'L', 'WSWin', 'R', 'AB', 'H', '2B',
       '3B', 'HR', 'BB', 'SO', 'SB', 'ERA', 'CG', 'SHO', 'SV', 'name']]
#mlb_df.head(20)

data_LG = mlb_df.copy()
data_bin = pd.get_dummies(data_LG, columns=["WSWin", "lgID"])
data_bin = data_bin.drop(columns=['WSWin_N', 'lgID_AL'])

#data_bin.head()

feature = data_bin.drop("name", axis=1)
team = data_bin["name"]
#print(data.shape, outcome.shape)

X_feature_scaler = StandardScaler().fit(feature)
X_feature_scaled = X_feature_scaler.transform(feature)
#X_test_scaled = X_scaler.transform(X_test)
#X_train_scaled

#label_team_encoder = LabelEncoder()
#label_team_encoder.fit(team)
#encoded_y_team = label_team_encoder.transform(team)
#encoded_y_test = label_encoder.transform(y_test)
#encoded_y_test

#y_team_categorical = to_categorical(encoded_y_team)
#y_test_categorical = to_categorical(encoded_y_test)

# %% [markdown]
# Evaluate Model

# %%
#Make prediction using test data

predictions = grid.predict(X_feature_scaled)
print('Test Acc: %.3f' % grid.score(X_feature_scaled, team))
# Out:
# Test Acc: 0.333

# %% [markdown]
# Predict World Series Champs

# %%
# Calculate classification report
from sklearn.metrics import classification_report
predictions = rf.predict(X_feature_scaled)
print(predictions)
# Out:
# ['Pittsburgh Pirates' 'San Francisco Giants' 'Kansas City Royals'
#  'Boston Red Sox' 'Cleveland Indians' 'Chicago Cubs' 'San Diego Padres'
#  'Baltimore Orioles' 'Colorado Rockies' 'Detroit Tigers'
#  'New York Yankees' 'Kansas City Royals' 'Baltimore Orioles'
#  'Atlanta Braves' 'San Diego Padres' 'Cincinnati Reds' 'Boston Red Sox'
#  'New York Yankees' 'Atlanta Braves' 'Oakland Athletics'
#  'Philadelphia Phillies' 'Pittsburgh Pirates' 'San Diego Padres'
#  'Oakland Athletics' 'Philadelphia Phillies' 'San Diego Padres'
#  'Toronto Blue Jays' 'Oakland Athletics' 'Baltimore Orioles'
#  'Cincinnati Reds']

# %%
import joblib
filename = 'SWilliams_RFC.sav'
joblib.dump(rf, filename)
# Out:
# ['SWilliams_RFC.sav']
